# %%
import numpy as np
import tensorflow as tf

# %%
generated_mask=np.load('/content/drive/MyDrive/Brain_tumor_Segmentation/asad data/results/final Results all modility/results/complete results/results for combined with different ratios x_test real/8000 generated/masks.npy')
generated_mask.shape
# Out:
# (8000, 128, 128, 4)

# %%
generated_mri=np.load('/content/drive/MyDrive/Brain_tumor_Segmentation/asad data/results/final Results all modility/results/complete results/results for combined with different ratios x_test real/8000 generated/MRI.npy')
generated_mri.shape
# Out:
# (8000, 128, 128, 1)

# %%
np.unique(generated_mask), np.unique(generated_mri)
# Out:
# (array([0., 1.], dtype=float32),
#  array([0.        , 0.05881732, 0.10863662, ..., 0.9999998 , 0.99999994,
#         1.        ], dtype=float32))

# %%
import matplotlib.pyplot as plt

# %%
original_mri=np.load('/content/drive/MyDrive/Brain_tumor_Segmentation/asad data/data/appended all/training/appended flair/flair.npy')

# %%
original_masks=np.load('/content/drive/MyDrive/Brain_tumor_Segmentation/asad data/data/appended all/training/appended masks/masks.npy')

# %%
original_mri.shape,original_masks.shape
# Out:
# ((195, 128, 128, 128), (195, 128, 128, 128))

# %%
image2D = []
mask2d=[]
for i in range(195):
  for j in range(128):
    image2D.append(original_mri[i,:,:,j])
    mask2d.append(original_masks[i,:,:,j])
original_mri = np.array(image2D)
original_masks=np.array(mask2d)
original_mri.shape,original_masks.shape
# Out:
# ((24960, 128, 128), (24960, 128, 128))

# %%
original_mri=np.expand_dims(original_mri, axis = 3)
original_mri.shape
# Out:
# (24960, 128, 128, 1)

# %%
original_mri.shape,original_masks.shape,generated_mri.shape,generated_mask.shape
# Out:
# ((24960, 128, 128, 1),
#  (24960, 128, 128),
#  (8000, 128, 128, 1),
#  (8000, 128, 128, 4))

# %%
path_real=('/content/drive/MyDrive/Brain_tumor_Segmentation/asad data/results/final Results all modility/results/complete results/exp 2 results for combined with different ratios x_test real/5:1/real /')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(original_mri, original_masks, test_size = 0.10)

# %%
x_test.shape,x_train.shape,y_train.shape
# Out:
# ((2496, 128, 128, 1), (22464, 128, 128, 1), (22464, 128, 128))

# %%
np.save(path_real+'x_test',x_test)
np.save(path_real+'y_test',y_test)

# %%
y_test.shape,x_test.shape
# Out:
# ((2496, 128, 128), (2496, 128, 128, 1))

# %%
del x_train,x_test,y_train,y_test,

# %%
original_mri=original_mri[2496:,:,:]

# %%
original_masks=original_masks[2496:,:,:]
original_masks.shape
# Out:
# (22464, 128, 128)

# %%
generated_mask=generated_mask[0:4800:,:,:]
generated_mask.shape
# Out:
# (4800, 128, 128, 4)

# %%
np.unique(generated_mask)
# Out:
# array([0., 1.], dtype=float32)

# %%
np.unique(generated_mri)
# Out:
# array([0.        , 0.05881732, 0.10863662, ..., 0.9999998 , 0.99999994,
#        1.        ], dtype=float32)

# %%
generated_mask.shape
# Out:
# (4800, 128, 128, 4)

# %%
generated_mri=generated_mri[0:4800,:,:]
generated_mri.shape
# Out:
# (4800, 128, 128, 1)

# %%
path_combined='/content/drive/MyDrive/Brain_tumor_Segmentation/asad data/results/final Results all modility/results/complete results/exp3 results for combined with different ratios x_test real/5:1/combined/'

# %%
generated_mask=np.argmax(generated_mask,axis=3)

# %%
original_masks.shape,generated_mask.shape
# Out:
# ((22464, 128, 128), (4800, 128, 128))

# %%
combined_mask=np.concatenate((original_masks, generated_mask))

# %%
combined_mask.shape
# Out:
# (27264, 128, 128)

# %%
np.save(path_combined+'combined_mask',combined_mask)

# %%
original_mri.shape,generated_mri.shape
# Out:
# ((22464, 128, 128, 1), (4800, 128, 128, 1))

# %%
combined_mri=np.concatenate((original_mri, generated_mri))

# %%
np.save(path_combined+'combined_mri',combined_mri)
