# %%
import numpy as np
import nibabel as nib
import glob
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
from tifffile import imsave






########################################

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
##########################
#This part of the code to get an initial understanding of the dataset.
#################################
#PART 1: Load sample images and visualize
#Includes, dividing each image by its max to scale them to [0,1]
#Converting mask from float to uint8
#Changing mask pixel values (labels) from 4 to 3 (as the original labels are 0, 1, 2, 4)
#Visualize
###########################################
#View a few images

#Note: Segmented file name in Folder 355 has a weird name. Rename it to match others.

TRAIN_DATASET_PATH = '/content/drive/MyDrive/TrainingData/'
#VALIDATION_DATASET_PATH = 'BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData'

test_image_flair=nib.load(TRAIN_DATASET_PATH + '/Brats18_2013_21_1/Brats18_2013_21_1_flair.nii').get_fdata()
print(test_image_flair.max())
#Scalers are applied to 1D so let us reshape and then reshape back to original shape. 
test_image_flair=scaler.fit_transform(test_image_flair.reshape(-1, test_image_flair.shape[-1])).reshape(test_image_flair.shape)


test_image_t1=nib.load(TRAIN_DATASET_PATH + '/Brats18_2013_21_1/Brats18_2013_21_1_flair.nii').get_fdata()
test_image_t1=scaler.fit_transform(test_image_t1.reshape(-1, test_image_t1.shape[-1])).reshape(test_image_t1.shape)

test_image_t1ce=nib.load(TRAIN_DATASET_PATH + '/Brats18_2013_21_1/Brats18_2013_21_1_t1ce.nii').get_fdata()
test_image_t1ce=scaler.fit_transform(test_image_t1ce.reshape(-1, test_image_t1ce.shape[-1])).reshape(test_image_t1ce.shape)

test_image_t2=nib.load(TRAIN_DATASET_PATH + '/Brats18_2013_21_1/Brats18_2013_21_1_t2.nii').get_fdata()
test_image_t2=scaler.fit_transform(test_image_t2.reshape(-1, test_image_t2.shape[-1])).reshape(test_image_t2.shape)

test_mask=nib.load(TRAIN_DATASET_PATH + '/Brats18_2013_21_1/Brats18_2013_21_1_seg.nii').get_fdata()
test_mask=test_mask.astype(np.uint8)

print(np.unique(test_mask))  #0, 1, 2, 4 (Need to reencode to 0, 1, 2, 3)
test_mask[test_mask==4] = 3  #Reassign mask values 4 to 3
print(np.unique(test_mask)) 

import random
n_slice=random.randint(0, test_mask.shape[2])

plt.figure(figsize=(12, 8))

plt.subplot(231)
plt.imshow(test_image_flair[:,:,n_slice], cmap='gray')
plt.title('Image flair')
plt.subplot(232)
plt.imshow(test_image_t1[:,:,n_slice], cmap='gray')
plt.title('Image t1')
plt.subplot(233)
plt.imshow(test_image_t1ce[:,:,n_slice], cmap='gray')
plt.title('Image t1ce')
plt.subplot(234)
plt.imshow(test_image_t2[:,:,n_slice], cmap='gray')
plt.title('Image t2')
plt.subplot(235)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()
# Out:
# 1431.0
# [0 1 2 4]
# [0 1 2 3]

# %%
##################################################
#PART 2: Explore the process of combining images to channels and divide them to patches
#Includes...
#Combining all 4 images to 4 channels of a numpy array.
#
################################################
#Flair, T1CE, annd T2 have the most information
#Combine t1ce, t2, and flair into single multichannel image

'''combined_x = np.stack([test_image_flair, test_image_t1ce, test_image_t2], axis=3)

#Crop to a size to be divisible by 64 so we can later extract 64x64x64 patches. 
#cropping x, y, and z
#combined_x=combined_x[24:216, 24:216, 13:141]

combined_x=combined_x[56:184, 56:184, 13:141] #Crop to 128x128x128x4

#Do the same for mask
test_mask = test_mask[56:184, 56:184, 13:141]

n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(combined_x[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(combined_x[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(combined_x[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()


imsave('BraTS2020_TrainingData/combined255.tif', combined_x)
np.save('BraTS2020_TrainingData/combined255.npy', combined_x)
#Verify image is being read properly
#my_img=imread('BraTS2020_TrainingData/combined255.tif')

my_img=np.load('BraTS2020_TrainingData/combined255.npy')

test_mask = to_categorical(test_mask, num_classes=4)
####################################################################
#####################################
#End of understanding the dataset. Now get it organized.
#####################################'''

#Now let us apply the same as above to all the images...
#Merge channels, crop, patchify, save
#GET DATA READY =  GENERATORS OR OTHERWISE

#Keras datagenerator does ntot support 3d

# # # images lists harley
#t1_list = sorted(glob.glob('BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/*/*t1.nii'))
t2_list = sorted(glob.glob('/content/drive/MyDrive/TrainingData/*/*t2.nii'))
t1ce_list = sorted(glob.glob('/content/drive/MyDrive/TrainingData/*/*t1ce.nii'))
flair_list = sorted(glob.glob('/content/drive/MyDrive/TrainingData/*/*flair.nii'))
mask_list = sorted(glob.glob('/content/drive/MyDrive/TrainingData/*/*seg.nii'))

#Each volume generates 18 64x64x64x4 sub-volumes. 
#Total 369 volumes = 6642 sub volumes

for img in range(len(t2_list)):   #Using t1_list as all lists are of same size
    print("Now preparing image and masks number: ", img)
      
    temp_image_t2=nib.load(t2_list[img]).get_fdata()
    temp_image_t2=scaler.fit_transform(temp_image_t2.reshape(-1, temp_image_t2.shape[-1])).reshape(temp_image_t2.shape)
   
    temp_image_t1ce=nib.load(t1ce_list[img]).get_fdata()
    temp_image_t1ce=scaler.fit_transform(temp_image_t1ce.reshape(-1, temp_image_t1ce.shape[-1])).reshape(temp_image_t1ce.shape)
   
    temp_image_flair=nib.load(flair_list[img]).get_fdata()
    temp_image_flair=scaler.fit_transform(temp_image_flair.reshape(-1, temp_image_flair.shape[-1])).reshape(temp_image_flair.shape)
        
    temp_mask=nib.load(mask_list[img]).get_fdata()
    temp_mask=temp_mask.astype(np.uint8)
    temp_mask[temp_mask==4] = 3  #Reassign mask values 4 to 3
    #print(np.unique(temp_mask))
    
    
    temp_combined_images = np.stack([temp_image_flair, temp_image_t1ce, temp_image_t2], axis=3)
    
    #Crop to a size to be divisible by 64 so we can later extract 64x64x64 patches. 
    #cropping x, y, and z
    temp_combined_images=temp_combined_images[56:184, 56:184, 13:141]
    temp_mask = temp_mask[56:184, 56:184, 13:141]
    
    val, counts = np.unique(temp_mask, return_counts=True)
    
    if (1 - (counts[0]/counts.sum())) > 0.01:  #At least 1% useful volume with labels that are not 0
        print("Save Me")
        temp_mask= to_categorical(temp_mask, num_classes=4)
        np.save('/content/drive/MyDrive/input_data_3_channels/images/image_'+str(img)+'.npy', temp_combined_images)
        np.save('/content/drive/MyDrive/input_data_3_channels/masks/mask_'+str(img)+'.npy', temp_mask)
        
    else:
        print("I am useless")
# Out:
# Now preparing image and masks number:  0
# Save Me
# Now preparing image and masks number:  1
# Save Me
# Now preparing image and masks number:  2
# Save Me
# Now preparing image and masks number:  3
# I am useless
# Now preparing image and masks number:  4
# Save Me
# Now preparing image and masks number:  5
# Save Me
# Now preparing image and masks number:  6
# Save Me
# Now preparing image and masks number:  7
# Save Me
# Now preparing image and masks number:  8
# Save Me
# Now preparing image and masks number:  9
# Save Me
# Now preparing image and masks number:  10
# Save Me
# Now preparing image and masks number:  11
# Save Me
# Now preparing image and masks number:  12
# Save Me
# Now preparing image and masks number:  13
# I am useless
# Now preparing image and masks number:  14
# Save Me
# Now preparing image and masks number:  15
# Save Me
# Now preparing image and masks number:  16
# Save Me
# Now preparing image and masks number:  17
# Save Me
# Now preparing image and masks number:  18
# Save Me
# Now preparing image and masks number:  19
# Save Me
# Now preparing image and masks number:  20
# Save Me
# Now preparing image and masks number:  21
# Save Me
# Now preparing image and masks number:  22
# Save Me
# Now preparing image and masks number:  23
# Save Me
# Now preparing image and masks number:  24
# I am useless
# Now preparing image and masks number:  25
# Save Me
# Now preparing image and masks number:  26
# Save Me
# Now preparing image and masks number:  27
# Save Me
# Now preparing image and masks number:  28
# Save Me
# Now preparing image and masks number:  29
# Save Me
# Now preparing image and masks number:  30
# Save Me
# Now preparing image and masks number:  31
# Save Me
# Now preparing image and masks number:  32
# Save Me
# Now preparing image and masks number:  33
# Save Me
# Now preparing image and masks number:  34
# Save Me
# Now preparing image and masks number:  35
# Save Me
# Now preparing image and masks number:  36
# Save Me
# Now preparing image and masks number:  37
# Save Me
# Now preparing image and masks number:  38
# Save Me
# Now preparing image and masks number:  39
# Save Me
# Now preparing image and masks number:  40
# Save Me
# Now preparing image and masks number:  41
# Save Me
# Now preparing image and masks number:  42
# Save Me
# Now preparing image and masks number:  43
# Save Me
# Now preparing image and masks number:  44
# Save Me
# Now preparing image and masks number:  45
# Save Me
# Now preparing image and masks number:  46
# Save Me
# Now preparing image and masks number:  47
# I am useless
# Now preparing image and masks number:  48
# Save Me
# Now preparing image and masks number:  49
# Save Me
# Now preparing image and masks number:  50
# Save Me
# Now preparing image and masks number:  51
# Save Me
# Now preparing image and masks number:  52
# Save Me
# Now preparing image and masks number:  53
# Save Me
# Now preparing image and masks number:  54
# Save Me
# Now preparing image and masks number:  55
# I am useless
# Now preparing image and masks number:  56
# Save Me
# Now preparing image and masks number:  57
# Save Me
# Now preparing image and masks number:  58
# Save Me
# Now preparing image and masks number:  59
# Save Me
# Now preparing image and masks number:  60
# Save Me

# %%
     
################################################################
#Repeat the same from above for validation data folder OR
#Split training data into train and validation

"""
Code for splitting folder into train, test, and val.
Once the new folders are created rename them and arrange in the format below to be used
for semantic segmentation using data generators. 
pip install split-folders
"""
#%pip install split_folders
import splitfolders  # or import split_folders

input_folder = '/content/drive/MyDrive/input_data_3_channels/'
output_folder = '/content/drive/MyDrive/input_data_validation/'
# Split with a ratio.
# To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.
splitfolders.ratio(input_folder, output=output_folder, seed=42, ratio=(.75, .25), group_prefix=None) # default values
# Out:
# Copying files: 0 files [00:00, ? files/s]
# Copying files: 2 files [00:00,  5.18 files/s]
# Copying files: 3 files [00:01,  1.48 files/s]
# Copying files: 4 files [00:02,  1.71 files/s]
# Copying files: 5 files [00:03,  1.01 files/s]
# Copying files: 6 files [00:05,  1.28s/ files]
# Copying files: 7 files [00:07,  1.33s/ files]
# Copying files: 8 files [00:09,  1.71s/ files]
# Copying files: 9 files [00:12,  2.00s/ files]
# Copying files: 10 files [00:12,  1.50s/ files]
# Copying files: 11 files [00:14,  1.47s/ files]
# Copying files: 12 files [00:16,  1.59s/ files]
# Copying files: 13 files [00:17,  1.52s/ files]
# Copying files: 14 files [00:19,  1.76s/ files]
# Copying files: 15 files [00:20,  1.37s/ files]
# Copying files: 16 files [00:22,  1.55s/ files]
# Copying files: 17 files [00:23,  1.57s/ files]
# Copying files: 18 files [00:25,  1.75s/ files]
# Copying files: 19 files [00:27,  1.65s/ files]
# Copying files: 20 files [00:27,  1.28s/ files]
# Copying files: 21 files [00:29,  1.46s/ files]
# Copying files: 22 files [00:30,  1.43s/ files]
# Copying files: 23 files [00:33,  1.78s/ files]
# Copying files: 24 files [00:35,  1.68s/ files]
# Copying files: 25 files [00:36,  1.60s/ files]
# Copying files: 26 files [00:37,  1.54s/ files]
# Copying files: 27 files [00:39,  1.49s/ files]
# Copying files: 28 files [00:41,  1.59s/ files]
# Copying files: 29 files [00:42,  1.52s/ files]
# Copying files: 30 files [00:42,  1.24s/ files]
# Copying files: 31 files [00:44,  1.30s/ files]
# Copying files: 32 files [00:46,  1.68s/ files]
# Copying files: 33 files [00:48,  1.59s/ files]
# Copying files: 34 files [00:49,  1.52s/ files]
# Copying files: 35 files [00:52,  1.76s/ files]
# Copying files: 36 files [00:53,  1.67s/ files]
# Copying files: 37 files [00:54,  1.59s/ files]
# Copying files: 38 files [00:56,  1.53s/ files]
# Copying files: 39 files [00:58,  1.72s/ files]
# Copying files: 40 files [00:59,  1.62s/ files]
# Copying files: 41 files [01:01,  1.71s/ files]
# Copying files: 42 files [01:03,  1.82s/ files]
# Copying files: 43 files [01:05,  1.69s/ files]
# Copying files: 44 files [01:07,  1.73s/ files]
# Copying files: 45 files [01:09,  1.83s/ files]
# Copying files: 46 files [01:10,  1.82s/ files]
# Copying files: 47 files [01:12,  1.70s/ files]
# Copying files: 48 files [01:14,  1.87s/ files]
# Copying files: 49 files [01:16,  1.84s/ files]
# Copying files: 50 files [01:18,  1.98s/ files]
# Copying files: 51 files [01:20,  1.98s/ files]
# Copying files: 52 files [01:22,  2.05s/ files]
# Copying files: 53 files [01:25,  2.08s/ files]
# Copying files: 54 files [01:26,  1.88s/ files]
# Copying files: 55 files [01:28,  1.99s/ files]
# Copying files: 56 files [01:31,  2.10s/ files]
# Copying files: 57 files [01:32,  2.03s/ files]
# Copying files: 58 files [01:34,  1.89s/ files]
# Copying files: 59 files [01:35,  1.73s/ files]
# Copying files: 60 files [01:36,  1.49s/ files]
# Copying files: 61 files [01:38,  1.42s/ files]
# Copying files: 62 files [01:39,  1.30s/ files]
# Copying files: 63 files [01:40,  1.43s/ files]
# Copying files: 64 files [01:42,  1.47s/ files]
# Copying files: 65 files [01:43,  1.46s/ files]
# Copying files: 66 files [01:45,  1.43s/ files]
# Copying files: 67 files [01:46,  1.42s/ files]
# Copying files: 68 files [01:47,  1.43s/ files]
# Copying files: 69 files [01:49,  1.41s/ files]
# Copying files: 70 files [01:50,  1.41s/ files]
# Copying files: 71 files [01:52,  1.41s/ files]
# Copying files: 72 files [01:54,  1.54s/ files]
# Copying files: 73 files [01:55,  1.47s/ files]
# Copying files: 74 files [01:56,  1.41s/ files]
# Copying files: 75 files [01:57,  1.41s/ files]
# Copying files: 76 files [01:59,  1.36s/ files]
# Copying files: 77 files [02:00,  1.34s/ files]
# Copying files: 78 files [02:01,  1.31s/ files]
# Copying files: 79 files [02:02,  1.28s/ files]
# Copying files: 80 files [02:04,  1.31s/ files]
# Copying files: 81 files [02:05,  1.28s/ files]
# Copying files: 82 files [02:06,  1.21s/ files]
# Copying files: 83 files [02:08,  1.28s/ files]
# Copying files: 84 files [02:11,  1.83s/ files]
# Copying files: 85 files [02:13,  2.05s/ files]
# Copying files: 86 files [02:15,  1.86s/ files]
# Copying files: 87 files [02:16,  1.70s/ files]
# Copying files: 88 files [02:17,  1.58s/ files]
# Copying files: 89 files [02:18,  1.46s/ files]
# Copying files: 90 files [02:20,  1.42s/ files]
# Copying files: 91 files [02:25,  2.43s/ files]
# Copying files: 92 files [02:27,  2.30s/ files]
# Copying files: 93 files [02:28,  2.03s/ files]
# Copying files: 94 files [02:29,  1.78s/ files]
# Copying files: 95 files [02:31,  1.65s/ files]
# Copying files: 96 files [02:32,  1.52s/ files]
# Copying files: 97 files [02:33,  1.39s/ files]
# Copying files: 98 files [02:34,  1.33s/ files]
# Copying files: 99 files [02:37,  1.98s/ files]
# Copying files: 100 files [02:39,  1.92s/ files]
# Copying files: 101 files [02:40,  1.66s/ files]
# Copying files: 102 files [02:41,  1.50s/ files]
# Copying files: 103 files [02:43,  1.52s/ files]
# Copying files: 104 files [02:44,  1.41s/ files]
# Copying files: 105 files [02:46,  1.64s/ files]
# Copying files: 106 files [02:52,  2.84s/ files]
# Copying files: 107 files [02:54,  2.59s/ files]
# Copying files: 108 files [02:56,  2.41s/ files]
# Copying files: 109 files [02:59,  2.47s/ files]
# Copying files: 110 files [03:00,  2.23s/ files]
# Copying files: 111 files [03:01,  1.89s/ files]
# Copying files: 112 files [03:04,  1.65s/ files]

# %%
####### Custom Data Generation ####################

import os
import numpy as np


def load_img(img_dir, img_list):
    images=[]
    for i, image_name in enumerate(img_list):    
        if (image_name.split('.')[1] == 'npy'):
            
            image = np.load(img_dir+image_name)
                      
            images.append(image)
    images = np.array(images)
    
    return(images)




def imageLoader(img_dir, img_list, mask_dir, mask_list, batch_size):

    L = len(img_list)

    #keras needs the generator infinite, so we will use while true  
    while True:

        batch_start = 0
        batch_end = batch_size

        while batch_start < L:
            limit = min(batch_end, L)
                       
            X = load_img(img_dir, img_list[batch_start:limit])
            Y = load_img(mask_dir, mask_list[batch_start:limit])

            yield (X,Y) #a tuple with two numpy arrays with batch_size samples     

            batch_start += batch_size   
            batch_end += batch_size

############################################

#Test the generator

from matplotlib import pyplot as plt
import random

train_img_dir = "/content/drive/MyDrive/input_data_validation/train/images/"
train_mask_dir = "/content/drive/MyDrive/input_data_validation/train/masks/"
train_img_list=os.listdir(train_img_dir)
train_mask_list = os.listdir(train_mask_dir)

batch_size = 2

train_img_datagen = imageLoader(train_img_dir, train_img_list, 
                                train_mask_dir, train_mask_list, batch_size)

#Verify generator.... In python 3 next() is renamed as __next__()
img, msk = train_img_datagen.__next__()


img_num = random.randint(0,img.shape[0]-1)
test_img=img[img_num]
test_mask=msk[img_num]
test_mask=np.argmax(test_mask, axis=3)

n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(test_img[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(test_img[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam

# %%
from keras.models import Model
from keras.layers import Input, Conv3D, MaxPooling3D, concatenate, Conv3DTranspose, BatchNormalization, Dropout, Lambda
#from keras.optimizers import Adam
from keras.metrics import MeanIoU

kernel_initializer =  'he_uniform' #Try others if you want


################################################################
def simple_unet_model(IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, IMG_CHANNELS, num_classes):
#Build the model
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, IMG_CHANNELS))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    c1 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(s)
    c1 = Dropout(0.1)(c1)
    c1 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c1)
    p1 = MaxPooling3D((2, 2, 2))(c1)
    
    c2 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p1)
    c2 = Dropout(0.1)(c2)
    c2 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c2)
    p2 = MaxPooling3D((2, 2, 2))(c2)
     
    c3 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c3)
    p3 = MaxPooling3D((2, 2, 2))(c3)
     
    c4 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c4)
    p4 = MaxPooling3D(pool_size=(2, 2, 2))(c4)
     
    c5 = Conv3D(256, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv3D(256, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c5)
    
    #Expansive path 
    u6 = Conv3DTranspose(128, (2, 2, 2), strides=(2, 2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c6)
     
    u7 = Conv3DTranspose(64, (2, 2, 2), strides=(2, 2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c7)
     
    u8 = Conv3DTranspose(32, (2, 2, 2), strides=(2, 2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u8)
    c8 = Dropout(0.1)(c8)
    c8 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c8)
     
    u9 = Conv3DTranspose(16, (2, 2, 2), strides=(2, 2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1])
    c9 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u9)
    c9 = Dropout(0.1)(c9)
    c9 = Conv3D(16, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c9)
     
    outputs = Conv3D(num_classes, (1, 1, 1), activation='softmax')(c9)
     
    model = Model(inputs=[inputs], outputs=[outputs])
    #compile model outside of this function to make it flexible. 
    model.summary()
    
    return model

#Test if everything is working ok. 
model = simple_unet_model(128, 128, 128, 3, 4)
print(model.input_shape)
print(model.output_shape)

# %%
# %pip install custom

# %%
"""
@author: Sreenivas Bhattiprolu
Code to train batches of cropped BraTS 2020 images using 3D U-net.
Please get the data ready and define custom data gnerator using the other
files in this directory.
Images are expected to be 128x128x128x3 npy data (3 corresponds to the 3 channels for 
                                                  test_image_flair, test_image_t1ce, test_image_t2)
Change the U-net input shape based on your input dataset shape (e.g. if you decide to only se 2 channels or all 4 channels)
Masks are expected to be 128x128x128x3 npy data (4 corresponds to the 4 classes / labels)
You can change input image sizes to customize for your computing resources.
"""


import os
import numpy as np
#from custom_datagen import imageLoader
#import tensorflow as tf
import keras
from matplotlib import pyplot as plt
import glob
import random



####################################################
train_img_dir = "/content/drive/MyDrive/input_data_validation/train/images/"
train_mask_dir = "/content/drive/MyDrive/input_data_validation/train/masks/"

img_list = os.listdir(train_img_dir)
msk_list = os.listdir(train_mask_dir)

num_images = len(os.listdir(train_img_dir))

img_num = random.randint(0,num_images-1)
test_img = np.load(train_img_dir+img_list[img_num])
test_mask = np.load(train_mask_dir+msk_list[img_num])
test_mask = np.argmax(test_mask, axis=3)

n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(test_img[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(test_img[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
##############################################################
#Define the image generators for training and validation

train_img_dir = "/content/drive/MyDrive/input_data_validation/train/images/"
train_mask_dir = "/content/drive/MyDrive/input_data_validation/train/masks/"

val_img_dir = "/content/drive/MyDrive/input_data_validation/val/images/"
val_mask_dir = "/content/drive/MyDrive/input_data_validation/val/masks/"

train_img_list=os.listdir(train_img_dir)
train_mask_list = os.listdir(train_mask_dir)

val_img_list=os.listdir(val_img_dir)
val_mask_list = os.listdir(val_mask_dir)
##################################

########################################################################
batch_size = 2

train_img_datagen = imageLoader(train_img_dir, train_img_list, 
                                train_mask_dir, train_mask_list, batch_size)

val_img_datagen = imageLoader(val_img_dir, val_img_list, 
                                val_mask_dir, val_mask_list, batch_size)

#Verify generator.... In python 3 next() is renamed as __next__()
img, msk = train_img_datagen.__next__()

img_num = random.randint(0,img.shape[0]-1)
test_img=img[img_num]
test_mask=msk[img_num]
test_mask=np.argmax(test_mask, axis=3)

n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(test_img[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(test_img[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
# !pip install classification-models-3D
# !pip install efficientnet-3D
# !pip install segmentation-models-3D
# Out:
# Requirement already satisfied: classification-models-3D in /usr/local/lib/python3.7/dist-packages (1.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from classification-models-3D) (1.19.5)
# Requirement already satisfied: keras>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from classification-models-3D) (2.6.0)
# Requirement already satisfied: efficientnet-3D in /usr/local/lib/python3.7/dist-packages (1.0.1)
# Requirement already satisfied: keras>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from efficientnet-3D) (2.6.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from efficientnet-3D) (1.19.5)
# Requirement already satisfied: segmentation-models-3D in /usr/local/lib/python3.7/dist-packages (1.0.1)
# Requirement already satisfied: classification-models-3D in /usr/local/lib/python3.7/dist-packages (from segmentation-models-3D) (1.0.2)
# Requirement already satisfied: efficientnet-3D in /usr/local/lib/python3.7/dist-packages (from segmentation-models-3D) (1.0.1)
# Requirement already satisfied: keras>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from segmentation-models-3D) (2.6.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from classification-models-3D->segmentation-models-3D) (1.19.5)

# %%
# !pip install keras_applications
import segmentation_models_3D as sm
# Out:
# Collecting keras_applications
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 3.0 MB/s
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras_applications) (1.19.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras_applications) (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras_applications) (1.5.2)
# Installing collected packages: keras-applications
# Successfully installed keras-applications-1.0.8
# Segmentation Models: using `keras` framework.

# %%
import tensorflow as tf

# %%
###########################################################################
#Define loss, metrics and optimizer to be used for training
wt0, wt1, wt2, wt3 = 0.25,0.25,0.25,0.25
#import segmentation_models_3D as sm
dice_loss = sm.losses.DiceLoss(class_weights=np.array([wt0, wt1, wt2, wt3])) 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

metrics = ['accuracy', sm.metrics.IOUScore(threshold=0.5)]

LR = 0.0001

from tensorflow.keras.optimizers import Adam

#optim = tensorflow.keras.optimizers.Adam(LR)

optim = Adam(LR)
#######################################################################
#Fit the model 

steps_per_epoch = len(train_img_list)//batch_size
val_steps_per_epoch = len(val_img_list)//batch_size

# %%
#from  simple_3d_unet import simple_unet_model

model = simple_unet_model(IMG_HEIGHT=128, 
                          IMG_WIDTH=128, 
                          IMG_DEPTH=128, 
                          IMG_CHANNELS=3, 
                          num_classes=4)

model.compile(optimizer = optim, loss=total_loss, metrics=metrics)
print(model.summary())

print(model.input_shape)
print(model.output_shape)

history=model.fit(train_img_datagen,
          steps_per_epoch=steps_per_epoch,
          epochs=100,
          verbose=1,
          validation_data=val_img_datagen,
          validation_steps=val_steps_per_epoch,
          )

model.save('brats_3d.hdf5')
##################################################################


#plot the training and validation IoU and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
#################################################
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 128, 128, 12 0
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 128, 128, 128 1312        input_2[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 128, 128, 128 0           conv3d_19[0][0]
# __________________________________________________________________________________________________
# conv3d_20 (Conv3D)              (None, 128, 128, 128 6928        dropout_9[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_4 (MaxPooling3D)  (None, 64, 64, 64, 1 0           conv3d_20[0][0]
# __________________________________________________________________________________________________
# conv3d_21 (Conv3D)              (None, 64, 64, 64, 3 13856       max_pooling3d_4[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 64, 64, 64, 3 0           conv3d_21[0][0]
# __________________________________________________________________________________________________
# conv3d_22 (Conv3D)              (None, 64, 64, 64, 3 27680       dropout_10[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_5 (MaxPooling3D)  (None, 32, 32, 32, 3 0           conv3d_22[0][0]
# __________________________________________________________________________________________________
# conv3d_23 (Conv3D)              (None, 32, 32, 32, 6 55360       max_pooling3d_5[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 32, 32, 32, 6 0           conv3d_23[0][0]
# __________________________________________________________________________________________________
# conv3d_24 (Conv3D)              (None, 32, 32, 32, 6 110656      dropout_11[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_6 (MaxPooling3D)  (None, 16, 16, 16, 6 0           conv3d_24[0][0]
# __________________________________________________________________________________________________
# conv3d_25 (Conv3D)              (None, 16, 16, 16, 1 221312      max_pooling3d_6[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 16, 16, 16, 1 0           conv3d_25[0][0]
# __________________________________________________________________________________________________
# conv3d_26 (Conv3D)              (None, 16, 16, 16, 1 442496      dropout_12[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_7 (MaxPooling3D)  (None, 8, 8, 8, 128) 0           conv3d_26[0][0]
# __________________________________________________________________________________________________
# conv3d_27 (Conv3D)              (None, 8, 8, 8, 256) 884992      max_pooling3d_7[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 8, 8, 8, 256) 0           conv3d_27[0][0]
# __________________________________________________________________________________________________
# conv3d_28 (Conv3D)              (None, 8, 8, 8, 256) 1769728     dropout_13[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_4 (Conv3DTrans (None, 16, 16, 16, 1 262272      conv3d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 16, 16, 16, 2 0           conv3d_transpose_4[0][0]
#                                                                  conv3d_26[0][0]
# __________________________________________________________________________________________________
# conv3d_29 (Conv3D)              (None, 16, 16, 16, 1 884864      concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 16, 16, 16, 1 0           conv3d_29[0][0]
# __________________________________________________________________________________________________
# conv3d_30 (Conv3D)              (None, 16, 16, 16, 1 442496      dropout_14[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_5 (Conv3DTrans (None, 32, 32, 32, 6 65600       conv3d_30[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 32, 32, 32, 1 0           conv3d_transpose_5[0][0]
#                                                                  conv3d_24[0][0]
# __________________________________________________________________________________________________
# conv3d_31 (Conv3D)              (None, 32, 32, 32, 6 221248      concatenate_5[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 32, 32, 32, 6 0           conv3d_31[0][0]
# __________________________________________________________________________________________________
# conv3d_32 (Conv3D)              (None, 32, 32, 32, 6 110656      dropout_15[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_6 (Conv3DTrans (None, 64, 64, 64, 3 16416       conv3d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 64, 6 0           conv3d_transpose_6[0][0]
#                                                                  conv3d_22[0][0]
# __________________________________________________________________________________________________
# conv3d_33 (Conv3D)              (None, 64, 64, 64, 3 55328       concatenate_6[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 64, 64, 64, 3 0           conv3d_33[0][0]
# __________________________________________________________________________________________________
# conv3d_34 (Conv3D)              (None, 64, 64, 64, 3 27680       dropout_16[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_7 (Conv3DTrans (None, 128, 128, 128 4112        conv3d_34[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 128, 128, 128 0           conv3d_transpose_7[0][0]
#                                                                  conv3d_20[0][0]
# __________________________________________________________________________________________________
# conv3d_35 (Conv3D)              (None, 128, 128, 128 13840       concatenate_7[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 128, 128, 128 0           conv3d_35[0][0]
# __________________________________________________________________________________________________
# conv3d_36 (Conv3D)              (None, 128, 128, 128 6928        dropout_17[0][0]
# __________________________________________________________________________________________________
# conv3d_37 (Conv3D)              (None, 128, 128, 128 68          conv3d_36[0][0]
# ==================================================================================================
# Total params: 5,645,828
# Trainable params: 5,645,828
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 128, 128, 12 0
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 128, 128, 128 1312        input_2[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 128, 128, 128 0           conv3d_19[0][0]
# __________________________________________________________________________________________________
# conv3d_20 (Conv3D)              (None, 128, 128, 128 6928        dropout_9[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_4 (MaxPooling3D)  (None, 64, 64, 64, 1 0           conv3d_20[0][0]
# __________________________________________________________________________________________________
# conv3d_21 (Conv3D)              (None, 64, 64, 64, 3 13856       max_pooling3d_4[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 64, 64, 64, 3 0           conv3d_21[0][0]
# __________________________________________________________________________________________________
# conv3d_22 (Conv3D)              (None, 64, 64, 64, 3 27680       dropout_10[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_5 (MaxPooling3D)  (None, 32, 32, 32, 3 0           conv3d_22[0][0]
# __________________________________________________________________________________________________
# conv3d_23 (Conv3D)              (None, 32, 32, 32, 6 55360       max_pooling3d_5[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 32, 32, 32, 6 0           conv3d_23[0][0]
# __________________________________________________________________________________________________
# conv3d_24 (Conv3D)              (None, 32, 32, 32, 6 110656      dropout_11[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_6 (MaxPooling3D)  (None, 16, 16, 16, 6 0           conv3d_24[0][0]
# __________________________________________________________________________________________________
# conv3d_25 (Conv3D)              (None, 16, 16, 16, 1 221312      max_pooling3d_6[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 16, 16, 16, 1 0           conv3d_25[0][0]
# __________________________________________________________________________________________________
# conv3d_26 (Conv3D)              (None, 16, 16, 16, 1 442496      dropout_12[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_7 (MaxPooling3D)  (None, 8, 8, 8, 128) 0           conv3d_26[0][0]
# __________________________________________________________________________________________________
# conv3d_27 (Conv3D)              (None, 8, 8, 8, 256) 884992      max_pooling3d_7[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 8, 8, 8, 256) 0           conv3d_27[0][0]
# __________________________________________________________________________________________________
# conv3d_28 (Conv3D)              (None, 8, 8, 8, 256) 1769728     dropout_13[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_4 (Conv3DTrans (None, 16, 16, 16, 1 262272      conv3d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 16, 16, 16, 2 0           conv3d_transpose_4[0][0]
#                                                                  conv3d_26[0][0]
# __________________________________________________________________________________________________
# conv3d_29 (Conv3D)              (None, 16, 16, 16, 1 884864      concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 16, 16, 16, 1 0           conv3d_29[0][0]
# __________________________________________________________________________________________________
# conv3d_30 (Conv3D)              (None, 16, 16, 16, 1 442496      dropout_14[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_5 (Conv3DTrans (None, 32, 32, 32, 6 65600       conv3d_30[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 32, 32, 32, 1 0           conv3d_transpose_5[0][0]
#                                                                  conv3d_24[0][0]
# __________________________________________________________________________________________________
# conv3d_31 (Conv3D)              (None, 32, 32, 32, 6 221248      concatenate_5[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 32, 32, 32, 6 0           conv3d_31[0][0]
# __________________________________________________________________________________________________
# conv3d_32 (Conv3D)              (None, 32, 32, 32, 6 110656      dropout_15[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_6 (Conv3DTrans (None, 64, 64, 64, 3 16416       conv3d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 64, 6 0           conv3d_transpose_6[0][0]
#                                                                  conv3d_22[0][0]
# __________________________________________________________________________________________________
# conv3d_33 (Conv3D)              (None, 64, 64, 64, 3 55328       concatenate_6[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 64, 64, 64, 3 0           conv3d_33[0][0]
# __________________________________________________________________________________________________
# conv3d_34 (Conv3D)              (None, 64, 64, 64, 3 27680       dropout_16[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_7 (Conv3DTrans (None, 128, 128, 128 4112        conv3d_34[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 128, 128, 128 0           conv3d_transpose_7[0][0]
#                                                                  conv3d_20[0][0]
# __________________________________________________________________________________________________
# conv3d_35 (Conv3D)              (None, 128, 128, 128 13840       concatenate_7[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 128, 128, 128 0           conv3d_35[0][0]
# __________________________________________________________________________________________________
# conv3d_36 (Conv3D)              (None, 128, 128, 128 6928        dropout_17[0][0]
# __________________________________________________________________________________________________
# conv3d_37 (Conv3D)              (None, 128, 128, 128 68          conv3d_36[0][0]
# ==================================================================================================
# Total params: 5,645,828
# Trainable params: 5,645,828
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# (None, 128, 128, 128, 3)
# (None, 128, 128, 128, 4)
# Epoch 1/100
# 21/21 [==============================] - 206s 8s/step - loss: 1.0275 - accuracy: 0.2607 - iou_score: 0.0149 - val_loss: 1.0077 - val_accuracy: 0.6378 - val_iou_score: 1.1036e-04
# Epoch 2/100
# 21/21 [==============================] - 135s 7s/step - loss: 0.9795 - accuracy: 0.8476 - iou_score: 0.1470 - val_loss: 0.9675 - val_accuracy: 0.9507 - val_iou_score: 0.1621
# Epoch 3/100
# 21/21 [==============================] - 122s 6s/step - loss: 0.9557 - accuracy: 0.9447 - iou_score: 0.2220 - val_loss: 0.9630 - val_accuracy: 0.9537 - val_iou_score: 0.1325
# Epoch 4/100
# 21/21 [==============================] - 118s 6s/step - loss: 0.9455 - accuracy: 0.9477 - iou_score: 0.2212 - val_loss: 0.9517 - val_accuracy: 0.9544 - val_iou_score: 0.1563
# Epoch 5/100
# 21/21 [==============================] - 115s 6s/step - loss: 0.9408 - accuracy: 0.9498 - iou_score: 0.2313 - val_loss: 0.9640 - val_accuracy: 0.8687 - val_iou_score: 0.1182
# Epoch 6/100
# 21/21 [==============================] - 111s 5s/step - loss: 0.9410 - accuracy: 0.9360 - iou_score: 0.2056 - val_loss: 0.9556 - val_accuracy: 0.8624 - val_iou_score: 0.1418
# Epoch 7/100
# 21/21 [==============================] - 107s 5s/step - loss: 0.9322 - accuracy: 0.9527 - iou_score: 0.2366 - val_loss: 0.9541 - val_accuracy: 0.7494 - val_iou_score: 0.1585
# Epoch 8/100
# 21/21 [==============================] - 103s 5s/step - loss: 0.9240 - accuracy: 0.9557 - iou_score: 0.2465 - val_loss: 0.9679 - val_accuracy: 0.5817 - val_iou_score: 0.1318
# Epoch 9/100
# 21/21 [==============================] - 106s 5s/step - loss: 0.9319 - accuracy: 0.8941 - iou_score: 0.2463 - val_loss: 0.9538 - val_accuracy: 0.7194 - val_iou_score: 0.1862
# Epoch 10/100
# 21/21 [==============================] - 106s 5s/step - loss: 0.9202 - accuracy: 0.9540 - iou_score: 0.2852 - val_loss: 0.9575 - val_accuracy: 0.6913 - val_iou_score: 0.2134
# Epoch 11/100
# 21/21 [==============================] - 104s 5s/step - loss: 0.9180 - accuracy: 0.9464 - iou_score: 0.3057 - val_loss: 0.9585 - val_accuracy: 0.7073 - val_iou_score: 0.2123
# Epoch 12/100
# 21/21 [==============================] - 116s 6s/step - loss: 0.9146 - accuracy: 0.9505 - iou_score: 0.3155 - val_loss: 0.9615 - val_accuracy: 0.7074 - val_iou_score: 0.2084
# Epoch 13/100
# 21/21 [==============================] - 110s 5s/step - loss: 0.9103 - accuracy: 0.9561 - iou_score: 0.3260 - val_loss: 0.9672 - val_accuracy: 0.6921 - val_iou_score: 0.1994
# Epoch 14/100
# 21/21 [==============================] - 111s 5s/step - loss: 0.9083 - accuracy: 0.9570 - iou_score: 0.3308 - val_loss: 0.9698 - val_accuracy: 0.6944 - val_iou_score: 0.1988
# Epoch 15/100
# 21/21 [==============================] - 116s 6s/step - loss: 0.9063 - accuracy: 0.9574 - iou_score: 0.3355 - val_loss: 0.9748 - val_accuracy: 0.6776 - val_iou_score: 0.1932
# Epoch 16/100
# 21/21 [==============================] - 108s 5s/step - loss: 0.9046 - accuracy: 0.9583 - iou_score: 0.3394 - val_loss: 0.9793 - val_accuracy: 0.6698 - val_iou_score: 0.1910
# Epoch 17/100
# 21/21 [==============================] - 110s 5s/step - loss: 0.9026 - accuracy: 0.9582 - iou_score: 0.3451 - val_loss: 0.9815 - val_accuracy: 0.6711 - val_iou_score: 0.1933
# Epoch 18/100
# 21/21 [==============================] - 108s 5s/step - loss: 0.9008 - accuracy: 0.9579 - iou_score: 0.3533 - val_loss: 0.9823 - val_accuracy: 0.6905 - val_iou_score: 0.1992
# Epoch 19/100
# 21/21 [==============================] - 104s 5s/step - loss: 0.8971 - accuracy: 0.9601 - iou_score: 0.3669 - val_loss: 0.9833 - val_accuracy: 0.7027 - val_iou_score: 0.2049
# Epoch 20/100
# 21/21 [==============================] - 109s 5s/step - loss: 0.8929 - accuracy: 0.9619 - iou_score: 0.3814 - val_loss: 0.9966 - val_accuracy: 0.6454 - val_iou_score: 0.1894
# Epoch 21/100
# 21/21 [==============================] - 116s 6s/step - loss: 0.8963 - accuracy: 0.9508 - iou_score: 0.3782 - val_loss: 0.9426 - val_accuracy: 0.8575 - val_iou_score: 0.2707
# Epoch 22/100
# 21/21 [==============================] - 116s 6s/step - loss: 0.8915 - accuracy: 0.9575 - iou_score: 0.3881 - val_loss: 0.9353 - val_accuracy: 0.8719 - val_iou_score: 0.2864
# Epoch 23/100
# 21/21 [==============================] - 116s 6s/step - loss: 0.8894 - accuracy: 0.9653 - iou_score: 0.3912 - val_loss: 0.9783 - val_accuracy: 0.7333 - val_iou_score: 0.2172
# Epoch 24/100
# 21/21 [==============================] - 106s 5s/step - loss: 0.8814 - accuracy: 0.9646 - iou_score: 0.4112 - val_loss: 0.9687 - val_accuracy: 0.7745 - val_iou_score: 0.2358
# Epoch 25/100
# 21/21 [==============================] - 106s 5s/step - loss: 0.8792 - accuracy: 0.9656 - iou_score: 0.4184 - val_loss: 0.9513 - val_accuracy: 0.8270 - val_iou_score: 0.2625
# Epoch 26/100
# 21/21 [==============================] - 104s 5s/step - loss: 0.8772 - accuracy: 0.9674 - iou_score: 0.4250 - val_loss: 0.9854 - val_accuracy: 0.7414 - val_iou_score: 0.2220
# Epoch 27/100
# 21/21 [==============================] - 104s 5s/step - loss: 0.8695 - accuracy: 0.9683 - iou_score: 0.4563 - val_loss: 0.9474 - val_accuracy: 0.8308 - val_iou_score: 0.2688
# Epoch 28/100
# 21/21 [==============================] - 106s 5s/step - loss: 0.8663 - accuracy: 0.9701 - iou_score: 0.4742 - val_loss: 0.9729 - val_accuracy: 0.7723 - val_iou_score: 0.2432
# Epoch 29/100
# 21/21 [==============================] - 104s 5s/step - loss: 0.8642 - accuracy: 0.9700 - iou_score: 0.4824 - val_loss: 0.9717 - val_accuracy: 0.7698 - val_iou_score: 0.2447
# Epoch 30/100
# 21/21 [==============================] - 110s 5s/step - loss: 0.8630 - accuracy: 0.9689 - iou_score: 0.4890 - val_loss: 0.9169 - val_accuracy: 0.9105 - val_iou_score: 0.3268
# Epoch 31/100
# 21/21 [==============================] - 116s 6s/step - loss: 0.8658 - accuracy: 0.9677 - iou_score: 0.4800 - val_loss: 0.9811 - val_accuracy: 0.7667 - val_iou_score: 0.2405
# Epoch 32/100
# 21/21 [==============================] - 104s 5s/step - loss: 0.8541 - accuracy: 0.9710 - iou_score: 0.5135 - val_loss: 0.9261 - val_accuracy: 0.8759 - val_iou_score: 0.3103
# Epoch 33/100
# 21/21 [==============================] - 106s 5s/step - loss: 0.8515 - accuracy: 0.9727 - iou_score: 0.5221 - val_loss: 0.9588 - val_accuracy: 0.7869 - val_iou_score: 0.2679
# Epoch 34/100
# 21/21 [==============================] - 117s 6s/step - loss: 0.8518 - accuracy: 0.9726 - iou_score: 0.5220 - val_loss: 0.9542 - val_accuracy: 0.7942 - val_iou_score: 0.2674
# Epoch 35/100
# 21/21 [==============================] - 109s 5s/step - loss: 0.8545 - accuracy: 0.9714 - iou_score: 0.5129 - val_loss: 0.9579 - val_accuracy: 0.7868 - val_iou_score: 0.2739
# Epoch 36/100
# 21/21 [==============================] - 107s 5s/step - loss: 0.8580 - accuracy: 0.9695 - iou_score: 0.5017 - val_loss: 0.9369 - val_accuracy: 0.8326 - val_iou_score: 0.3073
# Epoch 37/100
# 21/21 [==============================] - 113s 5s/step - loss: 0.8494 - accuracy: 0.9713 - iou_score: 0.5323 - val_loss: 0.9187 - val_accuracy: 0.8901 - val_iou_score: 0.3273
# Epoch 38/100
# 21/21 [==============================] - 116s 6s/step - loss: 0.8453 - accuracy: 0.9740 - iou_score: 0.5436 - val_loss: 0.9109 - val_accuracy: 0.9086 - val_iou_score: 0.3510
# Epoch 39/100
# 21/21 [==============================] - 115s 6s/step - loss: 0.8478 - accuracy: 0.9719 - iou_score: 0.5380 - val_loss: 0.9176 - val_accuracy: 0.8885 - val_iou_score: 0.3333
# Epoch 40/100
# 21/21 [==============================] - 112s 5s/step - loss: 0.8462 - accuracy: 0.9721 - iou_score: 0.5403 - val_loss: 0.9156 - val_accuracy: 0.8992 - val_iou_score: 0.3382
# Epoch 41/100
# 21/21 [==============================] - 107s 5s/step - loss: 0.8453 - accuracy: 0.9724 - iou_score: 0.5434 - val_loss: 0.9232 - val_accuracy: 0.8677 - val_iou_score: 0.3238
# Epoch 42/100
# 21/21 [==============================] - 117s 6s/step - loss: 0.8427 - accuracy: 0.9734 - iou_score: 0.5526 - val_loss: 0.9289 - val_accuracy: 0.8490 - val_iou_score: 0.3243
# Epoch 43/100
# 21/21 [==============================] - 113s 5s/step - loss: 0.8413 - accuracy: 0.9747 - iou_score: 0.5573 - val_loss: 0.9083 - val_accuracy: 0.9199 - val_iou_score: 0.3546
# Epoch 44/100
# 21/21 [==============================] - 111s 5s/step - loss: 0.8410 - accuracy: 0.9734 - iou_score: 0.5585 - val_loss: 0.9061 - val_accuracy: 0.9119 - val_iou_score: 0.3584
# Epoch 45/100
# 21/21 [==============================] - 108s 5s/step - loss: 0.8396 - accuracy: 0.9734 - iou_score: 0.5644 - val_loss: 0.8904 - val_accuracy: 0.9274 - val_iou_score: 0.4075
# Epoch 46/100
# 21/21 [==============================] - 105s 5s/step - loss: 0.8407 - accuracy: 0.9733 - iou_score: 0.5595 - val_loss: 0.8941 - val_accuracy: 0.9249 - val_iou_score: 0.3964
# Epoch 47/100
# 21/21 [==============================] - 105s 5s/step - loss: 0.8398 - accuracy: 0.9737 - iou_score: 0.5613 - val_loss: 0.8833 - val_accuracy: 0.9461 - val_iou_score: 0.4215
# Epoch 48/100
# 21/21 [==============================] - 112s 5s/step - loss: 0.8346 - accuracy: 0.9762 - iou_score: 0.5796 - val_loss: 0.8818 - val_accuracy: 0.9570 - val_iou_score: 0.4269
# Epoch 49/100
# 21/21 [==============================] - 117s 6s/step - loss: 0.8393 - accuracy: 0.9741 - iou_score: 0.5637 - val_loss: 0.8845 - val_accuracy: 0.9528 - val_iou_score: 0.4202
# Epoch 50/100
# 21/21 [==============================] - 117s 6s/step - loss: 0.8330 - accuracy: 0.9753 - iou_score: 0.5853 - val_loss: 0.8921 - val_accuracy: 0.9287 - val_iou_score: 0.3992
# Epoch 51/100
# 21/21 [==============================] - 109s 5s/step - loss: 0.8292 - accuracy: 0.9774 - iou_score: 0.5998 - val_loss: 0.9125 - val_accuracy: 0.8941 - val_iou_score: 0.3589
# Epoch 52/100
# 21/21 [==============================] - 108s 5s/step - loss: 0.8319 - accuracy: 0.9755 - iou_score: 0.5903 - val_loss: 0.9011 - val_accuracy: 0.9010 - val_iou_score: 0.3900
# Epoch 53/100
# 21/21 [==============================] - 108s 5s/step - loss: 0.8270 - accuracy: 0.9773 - iou_score: 0.6082 - val_loss: 0.8787 - val_accuracy: 0.9537 - val_iou_score: 0.4369
# Epoch 54/100
# 21/21 [==============================] - 109s 5s/step - loss: 0.8246 - accuracy: 0.9789 - iou_score: 0.6173 - val_loss: 0.8801 - val_accuracy: 0.9625 - val_iou_score: 0.4331
# Epoch 55/100
# 21/21 [==============================] - 105s 5s/step - loss: 0.8259 - accuracy: 0.9779 - iou_score: 0.6138 - val_loss: 0.8846 - val_accuracy: 0.9458 - val_iou_score: 0.4188
# Epoch 56/100
# 21/21 [==============================] - 106s 5s/step - loss: 0.8230 - accuracy: 0.9784 - iou_score: 0.6247 - val_loss: 0.8888 - val_accuracy: 0.9350 - val_iou_score: 0.4153
# Epoch 57/100
# 21/21 [==============================] - 104s 5s/step - loss: 0.8228 - accuracy: 0.9785 - iou_score: 0.6247 - val_loss: 0.8878 - val_accuracy: 0.9305 - val_iou_score: 0.4207
# Epoch 58/100
# 21/21 [==============================] - 104s 5s/step - loss: 0.8191 - accuracy: 0.9798 - iou_score: 0.6386 - val_loss: 0.8790 - val_accuracy: 0.9584 - val_iou_score: 0.4381
# Epoch 59/100
# 21/21 [==============================] - 104s 5s/step - loss: 0.8229 - accuracy: 0.9787 - iou_score: 0.6238 - val_loss: 0.8766 - val_accuracy: 0.9619 - val_iou_score: 0.4441
# Epoch 60/100
# 21/21 [==============================] - 117s 6s/step - loss: 0.8190 - accuracy: 0.9796 - iou_score: 0.6391 - val_loss: 0.8935 - val_accuracy: 0.9285 - val_iou_score: 0.4004
# Epoch 61/100
# 21/21 [==============================] - 117s 6s/step - loss: 0.8147 - accuracy: 0.9809 - iou_score: 0.6562 - val_loss: 0.8741 - val_accuracy: 0.9551 - val_iou_score: 0.4560
# Epoch 62/100
# 21/21 [==============================] - 111s 5s/step - loss: 0.8118 - accuracy: 0.9818 - iou_score: 0.6675 - val_loss: 0.8817 - val_accuracy: 0.9398 - val_iou_score: 0.4345
# Epoch 63/100
# 21/21 [==============================] - 111s 5s/step - loss: 0.8118 - accuracy: 0.9819 - iou_score: 0.6675 - val_loss: 0.8770 - val_accuracy: 0.9542 - val_iou_score: 0.4475
# Epoch 64/100
# 21/21 [==============================] - 117s 6s/step - loss: 0.8124 - accuracy: 0.9816 - iou_score: 0.6653 - val_loss: 0.8793 - val_accuracy: 0.9429 - val_iou_score: 0.4403
# Epoch 65/100
# 21/21 [==============================] - 113s 5s/step - loss: 0.8106 - accuracy: 0.9823 - iou_score: 0.6729 - val_loss: 0.8845 - val_accuracy: 0.9351 - val_iou_score: 0.4271
# Epoch 66/100
# 21/21 [==============================] - 107s 5s/step - loss: 0.8114 - accuracy: 0.9820 - iou_score: 0.6693 - val_loss: 0.8799 - val_accuracy: 0.9468 - val_iou_score: 0.4373
# Epoch 67/100
# 21/21 [==============================] - 113s 5s/step - loss: 0.8093 - accuracy: 0.9828 - iou_score: 0.6784 - val_loss: 0.8862 - val_accuracy: 0.9419 - val_iou_score: 0.4173
# Epoch 68/100
# 21/21 [==============================] - 112s 5s/step - loss: 0.8100 - accuracy: 0.9827 - iou_score: 0.6751 - val_loss: 0.8854 - val_accuracy: 0.9313 - val_iou_score: 0.4289
# Epoch 69/100
# 21/21 [==============================] - 113s 5s/step - loss: 0.8079 - accuracy: 0.9831 - iou_score: 0.6842 - val_loss: 0.8922 - val_accuracy: 0.9315 - val_iou_score: 0.4109
# Epoch 70/100
# 21/21 [==============================] - 117s 6s/step - loss: 0.8075 - accuracy: 0.9831 - iou_score: 0.6864 - val_loss: 0.8956 - val_accuracy: 0.9232 - val_iou_score: 0.4082
# Epoch 71/100
# 21/21 [==============================] - 117s 6s/step - loss: 0.8103 - accuracy: 0.9825 - iou_score: 0.6761 - val_loss: 0.8943 - val_accuracy: 0.9377 - val_iou_score: 0.4026
# Epoch 72/100
# 21/21 [==============================] - 107s 5s/step - loss: 0.8089 - accuracy: 0.9829 - iou_score: 0.6807 - val_loss: 0.8862 - val_accuracy: 0.9491 - val_iou_score: 0.4224
# Epoch 73/100
# 21/21 [==============================] - 117s 6s/step - loss: 0.8104 - accuracy: 0.9822 - iou_score: 0.6756 - val_loss: 0.8948 - val_accuracy: 0.9487 - val_iou_score: 0.4000
# Epoch 74/100
# 21/21 [==============================] - 112s 5s/step - loss: 0.8168 - accuracy: 0.9798 - iou_score: 0.6485 - val_loss: 0.9007 - val_accuracy: 0.9401 - val_iou_score: 0.3908
# Epoch 75/100
# 21/21 [==============================] - 117s 6s/step - loss: 0.8168 - accuracy: 0.9797 - iou_score: 0.6485 - val_loss: 0.8834 - val_accuracy: 0.9376 - val_iou_score: 0.4306
# Epoch 76/100
# 21/21 [==============================] - 114s 5s/step - loss: 0.8181 - accuracy: 0.9779 - iou_score: 0.6479 - val_loss: 0.8861 - val_accuracy: 0.9628 - val_iou_score: 0.4272
# Epoch 77/100
# 21/21 [==============================] - 109s 5s/step - loss: 0.8097 - accuracy: 0.9818 - iou_score: 0.6774 - val_loss: 0.8800 - val_accuracy: 0.9616 - val_iou_score: 0.4374
# Epoch 78/100
# 21/21 [==============================] - 109s 5s/step - loss: 0.8124 - accuracy: 0.9805 - iou_score: 0.6710 - val_loss: 0.8932 - val_accuracy: 0.9702 - val_iou_score: 0.4105
# Epoch 79/100
# 21/21 [==============================] - 113s 5s/step - loss: 0.8131 - accuracy: 0.9802 - iou_score: 0.6644 - val_loss: 0.8830 - val_accuracy: 0.9645 - val_iou_score: 0.4334
# Epoch 80/100
# 21/21 [==============================] - 116s 6s/step - loss: 0.8095 - accuracy: 0.9825 - iou_score: 0.6790 - val_loss: 0.8772 - val_accuracy: 0.9681 - val_iou_score: 0.4437
# Epoch 81/100
# 21/21 [==============================] - 116s 6s/step - loss: 0.8082 - accuracy: 0.9823 - iou_score: 0.6839 - val_loss: 0.8840 - val_accuracy: 0.9696 - val_iou_score: 0.4292
# Epoch 82/100
# 21/21 [==============================] - 116s 6s/step - loss: 0.8102 - accuracy: 0.9819 - iou_score: 0.6761 - val_loss: 0.8807 - val_accuracy: 0.9607 - val_iou_score: 0.4285
# Epoch 83/100
# 21/21 [==============================] - 116s 6s/step - loss: 0.8052 - accuracy: 0.9831 - iou_score: 0.6960 - val_loss: 0.8817 - val_accuracy: 0.9678 - val_iou_score: 0.4313
# Epoch 84/100
# 21/21 [==============================] - 115s 6s/step - loss: 0.8037 - accuracy: 0.9834 - iou_score: 0.7035 - val_loss: 0.8832 - val_accuracy: 0.9713 - val_iou_score: 0.4300
# Epoch 85/100
# 21/21 [==============================] - 113s 5s/step - loss: 0.8034 - accuracy: 0.9828 - iou_score: 0.7046 - val_loss: 0.8853 - val_accuracy: 0.9716 - val_iou_score: 0.4259
# Epoch 86/100
# 21/21 [==============================] - 116s 6s/step - loss: 0.8046 - accuracy: 0.9823 - iou_score: 0.6991 - val_loss: 0.8859 - val_accuracy: 0.9719 - val_iou_score: 0.4233
# Epoch 87/100
# 21/21 [==============================] - 116s 6s/step - loss: 0.8075 - accuracy: 0.9813 - iou_score: 0.6850 - val_loss: 0.8888 - val_accuracy: 0.9675 - val_iou_score: 0.4124
# Epoch 88/100
# 21/21 [==============================] - 116s 6s/step - loss: 0.8128 - accuracy: 0.9805 - iou_score: 0.6640 - val_loss: 0.8949 - val_accuracy: 0.9626 - val_iou_score: 0.4035
# Epoch 89/100
# 21/21 [==============================] - 110s 5s/step - loss: 0.8115 - accuracy: 0.9824 - iou_score: 0.6687 - val_loss: 0.8810 - val_accuracy: 0.9592 - val_iou_score: 0.4276
# Epoch 90/100
# 21/21 [==============================] - 106s 5s/step - loss: 0.8109 - accuracy: 0.9828 - iou_score: 0.6711 - val_loss: 0.8875 - val_accuracy: 0.9636 - val_iou_score: 0.4233
# Epoch 91/100
# 21/21 [==============================] - 106s 5s/step - loss: 0.8060 - accuracy: 0.9834 - iou_score: 0.6906 - val_loss: 0.8757 - val_accuracy: 0.9674 - val_iou_score: 0.4543
# Epoch 92/100
# 21/21 [==============================] - 106s 5s/step - loss: 0.8044 - accuracy: 0.9835 - iou_score: 0.6980 - val_loss: 0.8749 - val_accuracy: 0.9688 - val_iou_score: 0.4504
# Epoch 93/100
# 21/21 [==============================] - 104s 5s/step - loss: 0.8080 - accuracy: 0.9826 - iou_score: 0.6842 - val_loss: 0.8654 - val_accuracy: 0.9712 - val_iou_score: 0.4812
# Epoch 94/100
# 21/21 [==============================] - 104s 5s/step - loss: 0.8037 - accuracy: 0.9837 - iou_score: 0.7010 - val_loss: 0.8632 - val_accuracy: 0.9681 - val_iou_score: 0.4837
# Epoch 95/100
# 21/21 [==============================] - 104s 5s/step - loss: 0.8022 - accuracy: 0.9841 - iou_score: 0.7077 - val_loss: 0.8727 - val_accuracy: 0.9479 - val_iou_score: 0.4574
# Epoch 96/100
# 21/21 [==============================] - 104s 5s/step - loss: 0.8008 - accuracy: 0.9850 - iou_score: 0.7130 - val_loss: 0.8649 - val_accuracy: 0.9582 - val_iou_score: 0.4783
# Epoch 97/100
# 21/21 [==============================] - 105s 5s/step - loss: 0.8011 - accuracy: 0.9851 - iou_score: 0.7126 - val_loss: 0.8762 - val_accuracy: 0.9480 - val_iou_score: 0.4462
# Epoch 98/100
# 21/21 [==============================] - 107s 5s/step - loss: 0.7999 - accuracy: 0.9854 - iou_score: 0.7175 - val_loss: 0.8692 - val_accuracy: 0.9543 - val_iou_score: 0.4650
# Epoch 99/100
# 21/21 [==============================] - 106s 5s/step - loss: 0.7988 - accuracy: 0.9856 - iou_score: 0.7230 - val_loss: 0.8771 - val_accuracy: 0.9514 - val_iou_score: 0.4424
# Epoch 100/100
# 21/21 [==============================] - 116s 6s/step - loss: 0.7976 - accuracy: 0.9859 - iou_score: 0.7279 - val_loss: 0.8757 - val_accuracy: 0.9486 - val_iou_score: 0.4483

# %%
from keras.models import load_model

#Load model for prediction or continue training

#For continuing training....
#The following gives an error: Unknown loss function: dice_loss_plus_1focal_loss
#This is because the model does not save loss function and metrics. So to compile and 
#continue training we need to provide these as custom_objects.
#my_model = load_model('saved_models/brats_3d_100epochs_simple_unet_weighted_dice.hdf5')
my_model = load_model('brats_3d.hdf5')


#So let us add the loss as custom object... but the following throws another error...
#Unknown metric function: iou_score
my_model = load_model('saved_models/brats_3d_100epochs_simple_unet_weighted_dice.hdf5', 
                      custom_objects={'dice_loss_plus_1focal_loss': total_loss})

#Now, let us add the iou_score function we used during our initial training
my_model = load_model('saved_models/brats_3d_100epochs_simple_unet_weighted_dice.hdf5', 
                      custom_objects={'dice_loss_plus_1focal_loss': total_loss,
                                      'iou_score':sm.metrics.IOUScore(threshold=0.5)})

#Now all set to continue the training process. 
history2=my_model.fit(train_img_datagen,
          steps_per_epoch=steps_per_epoch,
          epochs=1,
          verbose=1,
          validation_data=val_img_datagen,
          validation_steps=val_steps_per_epoch,
          )
#################################################

#For predictions you do not need to compile the model, so ...
my_model = load_model('saved_models/brats_3d_100epochs_simple_unet_weighted_dice.hdf5', 
                      compile=False)


#Verify IoU on a batch of images from the test dataset
#Using built in keras function for IoU
#Only works on TF > 2.0
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-eeca3c8f594e> in <module>()
#       8 #continue training we need to provide these as custom_objects.
#       9 #my_model = load_model('saved_models/brats_3d_100epochs_simple_unet_weighted_dice.hdf5')
# ---> 10 my_model = load_model('brats_3d.hdf5')
#      11
#      12
#
# /usr/local/lib/python3.7/dist-packages/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     203         filepath = path_to_string(filepath)
#     204         if isinstance(filepath, str):
# --> 205           return saved_model_load.load(filepath, compile, options)
#     206
#     207   raise IOError(
#
# /usr/local/lib/python3.7/dist-packages/keras/saving/saved_model/load.py in load(path, compile, options)
#     106   # Look for metadata file or parse the SavedModel
#     107   metadata = saved_metadata_pb2.SavedMetadata()
# --> 108   meta_graph_def = tf.__internal__.saved_model.parse_saved_model(path).meta_graphs[0]
#     109   object_graph_def = meta_graph_def.object_graph_def
#     110   path_to_metadata_pb = os.path.join(path, constants.SAVED_METADATA_PATH)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
#     119         "SavedModel file does not exist at: %s%s{%s|%s}" %
#     120         (export_dir, os.path.sep, constants.SAVED_MODEL_FILENAME_PBTXT,
# --> 121          constants.SAVED_MODEL_FILENAME_PB))
#     122
#     123
#
# OSError: SavedModel file does not exist at: brats_3d.hdf5/{saved_model.pbtxt|saved_model.pb}

# %%
from keras.metrics import MeanIoU

batch_size=8 #Check IoU for a batch of images
test_img_datagen = imageLoader(val_img_dir, val_img_list, 
                                val_mask_dir, val_mask_list, batch_size)

#Verify generator.... In python 3 next() is renamed as __next__()
test_image_batch, test_mask_batch = test_img_datagen.__next__()

test_mask_batch_argmax = np.argmax(test_mask_batch, axis=4)
test_pred_batch = my_model.predict(test_image_batch)
test_pred_batch_argmax = np.argmax(test_pred_batch, axis=4)

n_classes = 4
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(test_pred_batch_argmax, test_mask_batch_argmax)
print("Mean IoU =", IOU_keras.result().numpy())

#############################################
#Predict on a few test images, one at a time
#Try images: 
img_num = 82

test_img = np.load("BraTS2020_TrainingData/input_data_128/val/images/image_"+str(img_num)+".npy")

test_mask = np.load("BraTS2020_TrainingData/input_data_128/val/masks/mask_"+str(img_num)+".npy")
test_mask_argmax=np.argmax(test_mask, axis=3)

test_img_input = np.expand_dims(test_img, axis=0)
test_prediction = my_model.predict(test_img_input)
test_prediction_argmax=np.argmax(test_prediction, axis=4)[0,:,:,:]


# print(test_prediction_argmax.shape)
# print(test_mask_argmax.shape)
# print(np.unique(test_prediction_argmax))


#Plot individual slices from test predictions for verification
from matplotlib import pyplot as plt
import random

#n_slice=random.randint(0, test_prediction_argmax.shape[2])
n_slice = 55
plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,n_slice,1], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_mask_argmax[:,:,n_slice])
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction_argmax[:,:, n_slice])
plt.show()

############################################################

# %%
#############################################################
#Optional step of finding the distribution of each class and calculating appropriate weights
#Alternatively you can just assign equal weights and see how well the model performs: 0.25, 0.25, 0.25, 0.25

import pandas as pd
columns = ['0','1', '2', '3']
df = pd.DataFrame(columns=columns)
train_mask_list = sorted(glob.glob('BraTS2020_TrainingData/input_data_128/train/masks/*.npy'))
for img in range(len(train_mask_list)):
    print(img)
    temp_image=np.load(train_mask_list[img])
    temp_image = np.argmax(temp_image, axis=3)
    val, counts = np.unique(temp_image, return_counts=True)
    zipped = zip(columns, counts)
    conts_dict = dict(zipped)
    
    df = df.append(conts_dict, ignore_index=True)

label_0 = df['0'].sum()
label_1 = df['1'].sum()
label_2 = df['1'].sum()
label_3 = df['3'].sum()
total_labels = label_0 + label_1 + label_2 + label_3
n_classes = 4
#Class weights claculation: n_samples / (n_classes * n_samples_for_class)
wt0 = round((total_labels/(n_classes*label_0)), 2) #round to 2 decimals
wt1 = round((total_labels/(n_classes*label_1)), 2)
wt2 = round((total_labels/(n_classes*label_2)), 2)
wt3 = round((total_labels/(n_classes*label_3)), 2)

#Weights are: 0.26, 22.53, 22.53, 26.21
#wt0, wt1, wt2, wt3 = 0.26, 22.53, 22.53, 26.21
#These weihts can be used for Dice loss
