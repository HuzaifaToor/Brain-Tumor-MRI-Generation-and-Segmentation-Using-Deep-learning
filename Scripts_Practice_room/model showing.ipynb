# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import keras
model=keras.models.load_model('/content/drive/MyDrive/brain tumor segmentation/asad data/save models')

# %%
model.summary()
# Out:
# Model: "SegNet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 128, 128, 1)]     0
#
#  block1_conv1 (Conv2D)       (None, 128, 128, 64)      640
#
#  batch_normalization_26 (Bat  (None, 128, 128, 64)     256
#  chNormalization)
#
#  activation_26 (Activation)  (None, 128, 128, 64)      0
#
#  block1_conv2 (Conv2D)       (None, 128, 128, 64)      36928
#
#  batch_normalization_27 (Bat  (None, 128, 128, 64)     256
#  chNormalization)
#
#  activation_27 (Activation)  (None, 128, 128, 64)      0
#
#  block1_pool (MaxPooling2D)  (None, 64, 64, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 64, 64, 128)       73856
#
#  batch_normalization_28 (Bat  (None, 64, 64, 128)      512
#  chNormalization)
#
#  activation_28 (Activation)  (None, 64, 64, 128)       0
#
#  block2_conv2 (Conv2D)       (None, 64, 64, 128)       147584
#
#  batch_normalization_29 (Bat  (None, 64, 64, 128)      512
#  chNormalization)
#
#  activation_29 (Activation)  (None, 64, 64, 128)       0
#
#  block2_pool (MaxPooling2D)  (None, 32, 32, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 32, 32, 256)       295168
#
#  batch_normalization_30 (Bat  (None, 32, 32, 256)      1024
#  chNormalization)
#
#  activation_30 (Activation)  (None, 32, 32, 256)       0
#
#  block3_conv2 (Conv2D)       (None, 32, 32, 256)       590080
#
#  batch_normalization_31 (Bat  (None, 32, 32, 256)      1024
#  chNormalization)
#
#  activation_31 (Activation)  (None, 32, 32, 256)       0
#
#  block3_conv3 (Conv2D)       (None, 32, 32, 256)       590080
#
#  batch_normalization_32 (Bat  (None, 32, 32, 256)      1024
#  chNormalization)
#
#  activation_32 (Activation)  (None, 32, 32, 256)       0
#
#  block3_pool (MaxPooling2D)  (None, 16, 16, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 16, 16, 512)       1180160
#
#  batch_normalization_33 (Bat  (None, 16, 16, 512)      2048
#  chNormalization)
#
#  activation_33 (Activation)  (None, 16, 16, 512)       0
#
#  block4_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  batch_normalization_34 (Bat  (None, 16, 16, 512)      2048
#  chNormalization)
#
#  activation_34 (Activation)  (None, 16, 16, 512)       0
#
#  block4_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  batch_normalization_35 (Bat  (None, 16, 16, 512)      2048
#  chNormalization)
#
#  activation_35 (Activation)  (None, 16, 16, 512)       0
#
#  block4_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  batch_normalization_36 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  activation_36 (Activation)  (None, 8, 8, 512)         0
#
#  block5_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  batch_normalization_37 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  activation_37 (Activation)  (None, 8, 8, 512)         0
#
#  block5_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  batch_normalization_38 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  activation_38 (Activation)  (None, 8, 8, 512)         0
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  up_sampling2d_5 (UpSampling  (None, 8, 8, 512)        0
#  2D)
#
#  conv2d_13 (Conv2D)          (None, 8, 8, 512)         2359808
#
#  batch_normalization_39 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  activation_39 (Activation)  (None, 8, 8, 512)         0
#
#  conv2d_14 (Conv2D)          (None, 8, 8, 512)         2359808
#
#  batch_normalization_40 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  activation_40 (Activation)  (None, 8, 8, 512)         0
#
#  conv2d_15 (Conv2D)          (None, 8, 8, 512)         2359808
#
#  batch_normalization_41 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  activation_41 (Activation)  (None, 8, 8, 512)         0
#
#  up_sampling2d_6 (UpSampling  (None, 16, 16, 512)      0
#  2D)
#
#  conv2d_16 (Conv2D)          (None, 16, 16, 512)       2359808
#
#  batch_normalization_42 (Bat  (None, 16, 16, 512)      2048
#  chNormalization)
#
#  activation_42 (Activation)  (None, 16, 16, 512)       0
#
#  conv2d_17 (Conv2D)          (None, 16, 16, 512)       2359808
#
#  batch_normalization_43 (Bat  (None, 16, 16, 512)      2048
#  chNormalization)
#
#  activation_43 (Activation)  (None, 16, 16, 512)       0
#
#  conv2d_18 (Conv2D)          (None, 16, 16, 256)       1179904
#
#  batch_normalization_44 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  activation_44 (Activation)  (None, 16, 16, 256)       0
#
#  up_sampling2d_7 (UpSampling  (None, 32, 32, 256)      0
#  2D)
#
#  conv2d_19 (Conv2D)          (None, 32, 32, 256)       590080
#
#  batch_normalization_45 (Bat  (None, 32, 32, 256)      1024
#  chNormalization)
#
#  activation_45 (Activation)  (None, 32, 32, 256)       0
#
#  conv2d_20 (Conv2D)          (None, 32, 32, 256)       590080
#
#  batch_normalization_46 (Bat  (None, 32, 32, 256)      1024
#  chNormalization)
#
#  activation_46 (Activation)  (None, 32, 32, 256)       0
#
#  conv2d_21 (Conv2D)          (None, 32, 32, 128)       295040
#
#  batch_normalization_47 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  activation_47 (Activation)  (None, 32, 32, 128)       0
#
#  up_sampling2d_8 (UpSampling  (None, 64, 64, 128)      0
#  2D)
#
#  conv2d_22 (Conv2D)          (None, 64, 64, 128)       147584
#
#  batch_normalization_48 (Bat  (None, 64, 64, 128)      512
#  chNormalization)
#
#  activation_48 (Activation)  (None, 64, 64, 128)       0
#
#  conv2d_23 (Conv2D)          (None, 64, 64, 64)        73792
#
#  batch_normalization_49 (Bat  (None, 64, 64, 64)       256
#  chNormalization)
#
#  activation_49 (Activation)  (None, 64, 64, 64)        0
#
#  up_sampling2d_9 (UpSampling  (None, 128, 128, 64)     0
#  2D)
#
#  conv2d_24 (Conv2D)          (None, 128, 128, 64)      36928
#
#  batch_normalization_50 (Bat  (None, 128, 128, 64)     256
#  chNormalization)
#
#  activation_50 (Activation)  (None, 128, 128, 64)      0
#
#  conv2d_25 (Conv2D)          (None, 128, 128, 4)       260
#
#  batch_normalization_51 (Bat  (None, 128, 128, 4)      16
#  chNormalization)
#
#  reshape_1 (Reshape)         (None, 128, 128, 4)       0
#
#  activation_51 (Activation)  (None, 128, 128, 4)       0
#
# =================================================================
# Total params: 29,458,004
# Trainable params: 29,442,124
# Non-trainable params: 15,880
# _________________________________________________________________

# %%
# !pip3 install keras-visualizer
# Out:
# Collecting keras-visualizer
#   Downloading keras_visualizer-2.4-py3-none-any.whl (5.4 kB)
# Installing collected packages: keras-visualizer
# Successfully installed keras-visualizer-2.4

# %%
from keras_visualizer import visualizer

# %%
from keras.utils.vis_utils import plot_model

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
 
from IPython.display import SVG

SVG(vutil.to_graph(model, recursive=True, show_shape=True).create(prog='dot', format="svg"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d1314284fe4c> in <module>()
#       2 from IPython.display import SVG
#       3
# ----> 4 SVG(vutil.to_graph(model, recursive=True, show_shape=True).create(prog='dot', format="svg"))
#
# NameError: name 'vutil' is not defined
