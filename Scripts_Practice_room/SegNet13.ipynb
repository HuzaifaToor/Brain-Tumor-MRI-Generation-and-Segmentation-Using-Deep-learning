# %%
from keras.models import Model,Sequential
import numpy as  np
from keras.layers.core import Activation, Reshape, Permute
from keras.layers.convolutional import Convolution2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.layers import BatchNormalization
from keras.layers import Input, merge, Conv2D,Concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau, TensorBoard, Callback
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array, load_img, ImageDataGenerator
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras import backend as K
from tensorflow.python import keras
from sklearn.model_selection import train_test_split
from keras.models import Model, Sequential
from keras.layers import Activation, Dense, BatchNormalization, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from keras.callbacks import EarlyStopping
from keras import backend as K

import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
from keras.layers import Conv3D, MaxPooling3D, concatenate, UpSampling3D
# %matplotlib inline

# %%
def segnet():#,savename):

    # Encoding layer
    img_input = Input(shape= (128,128,128))
    x = Conv2D(64, (3, 3), padding='same', name='conv1',strides= (1,1))(img_input)
    x = BatchNormalization(name='bn1')(x)
    x = Activation('relu')(x)
    x = Conv2D(64, (3, 3), padding='same', name='conv2')(x)
    x = BatchNormalization(name='bn2')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)
    
    x = Conv2D(128, (3, 3), padding='same', name='conv3')(x)
    x = BatchNormalization(name='bn3')(x)
    x = Activation('relu')(x)
    x = Conv2D(128, (3, 3), padding='same', name='conv4')(x)
    x = BatchNormalization(name='bn4')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Conv2D(256, (3, 3), padding='same', name='conv5')(x)
    x = BatchNormalization(name='bn5')(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same', name='conv6')(x)
    x = BatchNormalization(name='bn6')(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same', name='conv7')(x)
    x = BatchNormalization(name='bn7')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Conv2D(512, (3, 3), padding='same', name='conv8')(x)
    x = BatchNormalization(name='bn8')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv9')(x)
    x = BatchNormalization(name='bn9')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv10')(x)
    x = BatchNormalization(name='bn10')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)
    
    x = Conv2D(512, (3, 3), padding='same', name='conv11')(x)
    x = BatchNormalization(name='bn11')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv12')(x)
    x = BatchNormalization(name='bn12')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv13')(x)
    x = BatchNormalization(name='bn13')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Dense(1024, activation = 'relu', name='fc1')(x)
    x = Dense(1024, activation = 'relu', name='fc2')(x)
    # Decoding Layer 
    x = UpSampling2D()(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv1')(x)
    x = BatchNormalization(name='bn14')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv2')(x)
    x = BatchNormalization(name='bn15')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv3')(x)
    x = BatchNormalization(name='bn16')(x)
    x = Activation('relu')(x)
    
    x = UpSampling2D()(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv4')(x)
    x = BatchNormalization(name='bn17')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv5')(x)
    x = BatchNormalization(name='bn18')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv6')(x)
    x = BatchNormalization(name='bn19')(x)
    x = Activation('relu')(x)

    x = UpSampling2D()(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv7')(x)
    x = BatchNormalization(name='bn20')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv8')(x)
    x = BatchNormalization(name='bn21')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv9')(x)
    x = BatchNormalization(name='bn22')(x)
    x = Activation('relu')(x)

    x = UpSampling2D()(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv10')(x)
    x = BatchNormalization(name='bn23')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv11')(x)
    x = BatchNormalization(name='bn24')(x)
    x = Activation('relu')(x)
    
    x = UpSampling2D()(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv12')(x)
    x = BatchNormalization(name='bn25')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv13')(x)
    x = BatchNormalization(name='bn26')(x)
    x = Activation('softmax')(x)
    print("x.shape",x.shape)
    pred = Reshape((128,128,128))(x)
    
    model = Model(inputs=img_input, outputs=pred)
    
    model.compile(optimizer= Adam(learning_rate=0.001, decay=0.05), loss= ["binary_crossentropy"]
                  , metrics=[iou, dice_coef, precision, recall, accuracy])

    
    model.summary()
    #hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 18, validation_data= (x_val, y_val), verbose=1)
    
    #model.save(savename)
    return model#,hist

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

def dice_coef(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision
def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall
def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %%
import numpy as np
import nibabel as nib
import glob
#from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
x_train = np.load('/content/drive/MyDrive/brain tumor segmentation/huzaifa data/Prepared_MRI_data/Origna_data_handling/Stack_Arrays/train_images.npy')
x_test = np.load('/content/drive/MyDrive/brain tumor segmentation/huzaifa data/Prepared_MRI_data/Origna_data_handling/Stack_Arrays/val_images.npy')
y_train = np.load('/content/drive/MyDrive/brain tumor segmentation/huzaifa data/Prepared_MRI_data/Origna_data_handling/Stack_Arrays/train_masks.npy')
y_test = np.load('/content/drive/MyDrive/brain tumor segmentation/huzaifa data/Prepared_MRI_data/Origna_data_handling/Stack_Arrays/val_masks.npy')

# %%
#y_train_catagorical = tf.keras.utils.to_categorical(y_train)

# %%
#y_test_catagorical = tf.keras.utils.to_categorical(y_test)

# %%
# !pip install keras_applications
# !pip install classification-models-3D
# !pip install efficientnet-3D
# !pip install segmentation-models-3D

# %%
model = segnet()
#model.compile(optimizer = optim, loss=total_loss, metrics=metrics)
hist = model.fit(x_train, y_train, epochs= 100, batch_size= 2, validation_data= (x_test, y_test), verbose=1)
# Out:
# x.shape (None, 128, 128, 128)
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 128, 128)]   0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 128, 128, 64)      73792
# _________________________________________________________________
# bn1 (BatchNormalization)     (None, 128, 128, 64)      256
# _________________________________________________________________
# activation (Activation)      (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 128, 128, 64)      36928
# _________________________________________________________________
# bn2 (BatchNormalization)     (None, 128, 128, 64)      256
# _________________________________________________________________
# activation_1 (Activation)    (None, 128, 128, 64)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 64)        0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 64, 64, 128)       73856
# _________________________________________________________________
# bn3 (BatchNormalization)     (None, 64, 64, 128)       512
# _________________________________________________________________
# activation_2 (Activation)    (None, 64, 64, 128)       0
# _________________________________________________________________
# conv4 (Conv2D)               (None, 64, 64, 128)       147584
# _________________________________________________________________
# bn4 (BatchNormalization)     (None, 64, 64, 128)       512
# _________________________________________________________________
# activation_3 (Activation)    (None, 64, 64, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 128)       0
# _________________________________________________________________
# conv5 (Conv2D)               (None, 32, 32, 256)       295168
# _________________________________________________________________
# bn5 (BatchNormalization)     (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_4 (Activation)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv6 (Conv2D)               (None, 32, 32, 256)       590080
# _________________________________________________________________
# bn6 (BatchNormalization)     (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_5 (Activation)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv7 (Conv2D)               (None, 32, 32, 256)       590080
# _________________________________________________________________
# bn7 (BatchNormalization)     (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_6 (Activation)    (None, 32, 32, 256)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 256)       0
# _________________________________________________________________
# conv8 (Conv2D)               (None, 16, 16, 512)       1180160
# _________________________________________________________________
# bn8 (BatchNormalization)     (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_7 (Activation)    (None, 16, 16, 512)       0
# _________________________________________________________________
# conv9 (Conv2D)               (None, 16, 16, 512)       2359808
# _________________________________________________________________
# bn9 (BatchNormalization)     (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_8 (Activation)    (None, 16, 16, 512)       0
# _________________________________________________________________
# conv10 (Conv2D)              (None, 16, 16, 512)       2359808
# _________________________________________________________________
# bn10 (BatchNormalization)    (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_9 (Activation)    (None, 16, 16, 512)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 512)         0
# _________________________________________________________________
# conv11 (Conv2D)              (None, 8, 8, 512)         2359808
# _________________________________________________________________
# bn11 (BatchNormalization)    (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_10 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# conv12 (Conv2D)              (None, 8, 8, 512)         2359808
# _________________________________________________________________
# bn12 (BatchNormalization)    (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_11 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# conv13 (Conv2D)              (None, 8, 8, 512)         2359808
# _________________________________________________________________
# bn13 (BatchNormalization)    (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_12 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4, 4, 1024)        525312
# _________________________________________________________________
# fc2 (Dense)                  (None, 4, 4, 1024)        1049600
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 8, 8, 1024)        0
# _________________________________________________________________
# deconv1 (Conv2DTranspose)    (None, 8, 8, 512)         4719104
# _________________________________________________________________
# bn14 (BatchNormalization)    (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_13 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# deconv2 (Conv2DTranspose)    (None, 8, 8, 512)         2359808
# _________________________________________________________________
# bn15 (BatchNormalization)    (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_14 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# deconv3 (Conv2DTranspose)    (None, 8, 8, 512)         2359808
# _________________________________________________________________
# bn16 (BatchNormalization)    (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_15 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 16, 16, 512)       0
# _________________________________________________________________
# deconv4 (Conv2DTranspose)    (None, 16, 16, 512)       2359808
# _________________________________________________________________
# bn17 (BatchNormalization)    (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_16 (Activation)   (None, 16, 16, 512)       0
# _________________________________________________________________
# deconv5 (Conv2DTranspose)    (None, 16, 16, 512)       2359808
# _________________________________________________________________
# bn18 (BatchNormalization)    (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_17 (Activation)   (None, 16, 16, 512)       0
# _________________________________________________________________
# deconv6 (Conv2DTranspose)    (None, 16, 16, 256)       1179904
# _________________________________________________________________
# bn19 (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# activation_18 (Activation)   (None, 16, 16, 256)       0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 32, 32, 256)       0
# _________________________________________________________________
# deconv7 (Conv2DTranspose)    (None, 32, 32, 256)       590080
# _________________________________________________________________
# bn20 (BatchNormalization)    (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_19 (Activation)   (None, 32, 32, 256)       0
# _________________________________________________________________
# deconv8 (Conv2DTranspose)    (None, 32, 32, 256)       590080
# _________________________________________________________________
# bn21 (BatchNormalization)    (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_20 (Activation)   (None, 32, 32, 256)       0
# _________________________________________________________________
# deconv9 (Conv2DTranspose)    (None, 32, 32, 128)       295040
# _________________________________________________________________
# bn22 (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# activation_21 (Activation)   (None, 32, 32, 128)       0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 64, 64, 128)       0
# _________________________________________________________________
# deconv10 (Conv2DTranspose)   (None, 64, 64, 128)       147584
# _________________________________________________________________
# bn23 (BatchNormalization)    (None, 64, 64, 128)       512
# _________________________________________________________________
# activation_22 (Activation)   (None, 64, 64, 128)       0
# _________________________________________________________________
# deconv11 (Conv2DTranspose)   (None, 64, 64, 64)        73792
# _________________________________________________________________
# bn24 (BatchNormalization)    (None, 64, 64, 64)        256
# _________________________________________________________________
# activation_23 (Activation)   (None, 64, 64, 64)        0
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 128, 128, 64)      0
# _________________________________________________________________
# deconv12 (Conv2DTranspose)   (None, 128, 128, 128)     73856
# _________________________________________________________________
# bn25 (BatchNormalization)    (None, 128, 128, 128)     512
# _________________________________________________________________
# activation_24 (Activation)   (None, 128, 128, 128)     0
# _________________________________________________________________
# deconv13 (Conv2DTranspose)   (None, 128, 128, 128)     147584
# _________________________________________________________________
# bn26 (BatchNormalization)    (None, 128, 128, 128)     512
# _________________________________________________________________
# activation_25 (Activation)   (None, 128, 128, 128)     0
# _________________________________________________________________
# reshape (Reshape)            (None, 128, 128, 128)     0
# =================================================================
# Total params: 33,650,368
# Trainable params: 33,634,112
# Non-trainable params: 16,256
# _________________________________________________________________
# Epoch 1/100
# 84/84 [==============================] - 24s 64ms/step - loss: 0.4553 - iou: 0.9038 - dice_coef: 0.0157 - precision: 0.0743 - recall: 4.3522e-06 - accuracy: 0.9559 - val_loss: 0.6797 - val_iou: 0.9034 - val_dice_coef: 0.0121 - val_precision: 0.0145 - val_recall: 8.0524e-04 - val_accuracy: 0.9542
# Epoch 2/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4389 - iou: 0.9039 - dice_coef: 0.0195 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4231 - val_iou: 0.9060 - val_dice_coef: 0.0165 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 3/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4303 - iou: 0.9040 - dice_coef: 0.0212 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4062 - val_iou: 0.9061 - val_dice_coef: 0.0196 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 4/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4256 - iou: 0.9040 - dice_coef: 0.0224 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4000 - val_iou: 0.9062 - val_dice_coef: 0.0215 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 5/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4233 - iou: 0.9040 - dice_coef: 0.0231 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3952 - val_iou: 0.9062 - val_dice_coef: 0.0230 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 6/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4206 - iou: 0.9040 - dice_coef: 0.0237 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3947 - val_iou: 0.9062 - val_dice_coef: 0.0234 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 7/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4187 - iou: 0.9041 - dice_coef: 0.0241 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3942 - val_iou: 0.9063 - val_dice_coef: 0.0239 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 8/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4184 - iou: 0.9041 - dice_coef: 0.0246 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3943 - val_iou: 0.9063 - val_dice_coef: 0.0240 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 9/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4168 - iou: 0.9041 - dice_coef: 0.0245 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3949 - val_iou: 0.9063 - val_dice_coef: 0.0241 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 10/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4156 - iou: 0.9041 - dice_coef: 0.0251 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3945 - val_iou: 0.9063 - val_dice_coef: 0.0244 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 11/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4154 - iou: 0.9041 - dice_coef: 0.0253 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3976 - val_iou: 0.9063 - val_dice_coef: 0.0241 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 12/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4142 - iou: 0.9041 - dice_coef: 0.0253 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3945 - val_iou: 0.9063 - val_dice_coef: 0.0248 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 13/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4135 - iou: 0.9041 - dice_coef: 0.0257 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4060 - val_iou: 0.9062 - val_dice_coef: 0.0234 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 14/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4121 - iou: 0.9041 - dice_coef: 0.0260 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3981 - val_iou: 0.9063 - val_dice_coef: 0.0241 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 15/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4127 - iou: 0.9041 - dice_coef: 0.0260 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3963 - val_iou: 0.9063 - val_dice_coef: 0.0246 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 16/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4111 - iou: 0.9041 - dice_coef: 0.0262 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3960 - val_iou: 0.9063 - val_dice_coef: 0.0249 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 17/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4103 - iou: 0.9041 - dice_coef: 0.0268 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3947 - val_iou: 0.9063 - val_dice_coef: 0.0252 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 18/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4100 - iou: 0.9041 - dice_coef: 0.0267 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3953 - val_iou: 0.9063 - val_dice_coef: 0.0248 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 19/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4079 - iou: 0.9042 - dice_coef: 0.0275 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3998 - val_iou: 0.9063 - val_dice_coef: 0.0245 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 20/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4083 - iou: 0.9042 - dice_coef: 0.0270 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3972 - val_iou: 0.9063 - val_dice_coef: 0.0251 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 21/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4085 - iou: 0.9042 - dice_coef: 0.0272 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4041 - val_iou: 0.9063 - val_dice_coef: 0.0242 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 22/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4073 - iou: 0.9042 - dice_coef: 0.0275 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4008 - val_iou: 0.9063 - val_dice_coef: 0.0247 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 23/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4057 - iou: 0.9042 - dice_coef: 0.0278 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3957 - val_iou: 0.9063 - val_dice_coef: 0.0255 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 24/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4062 - iou: 0.9042 - dice_coef: 0.0279 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3953 - val_iou: 0.9063 - val_dice_coef: 0.0253 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 25/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4043 - iou: 0.9042 - dice_coef: 0.0283 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3978 - val_iou: 0.9063 - val_dice_coef: 0.0252 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 26/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4043 - iou: 0.9042 - dice_coef: 0.0284 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4001 - val_iou: 0.9063 - val_dice_coef: 0.0253 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 27/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4033 - iou: 0.9042 - dice_coef: 0.0286 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3907 - val_iou: 0.9064 - val_dice_coef: 0.0267 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 28/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4021 - iou: 0.9042 - dice_coef: 0.0290 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3986 - val_iou: 0.9063 - val_dice_coef: 0.0253 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 29/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4019 - iou: 0.9042 - dice_coef: 0.0291 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3962 - val_iou: 0.9063 - val_dice_coef: 0.0257 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 30/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4013 - iou: 0.9042 - dice_coef: 0.0292 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3963 - val_iou: 0.9063 - val_dice_coef: 0.0259 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 31/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4028 - iou: 0.9042 - dice_coef: 0.0290 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3953 - val_iou: 0.9063 - val_dice_coef: 0.0260 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 32/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4020 - iou: 0.9042 - dice_coef: 0.0291 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3990 - val_iou: 0.9063 - val_dice_coef: 0.0255 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 33/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4008 - iou: 0.9042 - dice_coef: 0.0291 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4044 - val_iou: 0.9063 - val_dice_coef: 0.0246 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 34/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.4004 - iou: 0.9042 - dice_coef: 0.0294 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3949 - val_iou: 0.9063 - val_dice_coef: 0.0261 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 35/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3995 - iou: 0.9042 - dice_coef: 0.0299 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3993 - val_iou: 0.9063 - val_dice_coef: 0.0256 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 36/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3986 - iou: 0.9043 - dice_coef: 0.0299 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4015 - val_iou: 0.9063 - val_dice_coef: 0.0253 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 37/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3980 - iou: 0.9043 - dice_coef: 0.0302 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4001 - val_iou: 0.9063 - val_dice_coef: 0.0255 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 38/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3971 - iou: 0.9043 - dice_coef: 0.0304 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3986 - val_iou: 0.9063 - val_dice_coef: 0.0261 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 39/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3979 - iou: 0.9043 - dice_coef: 0.0303 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3902 - val_iou: 0.9064 - val_dice_coef: 0.0272 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 40/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3967 - iou: 0.9043 - dice_coef: 0.0306 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3952 - val_iou: 0.9063 - val_dice_coef: 0.0265 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 41/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3972 - iou: 0.9043 - dice_coef: 0.0305 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4005 - val_iou: 0.9063 - val_dice_coef: 0.0254 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 42/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3960 - iou: 0.9043 - dice_coef: 0.0308 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3952 - val_iou: 0.9063 - val_dice_coef: 0.0268 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 43/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3960 - iou: 0.9043 - dice_coef: 0.0307 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3953 - val_iou: 0.9063 - val_dice_coef: 0.0265 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 44/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3964 - iou: 0.9043 - dice_coef: 0.0310 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3962 - val_iou: 0.9063 - val_dice_coef: 0.0265 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 45/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3958 - iou: 0.9043 - dice_coef: 0.0307 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3945 - val_iou: 0.9063 - val_dice_coef: 0.0265 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 46/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3954 - iou: 0.9043 - dice_coef: 0.0309 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3974 - val_iou: 0.9063 - val_dice_coef: 0.0261 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 47/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3949 - iou: 0.9043 - dice_coef: 0.0311 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3926 - val_iou: 0.9064 - val_dice_coef: 0.0272 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 48/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3948 - iou: 0.9043 - dice_coef: 0.0312 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3962 - val_iou: 0.9063 - val_dice_coef: 0.0264 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 49/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3945 - iou: 0.9043 - dice_coef: 0.0312 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3955 - val_iou: 0.9063 - val_dice_coef: 0.0265 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 50/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3952 - iou: 0.9043 - dice_coef: 0.0310 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3997 - val_iou: 0.9063 - val_dice_coef: 0.0257 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 51/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3935 - iou: 0.9043 - dice_coef: 0.0315 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4022 - val_iou: 0.9063 - val_dice_coef: 0.0254 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 52/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3925 - iou: 0.9043 - dice_coef: 0.0316 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4005 - val_iou: 0.9063 - val_dice_coef: 0.0258 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 53/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3938 - iou: 0.9043 - dice_coef: 0.0315 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3989 - val_iou: 0.9063 - val_dice_coef: 0.0262 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 54/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3924 - iou: 0.9043 - dice_coef: 0.0319 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3999 - val_iou: 0.9063 - val_dice_coef: 0.0260 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 55/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3925 - iou: 0.9043 - dice_coef: 0.0320 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4000 - val_iou: 0.9063 - val_dice_coef: 0.0263 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 56/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3924 - iou: 0.9043 - dice_coef: 0.0319 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3999 - val_iou: 0.9063 - val_dice_coef: 0.0262 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 57/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3927 - iou: 0.9043 - dice_coef: 0.0318 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4034 - val_iou: 0.9063 - val_dice_coef: 0.0255 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 58/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3918 - iou: 0.9043 - dice_coef: 0.0320 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4019 - val_iou: 0.9063 - val_dice_coef: 0.0258 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 59/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3923 - iou: 0.9043 - dice_coef: 0.0321 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4017 - val_iou: 0.9063 - val_dice_coef: 0.0259 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 60/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3914 - iou: 0.9043 - dice_coef: 0.0323 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3992 - val_iou: 0.9063 - val_dice_coef: 0.0262 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 61/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3916 - iou: 0.9043 - dice_coef: 0.0322 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3990 - val_iou: 0.9063 - val_dice_coef: 0.0261 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 62/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3909 - iou: 0.9043 - dice_coef: 0.0324 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4043 - val_iou: 0.9063 - val_dice_coef: 0.0253 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 63/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3909 - iou: 0.9043 - dice_coef: 0.0324 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4039 - val_iou: 0.9063 - val_dice_coef: 0.0255 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 64/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3910 - iou: 0.9043 - dice_coef: 0.0323 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4006 - val_iou: 0.9063 - val_dice_coef: 0.0260 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 65/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3903 - iou: 0.9043 - dice_coef: 0.0326 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4006 - val_iou: 0.9063 - val_dice_coef: 0.0257 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 66/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3905 - iou: 0.9043 - dice_coef: 0.0323 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3968 - val_iou: 0.9063 - val_dice_coef: 0.0265 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 67/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3902 - iou: 0.9043 - dice_coef: 0.0325 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4016 - val_iou: 0.9063 - val_dice_coef: 0.0256 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 68/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3900 - iou: 0.9044 - dice_coef: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3976 - val_iou: 0.9063 - val_dice_coef: 0.0264 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 69/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3897 - iou: 0.9044 - dice_coef: 0.0327 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4012 - val_iou: 0.9063 - val_dice_coef: 0.0259 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 70/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3900 - iou: 0.9044 - dice_coef: 0.0328 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3998 - val_iou: 0.9063 - val_dice_coef: 0.0261 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 71/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3890 - iou: 0.9044 - dice_coef: 0.0330 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4005 - val_iou: 0.9063 - val_dice_coef: 0.0263 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 72/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3886 - iou: 0.9044 - dice_coef: 0.0329 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3990 - val_iou: 0.9063 - val_dice_coef: 0.0262 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 73/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3887 - iou: 0.9044 - dice_coef: 0.0331 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3990 - val_iou: 0.9063 - val_dice_coef: 0.0263 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 74/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3889 - iou: 0.9044 - dice_coef: 0.0331 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3995 - val_iou: 0.9063 - val_dice_coef: 0.0262 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 75/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3892 - iou: 0.9044 - dice_coef: 0.0331 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3996 - val_iou: 0.9063 - val_dice_coef: 0.0261 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 76/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3889 - iou: 0.9044 - dice_coef: 0.0331 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4026 - val_iou: 0.9063 - val_dice_coef: 0.0255 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 77/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3899 - iou: 0.9044 - dice_coef: 0.0330 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4000 - val_iou: 0.9063 - val_dice_coef: 0.0261 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 78/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3885 - iou: 0.9044 - dice_coef: 0.0332 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4005 - val_iou: 0.9063 - val_dice_coef: 0.0262 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 79/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3885 - iou: 0.9044 - dice_coef: 0.0331 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3993 - val_iou: 0.9063 - val_dice_coef: 0.0262 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 80/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3890 - iou: 0.9044 - dice_coef: 0.0331 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4060 - val_iou: 0.9063 - val_dice_coef: 0.0253 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 81/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3877 - iou: 0.9044 - dice_coef: 0.0333 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3988 - val_iou: 0.9063 - val_dice_coef: 0.0264 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 82/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3882 - iou: 0.9044 - dice_coef: 0.0333 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3978 - val_iou: 0.9063 - val_dice_coef: 0.0267 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 83/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3885 - iou: 0.9044 - dice_coef: 0.0331 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4000 - val_iou: 0.9063 - val_dice_coef: 0.0266 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 84/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3878 - iou: 0.9044 - dice_coef: 0.0333 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4001 - val_iou: 0.9063 - val_dice_coef: 0.0262 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 85/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3868 - iou: 0.9044 - dice_coef: 0.0338 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3991 - val_iou: 0.9063 - val_dice_coef: 0.0263 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 86/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3873 - iou: 0.9044 - dice_coef: 0.0337 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4004 - val_iou: 0.9063 - val_dice_coef: 0.0259 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 87/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3873 - iou: 0.9044 - dice_coef: 0.0339 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4024 - val_iou: 0.9063 - val_dice_coef: 0.0256 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 88/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3869 - iou: 0.9044 - dice_coef: 0.0338 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4004 - val_iou: 0.9063 - val_dice_coef: 0.0264 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 89/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3872 - iou: 0.9044 - dice_coef: 0.0338 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4022 - val_iou: 0.9063 - val_dice_coef: 0.0259 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 90/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3869 - iou: 0.9044 - dice_coef: 0.0338 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3962 - val_iou: 0.9063 - val_dice_coef: 0.0268 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 91/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3870 - iou: 0.9044 - dice_coef: 0.0336 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4007 - val_iou: 0.9063 - val_dice_coef: 0.0260 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 92/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3866 - iou: 0.9044 - dice_coef: 0.0338 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4014 - val_iou: 0.9063 - val_dice_coef: 0.0259 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 93/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3868 - iou: 0.9044 - dice_coef: 0.0339 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3994 - val_iou: 0.9063 - val_dice_coef: 0.0263 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 94/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3862 - iou: 0.9044 - dice_coef: 0.0339 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4005 - val_iou: 0.9063 - val_dice_coef: 0.0261 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 95/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3860 - iou: 0.9044 - dice_coef: 0.0342 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4001 - val_iou: 0.9063 - val_dice_coef: 0.0261 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 96/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3859 - iou: 0.9044 - dice_coef: 0.0342 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3970 - val_iou: 0.9063 - val_dice_coef: 0.0267 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 97/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3865 - iou: 0.9044 - dice_coef: 0.0340 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3982 - val_iou: 0.9063 - val_dice_coef: 0.0265 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 98/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3857 - iou: 0.9044 - dice_coef: 0.0344 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4011 - val_iou: 0.9063 - val_dice_coef: 0.0261 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 99/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3856 - iou: 0.9044 - dice_coef: 0.0344 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.4022 - val_iou: 0.9063 - val_dice_coef: 0.0259 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
# Epoch 100/100
# 84/84 [==============================] - 4s 50ms/step - loss: 0.3853 - iou: 0.9044 - dice_coef: 0.0344 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 0.3984 - val_iou: 0.9063 - val_dice_coef: 0.0266 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9567
