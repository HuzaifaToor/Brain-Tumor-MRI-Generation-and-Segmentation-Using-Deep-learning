# %%
from keras.models import Model,Sequential
import numpy as  np
from keras.layers.core import Activation, Reshape, Permute
from keras.layers.convolutional import Convolution2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.layers import BatchNormalization
from keras.layers import Input, merge, Conv2D,Concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau, TensorBoard, Callback
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array, load_img, ImageDataGenerator
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras import backend as K
from tensorflow.python import keras
from sklearn.model_selection import train_test_split
from keras.models import Model, Sequential
from keras.layers import Activation, Dense, BatchNormalization, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from keras.callbacks import EarlyStopping
from keras import backend as K

import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
from keras.layers import Conv3D, MaxPooling3D, concatenate, UpSampling3D
# %matplotlib inline

# %%
from google.colab import drive
drive.mount("/content/drive") # Don't change this.
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
#     626         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-8315a535ce3d> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount("/content/drive") # Don't change this.
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     111       timeout_ms=timeout_ms,
#     112       use_metadata_server=use_metadata_server,
# --> 113       ephemeral=ephemeral)
#     114
#     115
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, use_metadata_server, ephemeral)
#     290       with _output.use_tags('dfs-auth-dance'):
#     291         with open(fifo, 'w') as fifo_file:
# --> 292           fifo_file.write(get_code(auth_prompt) + '\n')
#     293       wrote_to_fifo = True
#     294     elif case == 5:
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
imgarray=np.load('/content/drive/MyDrive/brain tumor segmentation/asad data/data/appended all/training/appended flair/flair.npy')
maskarray=np.load('/content/drive/MyDrive/brain tumor segmentation/asad data/data/appended all/training/appended masks/masks.npy')

# %%
imgarray.shape,maskarray.shape
# Out:
# ((195, 128, 128, 128), (195, 128, 128, 128))

# %%
imgarray = imgarray[:,:,:,0:16]
maskarray = maskarray[:,:,:,0:16]

# %%
imgarray = imgarray[:,:,:,0:16]
maskarray = maskarray[:,:,:,0:16]

# %%
x_train1,x_test,y_train1,y_test=train_test_split(imgarray, maskarray, test_size = 0.20, random_state = 101)

# %%
x_train1.shape,y_train1.shape
# Out:
# ((156, 128, 128, 128), (156, 128, 128, 128))

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train1, y_train1, test_size = 0.20, random_state = 101)

# %%
x_train.shape,x_val.shape
# Out:
# ((124, 128, 128, 128), (32, 128, 128, 128))

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

def dice_coef(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision
def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall
def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

def dice_coef(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision
def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall
def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %%
def segnet():#,savename):

    # Encoding layer
    img_input = Input(shape= (128,128,128))
    x = Conv2D(64, (3, 3), padding='same', name='conv1',strides= (1,1))(img_input)
    x = BatchNormalization(name='bn1')(x)
    x = Activation('relu')(x)
    x = Conv2D(64, (3, 3), padding='same', name='conv2')(x)
    x = BatchNormalization(name='bn2')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)
    
    x = Conv2D(128, (3, 3), padding='same', name='conv3')(x)
    x = BatchNormalization(name='bn3')(x)
    x = Activation('relu')(x)
    x = Conv2D(128, (3, 3), padding='same', name='conv4')(x)
    x = BatchNormalization(name='bn4')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Conv2D(256, (3, 3), padding='same', name='conv5')(x)
    x = BatchNormalization(name='bn5')(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same', name='conv6')(x)
    x = BatchNormalization(name='bn6')(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same', name='conv7')(x)
    x = BatchNormalization(name='bn7')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Conv2D(512, (3, 3), padding='same', name='conv8')(x)
    x = BatchNormalization(name='bn8')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv9')(x)
    x = BatchNormalization(name='bn9')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv10')(x)
    x = BatchNormalization(name='bn10')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)
    
    x = Conv2D(512, (3, 3), padding='same', name='conv11')(x)
    x = BatchNormalization(name='bn11')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv12')(x)
    x = BatchNormalization(name='bn12')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv13')(x)
    x = BatchNormalization(name='bn13')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Dense(1024, activation = 'relu', name='fc1')(x)
    x = Dense(1024, activation = 'relu', name='fc2')(x)
    # Decoding Layer 
    x = UpSampling2D()(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv1')(x)
    x = BatchNormalization(name='bn14')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv2')(x)
    x = BatchNormalization(name='bn15')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv3')(x)
    x = BatchNormalization(name='bn16')(x)
    x = Activation('relu')(x)
    
    x = UpSampling2D()(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv4')(x)
    x = BatchNormalization(name='bn17')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv5')(x)
    x = BatchNormalization(name='bn18')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv6')(x)
    x = BatchNormalization(name='bn19')(x)
    x = Activation('relu')(x)

    x = UpSampling2D()(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv7')(x)
    x = BatchNormalization(name='bn20')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv8')(x)
    x = BatchNormalization(name='bn21')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv9')(x)
    x = BatchNormalization(name='bn22')(x)
    x = Activation('relu')(x)

    x = UpSampling2D()(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv10')(x)
    x = BatchNormalization(name='bn23')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv11')(x)
    x = BatchNormalization(name='bn24')(x)
    x = Activation('relu')(x)
    
    x = UpSampling2D()(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv12')(x)
    x = BatchNormalization(name='bn25')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv13')(x)
    x = BatchNormalization(name='bn26')(x)
    x = Activation('sigmoid')(x)
    print("x.shape",x.shape)
    pred = Reshape((128,128,128))(x)
    
    model = Model(inputs=img_input, outputs=pred)
    
    model.compile(optimizer= SGD(learning_rate=0.001, momentum=0.9, decay=0.0005, nesterov=False), loss= ["binary_crossentropy"]
                  , metrics=[iou, dice_coef, precision, recall, accuracy])
    model.summary()
    #hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 18, validation_data= (x_val, y_val), verbose=1)
    
    #model.save(savename)
    return model#,hist

# %%
y_train.shape,x_train.shape
# Out:
# ((124, 128, 128, 128), (124, 128, 128, 128))

# %%
model = segnet()#'segnet_1_epoch.h5')
hist = model.fit(x_train, y_train, epochs= 100, batch_size= 18, validation_data= (x_val, y_val), verbose=1)
# Out:
# x.shape (None, 128, 128, 128)
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 128, 128, 128)]   0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 128, 128, 64)      73792
# _________________________________________________________________
# bn1 (BatchNormalization)     (None, 128, 128, 64)      256
# _________________________________________________________________
# activation_52 (Activation)   (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 128, 128, 64)      36928
# _________________________________________________________________
# bn2 (BatchNormalization)     (None, 128, 128, 64)      256
# _________________________________________________________________
# activation_53 (Activation)   (None, 128, 128, 64)      0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 64, 64, 64)        0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 64, 64, 128)       73856
# _________________________________________________________________
# bn3 (BatchNormalization)     (None, 64, 64, 128)       512
# _________________________________________________________________
# activation_54 (Activation)   (None, 64, 64, 128)       0
# _________________________________________________________________
# conv4 (Conv2D)               (None, 64, 64, 128)       147584
# _________________________________________________________________
# bn4 (BatchNormalization)     (None, 64, 64, 128)       512
# _________________________________________________________________
# activation_55 (Activation)   (None, 64, 64, 128)       0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 32, 32, 128)       0
# _________________________________________________________________
# conv5 (Conv2D)               (None, 32, 32, 256)       295168
# _________________________________________________________________
# bn5 (BatchNormalization)     (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_56 (Activation)   (None, 32, 32, 256)       0
# _________________________________________________________________
# conv6 (Conv2D)               (None, 32, 32, 256)       590080
# _________________________________________________________________
# bn6 (BatchNormalization)     (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_57 (Activation)   (None, 32, 32, 256)       0
# _________________________________________________________________
# conv7 (Conv2D)               (None, 32, 32, 256)       590080
# _________________________________________________________________
# bn7 (BatchNormalization)     (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_58 (Activation)   (None, 32, 32, 256)       0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 16, 16, 256)       0
# _________________________________________________________________
# conv8 (Conv2D)               (None, 16, 16, 512)       1180160
# _________________________________________________________________
# bn8 (BatchNormalization)     (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_59 (Activation)   (None, 16, 16, 512)       0
# _________________________________________________________________
# conv9 (Conv2D)               (None, 16, 16, 512)       2359808
# _________________________________________________________________
# bn9 (BatchNormalization)     (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_60 (Activation)   (None, 16, 16, 512)       0
# _________________________________________________________________
# conv10 (Conv2D)              (None, 16, 16, 512)       2359808
# _________________________________________________________________
# bn10 (BatchNormalization)    (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_61 (Activation)   (None, 16, 16, 512)       0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 8, 8, 512)         0
# _________________________________________________________________
# conv11 (Conv2D)              (None, 8, 8, 512)         2359808
# _________________________________________________________________
# bn11 (BatchNormalization)    (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_62 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# conv12 (Conv2D)              (None, 8, 8, 512)         2359808
# _________________________________________________________________
# bn12 (BatchNormalization)    (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_63 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# conv13 (Conv2D)              (None, 8, 8, 512)         2359808
# _________________________________________________________________
# bn13 (BatchNormalization)    (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_64 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 4, 4, 512)         0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4, 4, 1024)        525312
# _________________________________________________________________
# fc2 (Dense)                  (None, 4, 4, 1024)        1049600
# _________________________________________________________________
# up_sampling2d_10 (UpSampling (None, 8, 8, 1024)        0
# _________________________________________________________________
# deconv1 (Conv2DTranspose)    (None, 8, 8, 512)         4719104
# _________________________________________________________________
# bn14 (BatchNormalization)    (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_65 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# deconv2 (Conv2DTranspose)    (None, 8, 8, 512)         2359808
# _________________________________________________________________
# bn15 (BatchNormalization)    (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_66 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# deconv3 (Conv2DTranspose)    (None, 8, 8, 512)         2359808
# _________________________________________________________________
# bn16 (BatchNormalization)    (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_67 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# up_sampling2d_11 (UpSampling (None, 16, 16, 512)       0
# _________________________________________________________________
# deconv4 (Conv2DTranspose)    (None, 16, 16, 512)       2359808
# _________________________________________________________________
# bn17 (BatchNormalization)    (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_68 (Activation)   (None, 16, 16, 512)       0
# _________________________________________________________________
# deconv5 (Conv2DTranspose)    (None, 16, 16, 512)       2359808
# _________________________________________________________________
# bn18 (BatchNormalization)    (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_69 (Activation)   (None, 16, 16, 512)       0
# _________________________________________________________________
# deconv6 (Conv2DTranspose)    (None, 16, 16, 256)       1179904
# _________________________________________________________________
# bn19 (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# activation_70 (Activation)   (None, 16, 16, 256)       0
# _________________________________________________________________
# up_sampling2d_12 (UpSampling (None, 32, 32, 256)       0
# _________________________________________________________________
# deconv7 (Conv2DTranspose)    (None, 32, 32, 256)       590080
# _________________________________________________________________
# bn20 (BatchNormalization)    (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_71 (Activation)   (None, 32, 32, 256)       0
# _________________________________________________________________
# deconv8 (Conv2DTranspose)    (None, 32, 32, 256)       590080
# _________________________________________________________________
# bn21 (BatchNormalization)    (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_72 (Activation)   (None, 32, 32, 256)       0
# _________________________________________________________________
# deconv9 (Conv2DTranspose)    (None, 32, 32, 128)       295040
# _________________________________________________________________
# bn22 (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# activation_73 (Activation)   (None, 32, 32, 128)       0
# _________________________________________________________________
# up_sampling2d_13 (UpSampling (None, 64, 64, 128)       0
# _________________________________________________________________
# deconv10 (Conv2DTranspose)   (None, 64, 64, 128)       147584
# _________________________________________________________________
# bn23 (BatchNormalization)    (None, 64, 64, 128)       512
# _________________________________________________________________
# activation_74 (Activation)   (None, 64, 64, 128)       0
# _________________________________________________________________
# deconv11 (Conv2DTranspose)   (None, 64, 64, 64)        73792
# _________________________________________________________________
# bn24 (BatchNormalization)    (None, 64, 64, 64)        256
# _________________________________________________________________
# activation_75 (Activation)   (None, 64, 64, 64)        0
# _________________________________________________________________
# up_sampling2d_14 (UpSampling (None, 128, 128, 64)      0
# _________________________________________________________________
# deconv12 (Conv2DTranspose)   (None, 128, 128, 128)     73856
# _________________________________________________________________
# bn25 (BatchNormalization)    (None, 128, 128, 128)     512
# _________________________________________________________________
# activation_76 (Activation)   (None, 128, 128, 128)     0
# _________________________________________________________________
# deconv13 (Conv2DTranspose)   (None, 128, 128, 128)     147584
# _________________________________________________________________
# bn26 (BatchNormalization)    (None, 128, 128, 128)     512
# _________________________________________________________________
# activation_77 (Activation)   (None, 128, 128, 128)     0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 128, 128, 128)     0
# =================================================================
# Total params: 33,650,368
# Trainable params: 33,634,112
# Non-trainable params: 16,256
# _________________________________________________________________
# Epoch 1/100
# 7/7 [==============================] - 6s 445ms/step - loss: 0.8014 - iou: 0.6959 - dice_coef: 0.1667 - precision: 0.0785 - recall: 0.8132 - accuracy: 0.4801 - val_loss: 0.6928 - val_iou: 0.7187 - val_dice_coef: 0.1712 - val_precision: 0.0927 - val_recall: 0.9354 - val_accuracy: 0.4888
# Epoch 2/100
# 7/7 [==============================] - 2s 268ms/step - loss: 0.8002 - iou: 0.6963 - dice_coef: 0.1663 - precision: 0.0783 - recall: 0.8156 - accuracy: 0.4808 - val_loss: 0.6924 - val_iou: 0.7189 - val_dice_coef: 0.1712 - val_precision: 0.0946 - val_recall: 0.9327 - val_accuracy: 0.4993
# Epoch 3/100
# 7/7 [==============================] - 2s 263ms/step - loss: 0.7980 - iou: 0.6972 - dice_coef: 0.1677 - precision: 0.0791 - recall: 0.8201 - accuracy: 0.4820 - val_loss: 0.6920 - val_iou: 0.7190 - val_dice_coef: 0.1712 - val_precision: 0.0957 - val_recall: 0.9313 - val_accuracy: 0.5049
# Epoch 4/100
# 7/7 [==============================] - 2s 260ms/step - loss: 0.7948 - iou: 0.6984 - dice_coef: 0.1681 - precision: 0.0793 - recall: 0.8210 - accuracy: 0.4837 - val_loss: 0.6916 - val_iou: 0.7192 - val_dice_coef: 0.1712 - val_precision: 0.0962 - val_recall: 0.9311 - val_accuracy: 0.5075
# Epoch 5/100
# 7/7 [==============================] - 2s 268ms/step - loss: 0.7909 - iou: 0.6997 - dice_coef: 0.1694 - precision: 0.0802 - recall: 0.8264 - accuracy: 0.4858 - val_loss: 0.6911 - val_iou: 0.7194 - val_dice_coef: 0.1711 - val_precision: 0.0970 - val_recall: 0.9308 - val_accuracy: 0.5114
# Epoch 6/100
# 7/7 [==============================] - 2s 264ms/step - loss: 0.7873 - iou: 0.7010 - dice_coef: 0.1709 - precision: 0.0810 - recall: 0.8285 - accuracy: 0.4879 - val_loss: 0.6906 - val_iou: 0.7196 - val_dice_coef: 0.1711 - val_precision: 0.0980 - val_recall: 0.9301 - val_accuracy: 0.5161
# Epoch 7/100
# 7/7 [==============================] - 2s 269ms/step - loss: 0.7827 - iou: 0.7027 - dice_coef: 0.1718 - precision: 0.0819 - recall: 0.8338 - accuracy: 0.4910 - val_loss: 0.6900 - val_iou: 0.7198 - val_dice_coef: 0.1710 - val_precision: 0.0995 - val_recall: 0.9292 - val_accuracy: 0.5231
# Epoch 8/100
# 7/7 [==============================] - 2s 260ms/step - loss: 0.7776 - iou: 0.7047 - dice_coef: 0.1725 - precision: 0.0834 - recall: 0.8431 - accuracy: 0.4946 - val_loss: 0.6894 - val_iou: 0.7201 - val_dice_coef: 0.1709 - val_precision: 0.1000 - val_recall: 0.9288 - val_accuracy: 0.5256
# Epoch 9/100
# 7/7 [==============================] - 2s 263ms/step - loss: 0.7725 - iou: 0.7061 - dice_coef: 0.1730 - precision: 0.0832 - recall: 0.8407 - accuracy: 0.4977 - val_loss: 0.6887 - val_iou: 0.7204 - val_dice_coef: 0.1708 - val_precision: 0.1002 - val_recall: 0.9289 - val_accuracy: 0.5265
# Epoch 10/100
# 7/7 [==============================] - 2s 266ms/step - loss: 0.7679 - iou: 0.7077 - dice_coef: 0.1743 - precision: 0.0848 - recall: 0.8492 - accuracy: 0.5016 - val_loss: 0.6879 - val_iou: 0.7207 - val_dice_coef: 0.1707 - val_precision: 0.1007 - val_recall: 0.9287 - val_accuracy: 0.5284
# Epoch 11/100
# 7/7 [==============================] - 2s 263ms/step - loss: 0.7611 - iou: 0.7097 - dice_coef: 0.1761 - precision: 0.0866 - recall: 0.8545 - accuracy: 0.5059 - val_loss: 0.6871 - val_iou: 0.7210 - val_dice_coef: 0.1706 - val_precision: 0.1013 - val_recall: 0.9283 - val_accuracy: 0.5314
# Epoch 12/100
# 7/7 [==============================] - 2s 271ms/step - loss: 0.7571 - iou: 0.7110 - dice_coef: 0.1770 - precision: 0.0879 - recall: 0.8608 - accuracy: 0.5103 - val_loss: 0.6862 - val_iou: 0.7214 - val_dice_coef: 0.1705 - val_precision: 0.1021 - val_recall: 0.9277 - val_accuracy: 0.5351
# Epoch 13/100
# 7/7 [==============================] - 2s 264ms/step - loss: 0.7487 - iou: 0.7129 - dice_coef: 0.1772 - precision: 0.0890 - recall: 0.8669 - accuracy: 0.5148 - val_loss: 0.6853 - val_iou: 0.7217 - val_dice_coef: 0.1704 - val_precision: 0.1033 - val_recall: 0.9269 - val_accuracy: 0.5400
# Epoch 14/100
# 7/7 [==============================] - 2s 270ms/step - loss: 0.7400 - iou: 0.7150 - dice_coef: 0.1801 - precision: 0.0906 - recall: 0.8701 - accuracy: 0.5205 - val_loss: 0.6844 - val_iou: 0.7221 - val_dice_coef: 0.1702 - val_precision: 0.1047 - val_recall: 0.9259 - val_accuracy: 0.5461
# Epoch 15/100
# 7/7 [==============================] - 2s 271ms/step - loss: 0.7356 - iou: 0.7164 - dice_coef: 0.1813 - precision: 0.0921 - recall: 0.8752 - accuracy: 0.5260 - val_loss: 0.6834 - val_iou: 0.7225 - val_dice_coef: 0.1701 - val_precision: 0.1064 - val_recall: 0.9248 - val_accuracy: 0.5530
# Epoch 16/100
# 7/7 [==============================] - 2s 266ms/step - loss: 0.7297 - iou: 0.7175 - dice_coef: 0.1844 - precision: 0.0935 - recall: 0.8773 - accuracy: 0.5318 - val_loss: 0.6824 - val_iou: 0.7229 - val_dice_coef: 0.1699 - val_precision: 0.1084 - val_recall: 0.9233 - val_accuracy: 0.5609
# Epoch 17/100
# 7/7 [==============================] - 2s 269ms/step - loss: 0.7224 - iou: 0.7191 - dice_coef: 0.1856 - precision: 0.0953 - recall: 0.8818 - accuracy: 0.5367 - val_loss: 0.6814 - val_iou: 0.7234 - val_dice_coef: 0.1697 - val_precision: 0.1105 - val_recall: 0.9215 - val_accuracy: 0.5690
# Epoch 18/100
# 7/7 [==============================] - 2s 270ms/step - loss: 0.7173 - iou: 0.7207 - dice_coef: 0.1865 - precision: 0.0969 - recall: 0.8883 - accuracy: 0.5432 - val_loss: 0.6803 - val_iou: 0.7238 - val_dice_coef: 0.1695 - val_precision: 0.1128 - val_recall: 0.9198 - val_accuracy: 0.5771
# Epoch 19/100
# 7/7 [==============================] - 2s 268ms/step - loss: 0.7077 - iou: 0.7224 - dice_coef: 0.1910 - precision: 0.0987 - recall: 0.8896 - accuracy: 0.5499 - val_loss: 0.6792 - val_iou: 0.7243 - val_dice_coef: 0.1693 - val_precision: 0.1152 - val_recall: 0.9179 - val_accuracy: 0.5856
# Epoch 20/100
# 7/7 [==============================] - 2s 266ms/step - loss: 0.7014 - iou: 0.7236 - dice_coef: 0.1923 - precision: 0.1002 - recall: 0.8915 - accuracy: 0.5554 - val_loss: 0.6780 - val_iou: 0.7248 - val_dice_coef: 0.1691 - val_precision: 0.1177 - val_recall: 0.9161 - val_accuracy: 0.5939
# Epoch 21/100
# 7/7 [==============================] - 2s 264ms/step - loss: 0.6947 - iou: 0.7248 - dice_coef: 0.1938 - precision: 0.1023 - recall: 0.8962 - accuracy: 0.5623 - val_loss: 0.6768 - val_iou: 0.7252 - val_dice_coef: 0.1689 - val_precision: 0.1202 - val_recall: 0.9145 - val_accuracy: 0.6015
# Epoch 22/100
# 7/7 [==============================] - 2s 265ms/step - loss: 0.6865 - iou: 0.7264 - dice_coef: 0.1965 - precision: 0.1047 - recall: 0.8998 - accuracy: 0.5695 - val_loss: 0.6755 - val_iou: 0.7258 - val_dice_coef: 0.1687 - val_precision: 0.1226 - val_recall: 0.9128 - val_accuracy: 0.6088
# Epoch 23/100
# 7/7 [==============================] - 2s 262ms/step - loss: 0.6775 - iou: 0.7279 - dice_coef: 0.1985 - precision: 0.1066 - recall: 0.9046 - accuracy: 0.5762 - val_loss: 0.6743 - val_iou: 0.7262 - val_dice_coef: 0.1684 - val_precision: 0.1249 - val_recall: 0.9112 - val_accuracy: 0.6156
# Epoch 24/100
# 7/7 [==============================] - 2s 266ms/step - loss: 0.6729 - iou: 0.7291 - dice_coef: 0.2025 - precision: 0.1082 - recall: 0.9060 - accuracy: 0.5823 - val_loss: 0.6730 - val_iou: 0.7268 - val_dice_coef: 0.1682 - val_precision: 0.1274 - val_recall: 0.9094 - val_accuracy: 0.6225
# Epoch 25/100
# 7/7 [==============================] - 2s 267ms/step - loss: 0.6667 - iou: 0.7306 - dice_coef: 0.2044 - precision: 0.1114 - recall: 0.9119 - accuracy: 0.5908 - val_loss: 0.6716 - val_iou: 0.7274 - val_dice_coef: 0.1679 - val_precision: 0.1301 - val_recall: 0.9076 - val_accuracy: 0.6298
# Epoch 26/100
# 7/7 [==============================] - 2s 268ms/step - loss: 0.6578 - iou: 0.7321 - dice_coef: 0.2074 - precision: 0.1130 - recall: 0.9172 - accuracy: 0.5970 - val_loss: 0.6702 - val_iou: 0.7279 - val_dice_coef: 0.1676 - val_precision: 0.1330 - val_recall: 0.9058 - val_accuracy: 0.6369
# Epoch 27/100
# 7/7 [==============================] - 2s 268ms/step - loss: 0.6512 - iou: 0.7336 - dice_coef: 0.2114 - precision: 0.1153 - recall: 0.9190 - accuracy: 0.6044 - val_loss: 0.6687 - val_iou: 0.7285 - val_dice_coef: 0.1673 - val_precision: 0.1361 - val_recall: 0.9038 - val_accuracy: 0.6444
# Epoch 28/100
# 7/7 [==============================] - 2s 264ms/step - loss: 0.6460 - iou: 0.7345 - dice_coef: 0.2132 - precision: 0.1181 - recall: 0.9195 - accuracy: 0.6114 - val_loss: 0.6673 - val_iou: 0.7291 - val_dice_coef: 0.1671 - val_precision: 0.1394 - val_recall: 0.9017 - val_accuracy: 0.6518
# Epoch 29/100
# 7/7 [==============================] - 2s 265ms/step - loss: 0.6411 - iou: 0.7356 - dice_coef: 0.2153 - precision: 0.1202 - recall: 0.9244 - accuracy: 0.6174 - val_loss: 0.6658 - val_iou: 0.7297 - val_dice_coef: 0.1667 - val_precision: 0.1427 - val_recall: 0.8995 - val_accuracy: 0.6590
# Epoch 30/100
# 7/7 [==============================] - 2s 266ms/step - loss: 0.6340 - iou: 0.7371 - dice_coef: 0.2191 - precision: 0.1226 - recall: 0.9296 - accuracy: 0.6247 - val_loss: 0.6642 - val_iou: 0.7304 - val_dice_coef: 0.1664 - val_precision: 0.1462 - val_recall: 0.8974 - val_accuracy: 0.6662
# Epoch 31/100
# 7/7 [==============================] - 2s 261ms/step - loss: 0.6319 - iou: 0.7380 - dice_coef: 0.2217 - precision: 0.1247 - recall: 0.9292 - accuracy: 0.6291 - val_loss: 0.6624 - val_iou: 0.7311 - val_dice_coef: 0.1661 - val_precision: 0.1499 - val_recall: 0.8953 - val_accuracy: 0.6735
# Epoch 32/100
# 7/7 [==============================] - 2s 268ms/step - loss: 0.6215 - iou: 0.7397 - dice_coef: 0.2265 - precision: 0.1275 - recall: 0.9341 - accuracy: 0.6373 - val_loss: 0.6607 - val_iou: 0.7318 - val_dice_coef: 0.1659 - val_precision: 0.1538 - val_recall: 0.8936 - val_accuracy: 0.6806
# Epoch 33/100
# 7/7 [==============================] - 2s 262ms/step - loss: 0.6166 - iou: 0.7411 - dice_coef: 0.2282 - precision: 0.1305 - recall: 0.9350 - accuracy: 0.6459 - val_loss: 0.6589 - val_iou: 0.7325 - val_dice_coef: 0.1656 - val_precision: 0.1578 - val_recall: 0.8917 - val_accuracy: 0.6876
# Epoch 34/100
# 7/7 [==============================] - 2s 265ms/step - loss: 0.6117 - iou: 0.7421 - dice_coef: 0.2321 - precision: 0.1325 - recall: 0.9391 - accuracy: 0.6506 - val_loss: 0.6571 - val_iou: 0.7333 - val_dice_coef: 0.1653 - val_precision: 0.1618 - val_recall: 0.8901 - val_accuracy: 0.6942
# Epoch 35/100
# 7/7 [==============================] - 2s 268ms/step - loss: 0.6084 - iou: 0.7430 - dice_coef: 0.2354 - precision: 0.1351 - recall: 0.9401 - accuracy: 0.6545 - val_loss: 0.6553 - val_iou: 0.7340 - val_dice_coef: 0.1649 - val_precision: 0.1659 - val_recall: 0.8881 - val_accuracy: 0.7008
# Epoch 36/100
# 7/7 [==============================] - 2s 267ms/step - loss: 0.6015 - iou: 0.7443 - dice_coef: 0.2372 - precision: 0.1383 - recall: 0.9421 - accuracy: 0.6639 - val_loss: 0.6537 - val_iou: 0.7347 - val_dice_coef: 0.1647 - val_precision: 0.1698 - val_recall: 0.8871 - val_accuracy: 0.7064
# Epoch 37/100
# 7/7 [==============================] - 2s 268ms/step - loss: 0.5959 - iou: 0.7455 - dice_coef: 0.2397 - precision: 0.1419 - recall: 0.9473 - accuracy: 0.6704 - val_loss: 0.6521 - val_iou: 0.7353 - val_dice_coef: 0.1644 - val_precision: 0.1739 - val_recall: 0.8856 - val_accuracy: 0.7123
# Epoch 38/100
# 7/7 [==============================] - 2s 271ms/step - loss: 0.5925 - iou: 0.7460 - dice_coef: 0.2406 - precision: 0.1432 - recall: 0.9466 - accuracy: 0.6744 - val_loss: 0.6506 - val_iou: 0.7360 - val_dice_coef: 0.1642 - val_precision: 0.1778 - val_recall: 0.8846 - val_accuracy: 0.7175
# Epoch 39/100
# 7/7 [==============================] - 2s 263ms/step - loss: 0.5881 - iou: 0.7471 - dice_coef: 0.2435 - precision: 0.1464 - recall: 0.9496 - accuracy: 0.6813 - val_loss: 0.6491 - val_iou: 0.7366 - val_dice_coef: 0.1639 - val_precision: 0.1822 - val_recall: 0.8833 - val_accuracy: 0.7232
# Epoch 40/100
# 7/7 [==============================] - 2s 263ms/step - loss: 0.5826 - iou: 0.7483 - dice_coef: 0.2467 - precision: 0.1505 - recall: 0.9543 - accuracy: 0.6877 - val_loss: 0.6477 - val_iou: 0.7372 - val_dice_coef: 0.1637 - val_precision: 0.1864 - val_recall: 0.8820 - val_accuracy: 0.7284
# Epoch 41/100
# 7/7 [==============================] - 2s 277ms/step - loss: 0.5796 - iou: 0.7486 - dice_coef: 0.2468 - precision: 0.1520 - recall: 0.9539 - accuracy: 0.6919 - val_loss: 0.6463 - val_iou: 0.7377 - val_dice_coef: 0.1635 - val_precision: 0.1910 - val_recall: 0.8809 - val_accuracy: 0.7338
# Epoch 42/100
# 7/7 [==============================] - 2s 264ms/step - loss: 0.5780 - iou: 0.7493 - dice_coef: 0.2477 - precision: 0.1548 - recall: 0.9559 - accuracy: 0.6965 - val_loss: 0.6450 - val_iou: 0.7383 - val_dice_coef: 0.1633 - val_precision: 0.1953 - val_recall: 0.8797 - val_accuracy: 0.7387
# Epoch 43/100
# 7/7 [==============================] - 2s 261ms/step - loss: 0.5744 - iou: 0.7503 - dice_coef: 0.2498 - precision: 0.1563 - recall: 0.9560 - accuracy: 0.7002 - val_loss: 0.6437 - val_iou: 0.7388 - val_dice_coef: 0.1632 - val_precision: 0.1997 - val_recall: 0.8789 - val_accuracy: 0.7432
# Epoch 44/100
# 7/7 [==============================] - 2s 267ms/step - loss: 0.5697 - iou: 0.7510 - dice_coef: 0.2529 - precision: 0.1600 - recall: 0.9567 - accuracy: 0.7050 - val_loss: 0.6424 - val_iou: 0.7393 - val_dice_coef: 0.1630 - val_precision: 0.2040 - val_recall: 0.8779 - val_accuracy: 0.7477
# Epoch 45/100
# 7/7 [==============================] - 2s 266ms/step - loss: 0.5676 - iou: 0.7515 - dice_coef: 0.2533 - precision: 0.1615 - recall: 0.9592 - accuracy: 0.7092 - val_loss: 0.6412 - val_iou: 0.7398 - val_dice_coef: 0.1630 - val_precision: 0.2078 - val_recall: 0.8769 - val_accuracy: 0.7514
# Epoch 46/100
# 7/7 [==============================] - 2s 268ms/step - loss: 0.5641 - iou: 0.7519 - dice_coef: 0.2535 - precision: 0.1635 - recall: 0.9604 - accuracy: 0.7135 - val_loss: 0.6400 - val_iou: 0.7403 - val_dice_coef: 0.1631 - val_precision: 0.2115 - val_recall: 0.8760 - val_accuracy: 0.7551
# Epoch 47/100
# 7/7 [==============================] - 2s 271ms/step - loss: 0.5654 - iou: 0.7520 - dice_coef: 0.2539 - precision: 0.1634 - recall: 0.9587 - accuracy: 0.7128 - val_loss: 0.6386 - val_iou: 0.7408 - val_dice_coef: 0.1635 - val_precision: 0.2146 - val_recall: 0.8759 - val_accuracy: 0.7583
# Epoch 48/100
# 7/7 [==============================] - 2s 267ms/step - loss: 0.5622 - iou: 0.7528 - dice_coef: 0.2556 - precision: 0.1669 - recall: 0.9608 - accuracy: 0.7182 - val_loss: 0.6375 - val_iou: 0.7412 - val_dice_coef: 0.1636 - val_precision: 0.2185 - val_recall: 0.8754 - val_accuracy: 0.7619
# Epoch 49/100
# 7/7 [==============================] - 2s 271ms/step - loss: 0.5598 - iou: 0.7532 - dice_coef: 0.2567 - precision: 0.1682 - recall: 0.9617 - accuracy: 0.7199 - val_loss: 0.6363 - val_iou: 0.7416 - val_dice_coef: 0.1641 - val_precision: 0.2212 - val_recall: 0.8747 - val_accuracy: 0.7645
# Epoch 50/100
# 7/7 [==============================] - 2s 267ms/step - loss: 0.5564 - iou: 0.7538 - dice_coef: 0.2586 - precision: 0.1691 - recall: 0.9647 - accuracy: 0.7217 - val_loss: 0.6351 - val_iou: 0.7421 - val_dice_coef: 0.1644 - val_precision: 0.2240 - val_recall: 0.8747 - val_accuracy: 0.7671
# Epoch 51/100
# 7/7 [==============================] - 2s 265ms/step - loss: 0.5554 - iou: 0.7541 - dice_coef: 0.2580 - precision: 0.1708 - recall: 0.9648 - accuracy: 0.7251 - val_loss: 0.6329 - val_iou: 0.7426 - val_dice_coef: 0.1666 - val_precision: 0.2241 - val_recall: 0.8766 - val_accuracy: 0.7681
# Epoch 52/100
# 7/7 [==============================] - 2s 269ms/step - loss: 0.5511 - iou: 0.7548 - dice_coef: 0.2613 - precision: 0.1730 - recall: 0.9639 - accuracy: 0.7284 - val_loss: 0.6301 - val_iou: 0.7433 - val_dice_coef: 0.1696 - val_precision: 0.2237 - val_recall: 0.8793 - val_accuracy: 0.7687
# Epoch 53/100
# 7/7 [==============================] - 2s 267ms/step - loss: 0.5514 - iou: 0.7549 - dice_coef: 0.2618 - precision: 0.1743 - recall: 0.9660 - accuracy: 0.7281 - val_loss: 0.6276 - val_iou: 0.7439 - val_dice_coef: 0.1719 - val_precision: 0.2244 - val_recall: 0.8814 - val_accuracy: 0.7700
# Epoch 54/100
# 7/7 [==============================] - 2s 268ms/step - loss: 0.5476 - iou: 0.7556 - dice_coef: 0.2630 - precision: 0.1765 - recall: 0.9660 - accuracy: 0.7340 - val_loss: 0.6263 - val_iou: 0.7443 - val_dice_coef: 0.1727 - val_precision: 0.2269 - val_recall: 0.8822 - val_accuracy: 0.7722
# Epoch 55/100
# 7/7 [==============================] - 2s 268ms/step - loss: 0.5500 - iou: 0.7554 - dice_coef: 0.2614 - precision: 0.1762 - recall: 0.9662 - accuracy: 0.7331 - val_loss: 0.6226 - val_iou: 0.7449 - val_dice_coef: 0.1776 - val_precision: 0.2238 - val_recall: 0.8903 - val_accuracy: 0.7707
# Epoch 56/100
# 7/7 [==============================] - 2s 269ms/step - loss: 0.5456 - iou: 0.7560 - dice_coef: 0.2645 - precision: 0.1787 - recall: 0.9674 - accuracy: 0.7361 - val_loss: 0.6200 - val_iou: 0.7454 - val_dice_coef: 0.1810 - val_precision: 0.2222 - val_recall: 0.8955 - val_accuracy: 0.7702
# Epoch 57/100
# 7/7 [==============================] - 2s 263ms/step - loss: 0.5425 - iou: 0.7564 - dice_coef: 0.2653 - precision: 0.1804 - recall: 0.9677 - accuracy: 0.7394 - val_loss: 0.6177 - val_iou: 0.7459 - val_dice_coef: 0.1823 - val_precision: 0.2253 - val_recall: 0.8969 - val_accuracy: 0.7729
# Epoch 58/100
# 7/7 [==============================] - 2s 277ms/step - loss: 0.5440 - iou: 0.7564 - dice_coef: 0.2653 - precision: 0.1798 - recall: 0.9694 - accuracy: 0.7377 - val_loss: 0.6150 - val_iou: 0.7464 - val_dice_coef: 0.1849 - val_precision: 0.2253 - val_recall: 0.9005 - val_accuracy: 0.7733
# Epoch 59/100
# 7/7 [==============================] - 2s 265ms/step - loss: 0.5422 - iou: 0.7564 - dice_coef: 0.2645 - precision: 0.1807 - recall: 0.9689 - accuracy: 0.7398 - val_loss: 0.6115 - val_iou: 0.7469 - val_dice_coef: 0.1896 - val_precision: 0.2217 - val_recall: 0.9037 - val_accuracy: 0.7713
# Epoch 60/100
# 7/7 [==============================] - 2s 270ms/step - loss: 0.5388 - iou: 0.7572 - dice_coef: 0.2669 - precision: 0.1838 - recall: 0.9695 - accuracy: 0.7444 - val_loss: 0.6072 - val_iou: 0.7475 - val_dice_coef: 0.1958 - val_precision: 0.2174 - val_recall: 0.9128 - val_accuracy: 0.7682
# Epoch 61/100
# 7/7 [==============================] - 2s 262ms/step - loss: 0.5396 - iou: 0.7576 - dice_coef: 0.2676 - precision: 0.1831 - recall: 0.9727 - accuracy: 0.7434 - val_loss: 0.6082 - val_iou: 0.7476 - val_dice_coef: 0.1937 - val_precision: 0.2208 - val_recall: 0.9121 - val_accuracy: 0.7710
# Epoch 62/100
# 7/7 [==============================] - 2s 270ms/step - loss: 0.5367 - iou: 0.7580 - dice_coef: 0.2676 - precision: 0.1849 - recall: 0.9721 - accuracy: 0.7471 - val_loss: 0.6056 - val_iou: 0.7481 - val_dice_coef: 0.1970 - val_precision: 0.2200 - val_recall: 0.9141 - val_accuracy: 0.7709
# Epoch 63/100
# 7/7 [==============================] - 2s 269ms/step - loss: 0.5373 - iou: 0.7581 - dice_coef: 0.2695 - precision: 0.1864 - recall: 0.9723 - accuracy: 0.7472 - val_loss: 0.6011 - val_iou: 0.7487 - val_dice_coef: 0.2022 - val_precision: 0.2172 - val_recall: 0.9184 - val_accuracy: 0.7691
# Epoch 64/100
# 7/7 [==============================] - 2s 272ms/step - loss: 0.5349 - iou: 0.7585 - dice_coef: 0.2698 - precision: 0.1870 - recall: 0.9735 - accuracy: 0.7490 - val_loss: 0.5994 - val_iou: 0.7490 - val_dice_coef: 0.2035 - val_precision: 0.2185 - val_recall: 0.9198 - val_accuracy: 0.7704
# Epoch 65/100
# 7/7 [==============================] - 2s 265ms/step - loss: 0.5326 - iou: 0.7586 - dice_coef: 0.2706 - precision: 0.1871 - recall: 0.9740 - accuracy: 0.7488 - val_loss: 0.5999 - val_iou: 0.7490 - val_dice_coef: 0.2021 - val_precision: 0.2204 - val_recall: 0.9176 - val_accuracy: 0.7723
# Epoch 66/100
# 7/7 [==============================] - 2s 265ms/step - loss: 0.5361 - iou: 0.7584 - dice_coef: 0.2682 - precision: 0.1856 - recall: 0.9734 - accuracy: 0.7473 - val_loss: 0.5984 - val_iou: 0.7492 - val_dice_coef: 0.2040 - val_precision: 0.2178 - val_recall: 0.9218 - val_accuracy: 0.7701
# Epoch 67/100
# 7/7 [==============================] - 2s 261ms/step - loss: 0.5355 - iou: 0.7583 - dice_coef: 0.2683 - precision: 0.1872 - recall: 0.9746 - accuracy: 0.7492 - val_loss: 0.5988 - val_iou: 0.7493 - val_dice_coef: 0.2033 - val_precision: 0.2200 - val_recall: 0.9220 - val_accuracy: 0.7721
# Epoch 68/100
# 7/7 [==============================] - 2s 266ms/step - loss: 0.5298 - iou: 0.7595 - dice_coef: 0.2727 - precision: 0.1913 - recall: 0.9766 - accuracy: 0.7543 - val_loss: 0.5965 - val_iou: 0.7495 - val_dice_coef: 0.2062 - val_precision: 0.2175 - val_recall: 0.9237 - val_accuracy: 0.7703
# Epoch 69/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.5303 - iou: 0.7596 - dice_coef: 0.2735 - precision: 0.1900 - recall: 0.9763 - accuracy: 0.7529 - val_loss: 0.5947 - val_iou: 0.7498 - val_dice_coef: 0.2085 - val_precision: 0.2158 - val_recall: 0.9279 - val_accuracy: 0.7690
# Epoch 70/100
# 7/7 [==============================] - 2s 268ms/step - loss: 0.5251 - iou: 0.7602 - dice_coef: 0.2755 - precision: 0.1922 - recall: 0.9799 - accuracy: 0.7549 - val_loss: 0.5939 - val_iou: 0.7501 - val_dice_coef: 0.2089 - val_precision: 0.2181 - val_recall: 0.9301 - val_accuracy: 0.7709
# Epoch 71/100
# 7/7 [==============================] - 2s 270ms/step - loss: 0.5296 - iou: 0.7597 - dice_coef: 0.2729 - precision: 0.1896 - recall: 0.9776 - accuracy: 0.7526 - val_loss: 0.5918 - val_iou: 0.7503 - val_dice_coef: 0.2108 - val_precision: 0.2187 - val_recall: 0.9324 - val_accuracy: 0.7715
# Epoch 72/100
# 7/7 [==============================] - 2s 273ms/step - loss: 0.5281 - iou: 0.7600 - dice_coef: 0.2740 - precision: 0.1915 - recall: 0.9789 - accuracy: 0.7549 - val_loss: 0.5904 - val_iou: 0.7503 - val_dice_coef: 0.2134 - val_precision: 0.2140 - val_recall: 0.9338 - val_accuracy: 0.7675
# Epoch 73/100
# 7/7 [==============================] - 2s 265ms/step - loss: 0.5275 - iou: 0.7603 - dice_coef: 0.2747 - precision: 0.1919 - recall: 0.9774 - accuracy: 0.7557 - val_loss: 0.5902 - val_iou: 0.7503 - val_dice_coef: 0.2158 - val_precision: 0.2122 - val_recall: 0.9368 - val_accuracy: 0.7658
# Epoch 74/100
# 7/7 [==============================] - 2s 267ms/step - loss: 0.5242 - iou: 0.7608 - dice_coef: 0.2772 - precision: 0.1947 - recall: 0.9785 - accuracy: 0.7582 - val_loss: 0.5910 - val_iou: 0.7506 - val_dice_coef: 0.2139 - val_precision: 0.2176 - val_recall: 0.9400 - val_accuracy: 0.7703
# Epoch 75/100
# 7/7 [==============================] - 2s 270ms/step - loss: 0.5253 - iou: 0.7605 - dice_coef: 0.2754 - precision: 0.1940 - recall: 0.9795 - accuracy: 0.7578 - val_loss: 0.5897 - val_iou: 0.7510 - val_dice_coef: 0.2134 - val_precision: 0.2205 - val_recall: 0.9406 - val_accuracy: 0.7731
# Epoch 76/100
# 7/7 [==============================] - 2s 265ms/step - loss: 0.5212 - iou: 0.7612 - dice_coef: 0.2774 - precision: 0.1958 - recall: 0.9814 - accuracy: 0.7602 - val_loss: 0.5870 - val_iou: 0.7512 - val_dice_coef: 0.2177 - val_precision: 0.2170 - val_recall: 0.9459 - val_accuracy: 0.7702
# Epoch 77/100
# 7/7 [==============================] - 2s 267ms/step - loss: 0.5245 - iou: 0.7607 - dice_coef: 0.2761 - precision: 0.1954 - recall: 0.9795 - accuracy: 0.7596 - val_loss: 0.5853 - val_iou: 0.7513 - val_dice_coef: 0.2204 - val_precision: 0.2140 - val_recall: 0.9481 - val_accuracy: 0.7675
# Epoch 78/100
# 7/7 [==============================] - 2s 266ms/step - loss: 0.5194 - iou: 0.7616 - dice_coef: 0.2779 - precision: 0.1964 - recall: 0.9799 - accuracy: 0.7614 - val_loss: 0.5874 - val_iou: 0.7509 - val_dice_coef: 0.2199 - val_precision: 0.2091 - val_recall: 0.9446 - val_accuracy: 0.7635
# Epoch 79/100
# 7/7 [==============================] - 2s 265ms/step - loss: 0.5178 - iou: 0.7620 - dice_coef: 0.2793 - precision: 0.1962 - recall: 0.9816 - accuracy: 0.7613 - val_loss: 0.5871 - val_iou: 0.7510 - val_dice_coef: 0.2187 - val_precision: 0.2110 - val_recall: 0.9404 - val_accuracy: 0.7656
# Epoch 80/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.5184 - iou: 0.7618 - dice_coef: 0.2788 - precision: 0.1975 - recall: 0.9806 - accuracy: 0.7630 - val_loss: 0.5846 - val_iou: 0.7514 - val_dice_coef: 0.2209 - val_precision: 0.2128 - val_recall: 0.9441 - val_accuracy: 0.7671
# Epoch 81/100
# 7/7 [==============================] - 2s 260ms/step - loss: 0.5214 - iou: 0.7617 - dice_coef: 0.2790 - precision: 0.1964 - recall: 0.9817 - accuracy: 0.7610 - val_loss: 0.5813 - val_iou: 0.7518 - val_dice_coef: 0.2237 - val_precision: 0.2139 - val_recall: 0.9496 - val_accuracy: 0.7679
# Epoch 82/100
# 7/7 [==============================] - 2s 264ms/step - loss: 0.5183 - iou: 0.7617 - dice_coef: 0.2785 - precision: 0.1992 - recall: 0.9817 - accuracy: 0.7644 - val_loss: 0.5803 - val_iou: 0.7523 - val_dice_coef: 0.2236 - val_precision: 0.2171 - val_recall: 0.9488 - val_accuracy: 0.7713
# Epoch 83/100
# 7/7 [==============================] - 2s 269ms/step - loss: 0.5153 - iou: 0.7623 - dice_coef: 0.2807 - precision: 0.2002 - recall: 0.9825 - accuracy: 0.7657 - val_loss: 0.5793 - val_iou: 0.7525 - val_dice_coef: 0.2246 - val_precision: 0.2164 - val_recall: 0.9496 - val_accuracy: 0.7711
# Epoch 84/100
# 7/7 [==============================] - 2s 268ms/step - loss: 0.5212 - iou: 0.7618 - dice_coef: 0.2791 - precision: 0.1980 - recall: 0.9827 - accuracy: 0.7624 - val_loss: 0.5792 - val_iou: 0.7524 - val_dice_coef: 0.2279 - val_precision: 0.2123 - val_recall: 0.9548 - val_accuracy: 0.7674
# Epoch 85/100
# 7/7 [==============================] - 2s 267ms/step - loss: 0.5154 - iou: 0.7626 - dice_coef: 0.2820 - precision: 0.2023 - recall: 0.9827 - accuracy: 0.7674 - val_loss: 0.5800 - val_iou: 0.7524 - val_dice_coef: 0.2287 - val_precision: 0.2105 - val_recall: 0.9557 - val_accuracy: 0.7656
# Epoch 86/100
# 7/7 [==============================] - 2s 269ms/step - loss: 0.5177 - iou: 0.7620 - dice_coef: 0.2789 - precision: 0.1998 - recall: 0.9820 - accuracy: 0.7652 - val_loss: 0.5782 - val_iou: 0.7523 - val_dice_coef: 0.2321 - val_precision: 0.2068 - val_recall: 0.9554 - val_accuracy: 0.7623
# Epoch 87/100
# 7/7 [==============================] - 2s 266ms/step - loss: 0.5121 - iou: 0.7629 - dice_coef: 0.2829 - precision: 0.2024 - recall: 0.9842 - accuracy: 0.7678 - val_loss: 0.5777 - val_iou: 0.7526 - val_dice_coef: 0.2333 - val_precision: 0.2086 - val_recall: 0.9595 - val_accuracy: 0.7639
# Epoch 88/100
# 7/7 [==============================] - 2s 267ms/step - loss: 0.5146 - iou: 0.7628 - dice_coef: 0.2822 - precision: 0.2026 - recall: 0.9838 - accuracy: 0.7679 - val_loss: 0.5764 - val_iou: 0.7530 - val_dice_coef: 0.2314 - val_precision: 0.2144 - val_recall: 0.9582 - val_accuracy: 0.7695
# Epoch 89/100
# 7/7 [==============================] - 2s 265ms/step - loss: 0.5165 - iou: 0.7623 - dice_coef: 0.2804 - precision: 0.2030 - recall: 0.9820 - accuracy: 0.7688 - val_loss: 0.5754 - val_iou: 0.7530 - val_dice_coef: 0.2300 - val_precision: 0.2146 - val_recall: 0.9526 - val_accuracy: 0.7702
# Epoch 90/100
# 7/7 [==============================] - 2s 262ms/step - loss: 0.5121 - iou: 0.7630 - dice_coef: 0.2827 - precision: 0.2044 - recall: 0.9840 - accuracy: 0.7701 - val_loss: 0.5751 - val_iou: 0.7528 - val_dice_coef: 0.2346 - val_precision: 0.2075 - val_recall: 0.9576 - val_accuracy: 0.7633
# Epoch 91/100
# 7/7 [==============================] - 2s 268ms/step - loss: 0.5102 - iou: 0.7632 - dice_coef: 0.2838 - precision: 0.2059 - recall: 0.9842 - accuracy: 0.7711 - val_loss: 0.5754 - val_iou: 0.7525 - val_dice_coef: 0.2379 - val_precision: 0.2030 - val_recall: 0.9624 - val_accuracy: 0.7583
# Epoch 92/100
# 7/7 [==============================] - 2s 273ms/step - loss: 0.5112 - iou: 0.7632 - dice_coef: 0.2829 - precision: 0.2046 - recall: 0.9836 - accuracy: 0.7704 - val_loss: 0.5747 - val_iou: 0.7528 - val_dice_coef: 0.2379 - val_precision: 0.2048 - val_recall: 0.9621 - val_accuracy: 0.7605
# Epoch 93/100
# 7/7 [==============================] - 2s 266ms/step - loss: 0.5118 - iou: 0.7629 - dice_coef: 0.2810 - precision: 0.2041 - recall: 0.9853 - accuracy: 0.7706 - val_loss: 0.5735 - val_iou: 0.7527 - val_dice_coef: 0.2378 - val_precision: 0.2045 - val_recall: 0.9604 - val_accuracy: 0.7601
# Epoch 94/100
# 7/7 [==============================] - 2s 261ms/step - loss: 0.5076 - iou: 0.7635 - dice_coef: 0.2841 - precision: 0.2064 - recall: 0.9848 - accuracy: 0.7727 - val_loss: 0.5727 - val_iou: 0.7528 - val_dice_coef: 0.2379 - val_precision: 0.2054 - val_recall: 0.9605 - val_accuracy: 0.7609
# Epoch 95/100
# 7/7 [==============================] - 2s 267ms/step - loss: 0.5116 - iou: 0.7634 - dice_coef: 0.2836 - precision: 0.2057 - recall: 0.9846 - accuracy: 0.7715 - val_loss: 0.5720 - val_iou: 0.7532 - val_dice_coef: 0.2375 - val_precision: 0.2083 - val_recall: 0.9634 - val_accuracy: 0.7637
# Epoch 96/100
# 7/7 [==============================] - 2s 266ms/step - loss: 0.5087 - iou: 0.7638 - dice_coef: 0.2847 - precision: 0.2067 - recall: 0.9851 - accuracy: 0.7732 - val_loss: 0.5717 - val_iou: 0.7533 - val_dice_coef: 0.2389 - val_precision: 0.2071 - val_recall: 0.9646 - val_accuracy: 0.7629
# Epoch 97/100
# 7/7 [==============================] - 2s 266ms/step - loss: 0.5098 - iou: 0.7636 - dice_coef: 0.2844 - precision: 0.2053 - recall: 0.9855 - accuracy: 0.7710 - val_loss: 0.5710 - val_iou: 0.7537 - val_dice_coef: 0.2388 - val_precision: 0.2095 - val_recall: 0.9647 - val_accuracy: 0.7657
# Epoch 98/100
# 7/7 [==============================] - 2s 271ms/step - loss: 0.5089 - iou: 0.7638 - dice_coef: 0.2846 - precision: 0.2072 - recall: 0.9864 - accuracy: 0.7732 - val_loss: 0.5705 - val_iou: 0.7539 - val_dice_coef: 0.2372 - val_precision: 0.2121 - val_recall: 0.9619 - val_accuracy: 0.7684
# Epoch 99/100
# 7/7 [==============================] - 2s 267ms/step - loss: 0.5086 - iou: 0.7636 - dice_coef: 0.2833 - precision: 0.2078 - recall: 0.9859 - accuracy: 0.7742 - val_loss: 0.5688 - val_iou: 0.7539 - val_dice_coef: 0.2410 - val_precision: 0.2082 - val_recall: 0.9681 - val_accuracy: 0.7645
# Epoch 100/100
# 7/7 [==============================] - 2s 262ms/step - loss: 0.5095 - iou: 0.7634 - dice_coef: 0.2830 - precision: 0.2069 - recall: 0.9849 - accuracy: 0.7730 - val_loss: 0.5690 - val_iou: 0.7535 - val_dice_coef: 0.2437 - val_precision: 0.2041 - val_recall: 0.9712 - val_accuracy: 0.7600

# %%
import matplotlib.pyplot as plt

history  = hist
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
res = model.evaluate(x_train, y_train, batch_size= 18)
# Out:
# 7/7 [==============================] - 1s 105ms/step - loss: 0.4860 - iou: 0.7637 - dice_coef: 0.2926 - precision: 0.1975 - recall: 0.9867 - accuracy: 0.7638

# %%
print('\n~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 7/7 [==============================] - 1s 106ms/step - loss: 0.4860 - iou: 0.7637 - dice_coef: 0.2926 - precision: 0.1975 - recall: 0.9867 - accuracy: 0.7638
# ________________________
# IOU:       |   76.37  |
# Dice Coef: |   29.26  |
# Precision: |   19.75  |
# Recall:    |   98.67  |
# Accuracy:  |   76.38  |
# Loss:      |   48.60  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 3/3 [==============================] - 1s 267ms/step - loss: 0.5937 - iou: 0.7580 - dice_coef: 0.2265 - precision: 0.2062 - recall: 0.9677 - accuracy: 0.7744
# ________________________
# IOU:       |   75.80  |
# Dice Coef: |   22.65  |
# Precision: |   20.62  |
# Recall:    |   96.77  |
# Accuracy:  |   77.44  |
# Loss:      |   59.37  |
# ________________________
#
# -------------On validation Set---------------------
#
# 2/2 [==============================] - 0s 83ms/step - loss: 0.5690 - iou: 0.7535 - dice_coef: 0.2437 - precision: 0.2041 - recall: 0.9712 - accuracy: 0.7600
# ________________________
# IOU:       |   75.35  |
# Dice Coef: |   24.37  |
# Precision: |   20.41  |
# Recall:    |   97.12  |
# Accuracy:  |   76.00  |
# Loss:      |   56.90  |
# ________________________

# %%
plt.figure(figsize=(20, 14))
plt.suptitle('Training Statistics on Train Set')
plt.subplot(2,2,1)
plt.plot(hist.history['loss'], 'red')
plt.title('Loss')
plt.subplot(2,2,2)
plt.plot(hist.history['accuracy'], 'green')
plt.title('Accuracy')
plt.subplot(2,2,3)
plt.plot(hist.history['val_loss'], 'red')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Valdiation Loss')
plt.subplot(2,2,4)
plt.plot(hist.history['val_accuracy'], 'green')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Validation Accuracy')
plt.show()

# %%
model_0=model;
x_test_1=x_test[18,:,:,78]
y_test_1=y_test[18,:,:,78]

# %%
img_pred = model_0.predict(x_test)

# %%
img_pred.shape,x_test.shape
# Out:
# ((39, 128, 128, 128), (39, 128, 128, 128))

# %%
rand_1=np.random.randint(1,38)
rand_2=np.random.randint(1,127)
rand_2
# Out:
# 56

# %%
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[rand_1,:,:,rand_2])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[rand_1,:,:,rand_2])
plt.title('Ground Truth')

plt.subplot(1,3,3)
plt.imshow(img_pred[rand_1,:,:,rand_2])
plt.title('Predicted Output')
plt.show()

# %%
plt.imshow(x_test[1,:,:,78])

# %%
plt.imshow(y_test[1,:,:,78])
