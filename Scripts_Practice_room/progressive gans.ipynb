# %%
# !git clone https://github.com/volotat/GANLib.git
# Out:
# Cloning into 'GANLib'...
# remote: Enumerating objects: 1699, done.
# remote: Total 1699 (delta 0), reused 0 (delta 0), pack-reused 1699
# Receiving objects: 100% (1699/1699), 40.34 MiB | 33.94 MiB/s, done.
# Resolving deltas: 100% (968/968), done.

# %%
ls
# Out:
# config.py*        loss.py*      representative_image_512x256.png*
# dataset.py*       metrics/      requirements-pip.txt*
# dataset_tool.py*  misc.py*      tfutil.py*
# GANLib/           networks.py*  train.py*
# legacy.py*        __pycache__/  util_scripts.py*
# LICENSE.txt*      README.md
