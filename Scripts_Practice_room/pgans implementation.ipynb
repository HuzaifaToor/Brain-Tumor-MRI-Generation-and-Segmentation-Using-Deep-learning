# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd drive
# Out:
# /content/drive

# %%
ls
# Out:
# MyDrive/  Shareddrives/

# %%
cd MyDrive/
# Out:
# /content/drive/MyDrive

# %%
ls
# Out:
# 'block chain books'/          notes/
# 'Books on networking'/        party_upload/
# 'brain tumor segmentation'/   party_upload.zip
#  Classroom/                  'party_upload.zip (Unzipped Files)'/
# 'Colab Notebooks'/           'ppse books'/
#  Lab8.rar                     SPADE/
#  Lec13.pdf                    stuff/
# 'MS OFFICE 2007'/            'visual studio'/

# %%
cd brain\ tumor\ segmentation
# Out:
# /content/drive/MyDrive/brain tumor segmentation

# %%
ls
# Out:
# 'asad data'/           'png images1964.png'  'png images5982.png'
#  GANS/                 'png images1965.png'  'png images5983.png'
# 'huzaifa data'/        'png images1966.png'  'png images5984.png'
#  huzaifa_data/         'png images1967.png'  'png images5985.png'
# 'png images10000.png'  'png images1968.png'  'png images5986.png'
# 'png images10001.png'  'png images1969.png'  'png images5987.png'
# 'png images10002.png'  'png images196.png'   'png images5988.png'
# 'png images10003.png'  'png images1970.png'  'png images5989.png'
# 'png images10004.png'  'png images1971.png'  'png images598.png'
# 'png images10005.png'  'png images1972.png'  'png images5990.png'
# 'png images10006.png'  'png images1973.png'  'png images5991.png'
# 'png images10007.png'  'png images1974.png'  'png images5992.png'
# 'png images10008.png'  'png images1975.png'  'png images5993.png'
# 'png images10009.png'  'png images1976.png'  'png images5994.png'
# ...

# %%
cd GANS
# Out:
# /content/drive/My Drive/brain tumor segmentation/GANS

# %%
ls
# Out:
# 'asad data'/  'pgans repo'/   thesis/

# %%
cd asad\ data
# Out:
# /content/drive/My Drive/brain tumor segmentation/GANS/asad data

# %%
ls
# Out:
# 'non zeros masks'/            'png brats flair'/      'saved models '/
# 'pgans repo mehdi eddition'/  'results brats pgans'/

# %%
cd pgans repo mehdi eddition
# Out:
# /content/drive/My Drive/brain tumor segmentation/GANS/asad data/pgans repo mehdi eddition

# %%
ls

# %%
# !git clone https://github.com/tkarras/progressive_growing_of_gans.git
# Out:
# Cloning into 'progressive_growing_of_gans'...
# remote: Enumerating objects: 170, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 170 (delta 1), reused 2 (delta 0), pack-reused 164
# Receiving objects: 100% (170/170), 356.84 KiB | 8.11 MiB/s, done.
# Resolving deltas: 100% (87/87), done.

# %%
ls
# Out:
# progressive_growing_of_gans/

# %%
cd progressive_growing_of_gans/
# Out:
# /content/drive/My Drive/brain tumor segmentation/GANS/asad data/pgans repo mehdi eddition/progressive_growing_of_gans

# %%
ls
# Out:
# config.py        LICENSE.txt  networks.py                       tfutil.py
# dataset.py       loss.py      README.md                         train.py
# dataset_tool.py  metrics/     representative_image_512x256.png  util_scripts.py
# legacy.py        misc.py      requirements-pip.txt

# %%
ls
# Out:
# config.py        LICENSE.txt  networks.py                       tfutil.py
# dataset.py       loss.py      README.md                         train.py
# dataset_tool.py  metrics/     representative_image_512x256.png  util_scripts.py
# legacy.py        misc.py      requirements-pip.txt

# %%
pip install -r requirements-pip.txt
# Out:
# ...
#      |████████████████████████████████| 489.6 MB 22 kB/s
# ...
#      |████████████████████████████████| 3.6 MB 46.1 MB/s
# ...

# %%
path_input='/content/drive/MyDrive/brain tumor segmentation/GANS/asad data/png brats flair'

# %%
path_out='/content/drive/MyDrive/brain tumor segmentation/GANS/asad data/pgans repo mehdi eddition/output of pgans'

# %%
# !python dataset_tool.py create_from_images -h --shuffle SHUFFLE path_out path_input
# Out:
# usage: dataset_tool.py create_from_images [-h] [--shuffle SHUFFLE]
#                                           tfrecord_dir image_dir
#
# Create dataset from a directory full of images.
#
# positional arguments:
#   tfrecord_dir       New dataset directory to be created
#   image_dir          Directory containing the images
#
# optional arguments:
#   -h, --help         show this help message and exit
#   --shuffle SHUFFLE  Randomize image order (default: 1)
#
# Example: dataset_tool.py create_from_images datasets/mydataset myimagedir
