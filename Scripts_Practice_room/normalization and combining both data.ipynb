# %%
import numpy as np
import tensorflow as tf

# %%
generated_mask=np.load('/content/drive/MyDrive/Brain_tumor_Segmentation/asad data/results/final Results all modility/results/complete results/results for combined with different ratios x_test real/5:1/xtest ytest/masks.npy')
generated_mask.shape
# Out:
# (4800, 128, 128, 4)

# %%
generated_mri=np.load('/content/drive/MyDrive/Brain_tumor_Segmentation/asad data/results/final Results all modility/results/complete results/results for combined with different ratios x_test real/5:1/xtest ytest/MRI.npy')
generated_mri.shape
# Out:
# (4800, 128, 128, 1)

# %%
import matplotlib.pyplot as plt

# %%
max_mask=np.argmax(generated_mask,axis=3)

# %%
max_mask.shape
# Out:
# (4800, 128, 128)

# %%
plt.imshow(max_mask[98])

# %%
original_mri=np.load('/content/drive/MyDrive/Brain_tumor_Segmentation/asad data/data/appended all/training/appended flair/flair.npy')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-106495b9084a> in <module>()
# ----> 1 original_mri=np.load('/content/drive/MyDrive/Brain_tumor_Segmentation/asad data/data/appended all/training/appended flair/flair.npy')
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     438             else:
#     439                 return format.read_array(fid, allow_pickle=allow_pickle,
# --> 440                                          pickle_kwargs=pickle_kwargs)
#     441         else:
#     442             # Try a pickle
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     739         if isfileobj(fp):
#     740             # We can use the fast fromfile() function.
# --> 741             array = numpy.fromfile(fp, dtype=dtype, count=count)
#     742         else:
#     743             # This is not a real file. We have to read it the
#
# KeyboardInterrupt:

# %%
original_masks=np.load('/content/drive/MyDrive/Brain_tumor_Segmentation/asad data/data/appended all/training/appended masks/masks.npy')

# %%
original_mri.shape,original_masks.shape

# %%
image2D = []
mask2d=[]
for i in range(195):
  for j in range(128):
    image2D.append(original_mri[i,:,:,j])
    mask2d.append(original_masks[i,:,:,j])
original_mri = np.array(image2D)
original_masks=np.array(mask2d)
original_mri.shape,original_masks.shape

# %%
original_masks=tf.keras.utils.to_categorical(original_masks)

# %%
original_masks.shape

# %%
original_mri=np.expand_dims(original_mri, axis = 3)
original_mri.shape

# %%
original_mri.shape,original_masks.shape,generated_mri.shape,generated_mask.shape

# %%
np.min(original_mri),np.min(generated_mri)

# %%
original_mri_one_d=original_mri[:,:,:,0]

# %%
original_mri_one_d.shape

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()

normlized_genereated_mri=min_max_scaler.fit_transform(generated_mri.reshape(-1, generated_mri.shape[-1])).reshape(generated_mri.shape)

# %%
normlized_genereated_mri.shape

# %%
np.max(normlized_genereated_mri),np.min(normlized_genereated_mri)

# %%
checking_mask=np.argmax(generated_mask,axis=3)
checking_mask.shape

# %%
plt.imshow(normlized_genereated_mri[5500,:,:,0])

# %%
plt.imshow(checking_mask[5500])

# %%
combined_mri=np.concatenate((original_mri, generated_mri))

# %%
combined_mri.shape

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()

# %%
combined_mri=min_max_scaler.fit_transform(combined_mri.reshape(-1, combined_mri.shape[-1])).reshape(combined_mri.shape)

# %%
combined_mri.shape

# %%
path='/content/drive/MyDrive/Brain_tumor_Segmentation/asad data/data/combined data final folder/flair/'

# %%
np.save(path+'mri',combined_mri)

# %%
del combined_mri

# %%
combined_mask=np.concatenate((original_masks, generated_mask))

# %%
combined_mask.shape

# %%
np.save(path+'masks',combined_mask)

# %%
original_mri.shape,original_masks.shape,generated_mri.shape,generated_mask.shape

# %%
del original_mri
del generated_mri

# %%
del original_masks
del generated_mask

# %%
del
