# %%
path_generator='/content/drive/MyDrive/brain tumor segmentation/GANS/asad data/saved models /120 epochs/generator/'

# %%
import keras
generator=keras.models.load_model(path_generator)

# %%
#Initialising Hyper Parameters

#Uncomment one of the two below lines. For some reason, on some computers the first one works, while on others the second.
from tensorflow.keras.optimizers import Adam
#from keras.optimizers import adam
import tensorflow as tf

import numpy as np
import keras

noise_dim = 100  # input dimension of random vector - the vector that goes into the generator

batch_size = 64   #How many images do we want to include in each batch
steps_per_epoch = 2500  #How many steps do we want to take per iteration of our training set (number of batches)
epochs = 60      #How many iterations of our training set do we want to do.

#change the below values to the dimensions of your image. The channels number refers to the number of colors
img_rows, img_cols, channels = 128, 128, 4

#These are the recommended values for the optimizer
optimizer = Adam(0.0002, 0.5)

# %%
import matplotlib.pyplot as plt
def show_images(noise, size_fig):
    generated_images = generator.predict(noise)   #Create the images from the GAN.
    print("unique values before argmx",np.unique(generated_images))
    generated_images=np.argmax(generated_images,axis=3)
    unique_values=np.unique(generated_images)
    plt.figure(figsize=size_fig)
    
    for i, image in enumerate(generated_images):
        plt.subplot(size_fig[0], size_fig[1], i+1)
        if channels == 1:
            plt.imshow(image.reshape((img_rows, img_cols)))    #If the image is grayscale, as in our case, then we will reshape the output in the following way.
                                                                            #Also, we set the coloring to grayscale so that it doesn't look like it came out of an infrared camera :)
        else:
            plt.imshow(image.reshape((img_rows, img_cols)))
        plt.axis('off')
    
    plt.tight_layout()   #Tight layout so that all of the generated images form a nice grid
    plt.show()
    return unique_values

# %%
noise = np.random.normal(0, 1, size=(25, noise_dim))
generated_images = generator.predict(noise)
show_images(noise, (5, 5))
# Out:
# unique values before argmx [-0.98549306 -0.9847297  -0.98435813 ...  0.9999998   0.9999999
#   1.        ]
# array([0, 1, 2, 3])

# %%
a=generated_images

# %%
b=generated_images

# %%
result = np.subtract(a,b)
print ('the difference =', result)
# Out:
# the difference = [[[[-4.59045172e-03  1.88037008e-03 -8.56682938e-03  1.11512663e-02]
#    [-3.49938869e-04  3.78312729e-03  1.88240409e-03 -7.50084221e-03]
#    [-6.10888004e-04 -1.83963962e-03 -1.79846436e-02 -3.19181755e-03]
#    ...
#    [-9.53674316e-07  2.45841034e-03  1.66021287e-04  3.76356207e-03]
#    [ 1.29938126e-05 -2.65375478e-03  2.29879469e-03  3.55050107e-03]
#    [ 1.41859055e-05 -5.60525432e-03 -3.88064515e-03 -7.50552490e-03]]
#
#   [[-5.75184822e-05 -1.30318105e-04 -1.12420171e-02 -1.07645243e-03]
#    [ 0.00000000e+00 -2.45654024e-03 -7.49019627e-03 -1.10532567e-02]
#    [-5.61475754e-05 -1.56710483e-03 -8.53779539e-03 -5.85139636e-03]
#    ...
#    [ 0.00000000e+00 -1.68485940e-03 -2.21985579e-03  8.83754529e-03]
#    [ 0.00000000e+00 -1.22055411e-04 -2.94230878e-03 -5.17126918e-03]
#    [ 1.66893005e-06  2.89049931e-03 -6.76233321e-05 -1.13337999e-02]]
#
#   [[-2.98023224e-05  1.64824352e-03  4.40823473e-03  3.06967460e-03]
# ...

# %%
path="C:/Users/guest/Downloads/asad_gan_code/"

# %%
img1 = cv2.imread('Cybertruck.jpg',1)
# Creating our sharpening filter
filter = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
# Applying cv2.filter2D function on our Cybertruck image
sharpen_img_1=cv2.filter2D(img1,-1,filter)
cv2_imshow(sharpen_img_1)

# %%
import keras
c_gan_generator=keras.models.load_model('/content/drive/MyDrive/Brain_tumor_Segmentation/huzaifa_data/Models/Models/C_Gans_Generator/CGAN_model_generator.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
import numpy as np
generated_mri=np.load('/content/drive/MyDrive/Brain_tumor_Segmentation/asad data/results/final Results all modility/results/complete results/results for combined with different ratios x_test real/4:1/xtest ytest/MRI.npy')
generated_mri.shape
# Out:
# (6000, 128, 128, 1)

# %%
image=generated_mri[100,:,:,0]

# %%
np.min(image)
# Out:
# -0.034193728

# %%
image.shape
# Out:
# (128, 128)

# %%
import matplotlib.pyplot as plt
plt.imshow(image)

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()

# %%
image=min_max_scaler.fit_transform(image.reshape(-1, image.shape[-1])).reshape(image.shape)

# %%
import sklearn

# %%
image=sklearn.preprocessing.normalize(image)

# %%
Generated_MRI=image

# %%
plt.imshow(image)

# %%
b = (Generated_MRI - np.min(Generated_MRI))/np.ptp(Generated_MRI)

# %%
plt.imshow(b)

# %%
image=np.load('/content/drive/MyDrive/Brain_tumor_Segmentation/asad data/results/final Results all modility/results/complete results/results for combined with different ratios x_test real/5:1/combined dataset/combined_mri.npy')

# %%
masks=np.load('/content/drive/MyDrive/Brain_tumor_Segmentation/asad data/results/final Results all modility/results/complete results/results for combined with different ratios x_test real/5:1/combined dataset/combined_mask.npy')

# %%
image.shape, masks.shape
# Out:
# ((27264, 128, 128, 1), (27264, 128, 128))

# %%
plt.imshow(image[26952,:,:,0])

# %%
a=

# %%
plt.imshow(masks[26952])

# %%
a=image[27102,:,:,0]

# %%
np.max(a)
# Out:
# 0.6385299563407898

# %%
Generated_MRI=a

# %%
b = (Generated_MRI - np.min(Generated_MRI))/np.ptp(Generated_MRI)

# %%
plt.imshow(b)

# %%
np.max()
# Out:
# 1.0

# %%
import keras
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **lets try the new generator**

# %%
generator=keras.models.load_model('/content/drive/MyDrive/brain tumor segmentation/GANS/asad data/saved models /60 epochs with batch size 64/generator')

# %%
noise = np.random.normal(0, 1, size=(25, 100))

# %%
generated_masks=generator.predict(noise)

# %%
generated_masks.shape
# Out:
# (25, 128, 128, 4)

# %%
arg_maxed=np.argmax(generated_masks,axis=3)

# %%
arg_maxed.shape
# Out:
# (25, 128, 128)

# %%
plt.imshow(arg_maxed[1])

# %%
np.unique(arg_maxed[1])
# Out:
# array([0, 2])

# %%
plt.imshow(arg_maxed[2])

# %%
np.unique(arg_maxed[2])
# Out:
# array([0, 2])

# %%
np.unique(arg_maxed[14])
# Out:
# array([0, 1, 2])

# %%
plt.imshow(arg_maxed[13])

# %%
images=np.load('/content/drive/MyDrive/Brain_tumor_Segmentation/asad data/results/final Results all modility/results/complete results/results for combined with different ratios x_test real/4:1/xtest ytest/MRI.npy')

# %%
masks=np.load('/content/drive/MyDrive/Brain_tumor_Segmentation/asad data/results/final Results all modility/results/complete results/results for combined with different ratios x_test real/4:1/xtest ytest/masks.npy')

# %%
images.shape,masks.shape
# Out:
# ((6000, 128, 128, 1), (6000, 128, 128))

# %%
np.max(images)
# Out:
# 1.0

# %%
np.min(images)
# Out:
# -0.47641206

# %%
plt.imshow(images[3,:,:,0])

# %%
b = (images - np.min(images))/np.ptp(images)

# %%
b.shape
# Out:
# (6000, 128, 128, 1)

# %%
np.min(b)
# Out:
# 0.0

# %%
plt.imshow(b[3,:,:,0])
