# %%
from keras.models import Model
from keras.layers import Input
from keras.layers.core import Activation, Reshape, Dense
from keras.layers.convolutional import Convolution2D
from keras.layers import BatchNormalization
#from keras import layers
from keras.layers.convolutional import Convolution2D, MaxPooling2D, UpSampling2D
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import numpy as np
import nibabel as nib
import glob
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import backend as K
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
output='/content/drive/MyDrive/brain tumor segmentation/GANS/asad data/png brats flair/'

# %%
x=np.load('/content/drive/MyDrive/brain tumor segmentation/asad data/data/appended all/training/appended flair/flair.npy')
y=np.load('/content/drive/MyDrive/brain tumor segmentation/asad data/data/appended all/training/appended masks/masks.npy')

# %%
rand=np.random.randint(0,194 )
rand_2=np.random.randint(0,127)
plt.figure(figsize=(12, 8))
plt.subplot(121)
plt.title('MRI Image')
plt.imshow(x[rand,:,:,rand_2])
plt.subplot(122)
plt.imshow(y[rand,:,:,rand_2])
plt.imshow
# Out:
# <function matplotlib.pyplot.imshow>

# %%
image2D = []
mask2D = []
counter=0
for i in range(3):
  for j in range(4):
    a=x[i,:,:,j]
    print(a.shape)
    matplotlib.image.imsave(output+str(counter)+'.png', a)
    

    counter=counter+1
# Out:
# (128, 128)
# (128, 128)
# (128, 128)
# (128, 128)
# (128, 128)
# (128, 128)
# (128, 128)
# (128, 128)
# (128, 128)
# (128, 128)
# (128, 128)
# (128, 128)

# %%
a=plt.imread('/content/drive/MyDrive/brain tumor segmentation/GANS/asad data/png brats flair/11.png')

# %%
a.shape
# Out:
# (128, 128, 4)

# %%
plt.imshow(a)

# %%
aaa=np.argmax(a,axis=2)

# %%
aaa.shape
# Out:
# (128, 128)

# %%
plt.imshow(aaa)

# %%
a
# Out:
# array([[[0.26666668, 0.00392157, 0.32941177, 1.        ],
#         [0.26666668, 0.00392157, 0.32941177, 1.        ],
#         [0.26666668, 0.00392157, 0.32941177, 1.        ],
#         ...,
#         [0.26666668, 0.00392157, 0.32941177, 1.        ],
#         [0.26666668, 0.00392157, 0.32941177, 1.        ],
#         [0.26666668, 0.00392157, 0.32941177, 1.        ]],
#
#        [[0.26666668, 0.00392157, 0.32941177, 1.        ],
#         [0.26666668, 0.00392157, 0.32941177, 1.        ],
#         [0.26666668, 0.00392157, 0.32941177, 1.        ],
#         ...,
#         [0.26666668, 0.00392157, 0.32941177, 1.        ],
#         [0.26666668, 0.00392157, 0.32941177, 1.        ],
#         [0.26666668, 0.00392157, 0.32941177, 1.        ]],
#
#        [[0.26666668, 0.00392157, 0.32941177, 1.        ],
#         [0.26666668, 0.00392157, 0.32941177, 1.        ],
#         [0.26666668, 0.00392157, 0.32941177, 1.        ],
#         ...,
# ...
