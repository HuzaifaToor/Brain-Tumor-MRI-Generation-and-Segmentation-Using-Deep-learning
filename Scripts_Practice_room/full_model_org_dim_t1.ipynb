# %%
from keras.models import Model,Sequential
import numpy as  np
from keras.layers.core import Activation, Reshape, Permute
from keras.layers.convolutional import Convolution2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.layers import BatchNormalization
from keras.layers import Input, merge, Conv2D,Concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau, TensorBoard, Callback
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array, load_img, ImageDataGenerator
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras import backend as K
from tensorflow.python import keras
from sklearn.model_selection import train_test_split
from keras.models import Model, Sequential
from keras.layers import Activation, Dense, BatchNormalization, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from keras.callbacks import EarlyStopping
from keras import backend as K

import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
from keras.layers import Conv3D, MaxPooling3D, concatenate, UpSampling3D
# %matplotlib inline

# %%
from google.colab import drive
drive.mount("/content/drive") # Don't change this.
# Out:
# Mounted at /content/drive

# %%
imgarray=np.load('/content/drive/MyDrive/brain tumor segmentation/asad data/data/appended all/training/appended t1/t1.npy')
maskarray=np.load('/content/drive/MyDrive/brain tumor segmentation/asad data/data/appended all/training/appended masks/masks.npy')

# %%
imgarray.shape,maskarray.shape
# Out:
# ((195, 128, 128, 128), (195, 128, 128, 128))

# %%
x_train1,x_test,y_train1,y_test=train_test_split(imgarray, maskarray, test_size = 0.20, random_state = 101)

# %%
x_train1.shape,y_train1.shape
# Out:
# ((156, 128, 128, 128), (156, 128, 128, 128))

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train1, y_train1, test_size = 0.20, random_state = 101)

# %%
x_train.shape,x_val.shape
# Out:
# ((124, 128, 128, 128), (32, 128, 128, 128))

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

def dice_coef(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision
def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall
def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %%
def segnet():#,savename):

    # Encoding layer
    img_input = Input(shape= (128,128,128))
    x = Conv2D(64, (3, 3), padding='same', name='conv1',strides= (1,1))(img_input)
    x = BatchNormalization(name='bn1')(x)
    x = Activation('relu')(x)
    x = Conv2D(64, (3, 3), padding='same', name='conv2')(x)
    x = BatchNormalization(name='bn2')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)
    
    x = Conv2D(128, (3, 3), padding='same', name='conv3')(x)
    x = BatchNormalization(name='bn3')(x)
    x = Activation('relu')(x)
    x = Conv2D(128, (3, 3), padding='same', name='conv4')(x)
    x = BatchNormalization(name='bn4')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Conv2D(256, (3, 3), padding='same', name='conv5')(x)
    x = BatchNormalization(name='bn5')(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same', name='conv6')(x)
    x = BatchNormalization(name='bn6')(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same', name='conv7')(x)
    x = BatchNormalization(name='bn7')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Conv2D(512, (3, 3), padding='same', name='conv8')(x)
    x = BatchNormalization(name='bn8')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv9')(x)
    x = BatchNormalization(name='bn9')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv10')(x)
    x = BatchNormalization(name='bn10')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)
    
    x = Conv2D(512, (3, 3), padding='same', name='conv11')(x)
    x = BatchNormalization(name='bn11')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv12')(x)
    x = BatchNormalization(name='bn12')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv13')(x)
    x = BatchNormalization(name='bn13')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Dense(1024, activation = 'relu', name='fc1')(x)
    x = Dense(1024, activation = 'relu', name='fc2')(x)
    # Decoding Layer 
    x = UpSampling2D()(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv1')(x)
    x = BatchNormalization(name='bn14')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv2')(x)
    x = BatchNormalization(name='bn15')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv3')(x)
    x = BatchNormalization(name='bn16')(x)
    x = Activation('relu')(x)
    
    x = UpSampling2D()(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv4')(x)
    x = BatchNormalization(name='bn17')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv5')(x)
    x = BatchNormalization(name='bn18')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv6')(x)
    x = BatchNormalization(name='bn19')(x)
    x = Activation('relu')(x)

    x = UpSampling2D()(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv7')(x)
    x = BatchNormalization(name='bn20')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv8')(x)
    x = BatchNormalization(name='bn21')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv9')(x)
    x = BatchNormalization(name='bn22')(x)
    x = Activation('relu')(x)

    x = UpSampling2D()(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv10')(x)
    x = BatchNormalization(name='bn23')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv11')(x)
    x = BatchNormalization(name='bn24')(x)
    x = Activation('relu')(x)
    
    x = UpSampling2D()(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv12')(x)
    x = BatchNormalization(name='bn25')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv13')(x)
    x = BatchNormalization(name='bn26')(x)
    x = Activation('sigmoid')(x)
    print("x.shape",x.shape)
    pred = Reshape((128,128,128))(x)
    
    model = Model(inputs=img_input, outputs=pred)
    
    model.compile(optimizer= SGD(learning_rate=0.0001, momentum=0.9, decay=0.0005, nesterov=False), loss= ["binary_crossentropy"]
                  , metrics=[iou, dice_coef, precision, recall, accuracy])
    model.summary()
    #hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 18, validation_data= (x_val, y_val), verbose=1)
    
    #model.save(savename)
    return model#,hist

# %%
model = segnet()#'segnet_1_epoch.h5')
hist = model.fit(x_train, y_train, epochs= 100, batch_size= 18, validation_data= (x_val, y_val), verbose=1)
# Out:
# x.shape (None, 128, 128, 128)
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 128, 128)]   0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 128, 128, 64)      73792
# _________________________________________________________________
# bn1 (BatchNormalization)     (None, 128, 128, 64)      256
# _________________________________________________________________
# activation (Activation)      (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 128, 128, 64)      36928
# _________________________________________________________________
# bn2 (BatchNormalization)     (None, 128, 128, 64)      256
# _________________________________________________________________
# activation_1 (Activation)    (None, 128, 128, 64)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 64)        0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 64, 64, 128)       73856
# _________________________________________________________________
# bn3 (BatchNormalization)     (None, 64, 64, 128)       512
# _________________________________________________________________
# activation_2 (Activation)    (None, 64, 64, 128)       0
# _________________________________________________________________
# conv4 (Conv2D)               (None, 64, 64, 128)       147584
# _________________________________________________________________
# bn4 (BatchNormalization)     (None, 64, 64, 128)       512
# _________________________________________________________________
# activation_3 (Activation)    (None, 64, 64, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 128)       0
# _________________________________________________________________
# conv5 (Conv2D)               (None, 32, 32, 256)       295168
# _________________________________________________________________
# bn5 (BatchNormalization)     (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_4 (Activation)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv6 (Conv2D)               (None, 32, 32, 256)       590080
# _________________________________________________________________
# bn6 (BatchNormalization)     (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_5 (Activation)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv7 (Conv2D)               (None, 32, 32, 256)       590080
# _________________________________________________________________
# bn7 (BatchNormalization)     (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_6 (Activation)    (None, 32, 32, 256)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 256)       0
# _________________________________________________________________
# conv8 (Conv2D)               (None, 16, 16, 512)       1180160
# _________________________________________________________________
# bn8 (BatchNormalization)     (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_7 (Activation)    (None, 16, 16, 512)       0
# _________________________________________________________________
# conv9 (Conv2D)               (None, 16, 16, 512)       2359808
# _________________________________________________________________
# bn9 (BatchNormalization)     (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_8 (Activation)    (None, 16, 16, 512)       0
# _________________________________________________________________
# conv10 (Conv2D)              (None, 16, 16, 512)       2359808
# _________________________________________________________________
# bn10 (BatchNormalization)    (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_9 (Activation)    (None, 16, 16, 512)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 512)         0
# _________________________________________________________________
# conv11 (Conv2D)              (None, 8, 8, 512)         2359808
# _________________________________________________________________
# bn11 (BatchNormalization)    (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_10 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# conv12 (Conv2D)              (None, 8, 8, 512)         2359808
# _________________________________________________________________
# bn12 (BatchNormalization)    (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_11 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# conv13 (Conv2D)              (None, 8, 8, 512)         2359808
# _________________________________________________________________
# bn13 (BatchNormalization)    (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_12 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4, 4, 1024)        525312
# _________________________________________________________________
# fc2 (Dense)                  (None, 4, 4, 1024)        1049600
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 8, 8, 1024)        0
# _________________________________________________________________
# deconv1 (Conv2DTranspose)    (None, 8, 8, 512)         4719104
# _________________________________________________________________
# bn14 (BatchNormalization)    (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_13 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# deconv2 (Conv2DTranspose)    (None, 8, 8, 512)         2359808
# _________________________________________________________________
# bn15 (BatchNormalization)    (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_14 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# deconv3 (Conv2DTranspose)    (None, 8, 8, 512)         2359808
# _________________________________________________________________
# bn16 (BatchNormalization)    (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_15 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 16, 16, 512)       0
# _________________________________________________________________
# deconv4 (Conv2DTranspose)    (None, 16, 16, 512)       2359808
# _________________________________________________________________
# bn17 (BatchNormalization)    (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_16 (Activation)   (None, 16, 16, 512)       0
# _________________________________________________________________
# deconv5 (Conv2DTranspose)    (None, 16, 16, 512)       2359808
# _________________________________________________________________
# bn18 (BatchNormalization)    (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_17 (Activation)   (None, 16, 16, 512)       0
# _________________________________________________________________
# deconv6 (Conv2DTranspose)    (None, 16, 16, 256)       1179904
# _________________________________________________________________
# bn19 (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# activation_18 (Activation)   (None, 16, 16, 256)       0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 32, 32, 256)       0
# _________________________________________________________________
# deconv7 (Conv2DTranspose)    (None, 32, 32, 256)       590080
# _________________________________________________________________
# bn20 (BatchNormalization)    (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_19 (Activation)   (None, 32, 32, 256)       0
# _________________________________________________________________
# deconv8 (Conv2DTranspose)    (None, 32, 32, 256)       590080
# _________________________________________________________________
# bn21 (BatchNormalization)    (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_20 (Activation)   (None, 32, 32, 256)       0
# _________________________________________________________________
# deconv9 (Conv2DTranspose)    (None, 32, 32, 128)       295040
# _________________________________________________________________
# bn22 (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# activation_21 (Activation)   (None, 32, 32, 128)       0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 64, 64, 128)       0
# _________________________________________________________________
# deconv10 (Conv2DTranspose)   (None, 64, 64, 128)       147584
# _________________________________________________________________
# bn23 (BatchNormalization)    (None, 64, 64, 128)       512
# _________________________________________________________________
# activation_22 (Activation)   (None, 64, 64, 128)       0
# _________________________________________________________________
# deconv11 (Conv2DTranspose)   (None, 64, 64, 64)        73792
# _________________________________________________________________
# bn24 (BatchNormalization)    (None, 64, 64, 64)        256
# _________________________________________________________________
# activation_23 (Activation)   (None, 64, 64, 64)        0
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 128, 128, 64)      0
# _________________________________________________________________
# deconv12 (Conv2DTranspose)   (None, 128, 128, 128)     73856
# _________________________________________________________________
# bn25 (BatchNormalization)    (None, 128, 128, 128)     512
# _________________________________________________________________
# activation_24 (Activation)   (None, 128, 128, 128)     0
# _________________________________________________________________
# deconv13 (Conv2DTranspose)   (None, 128, 128, 128)     147584
# _________________________________________________________________
# bn26 (BatchNormalization)    (None, 128, 128, 128)     512
# _________________________________________________________________
# activation_25 (Activation)   (None, 128, 128, 128)     0
# _________________________________________________________________
# reshape (Reshape)            (None, 128, 128, 128)     0
# =================================================================
# Total params: 33,650,368
# Trainable params: 33,634,112
# Non-trainable params: 16,256
# _________________________________________________________________
# Epoch 1/100
# 7/7 [==============================] - 25s 676ms/step - loss: 0.8043 - iou: 0.6946 - dice_coef: 0.1657 - precision: 0.0791 - recall: 0.8233 - accuracy: 0.4809 - val_loss: 0.6925 - val_iou: 0.7188 - val_dice_coef: 0.1714 - val_precision: 0.0988 - val_recall: 0.9366 - val_accuracy: 0.5199
# Epoch 2/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.8037 - iou: 0.6947 - dice_coef: 0.1660 - precision: 0.0793 - recall: 0.8228 - accuracy: 0.4810 - val_loss: 0.6920 - val_iou: 0.7189 - val_dice_coef: 0.1716 - val_precision: 0.0990 - val_recall: 0.9363 - val_accuracy: 0.5209
# Epoch 3/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.8026 - iou: 0.6951 - dice_coef: 0.1666 - precision: 0.0797 - recall: 0.8250 - accuracy: 0.4815 - val_loss: 0.6916 - val_iou: 0.7190 - val_dice_coef: 0.1718 - val_precision: 0.0993 - val_recall: 0.9356 - val_accuracy: 0.5225
# Epoch 4/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.8020 - iou: 0.6953 - dice_coef: 0.1665 - precision: 0.0798 - recall: 0.8247 - accuracy: 0.4819 - val_loss: 0.6912 - val_iou: 0.7192 - val_dice_coef: 0.1720 - val_precision: 0.0993 - val_recall: 0.9356 - val_accuracy: 0.5223
# Epoch 5/100
# 7/7 [==============================] - 2s 278ms/step - loss: 0.8013 - iou: 0.6955 - dice_coef: 0.1664 - precision: 0.0798 - recall: 0.8284 - accuracy: 0.4826 - val_loss: 0.6909 - val_iou: 0.7192 - val_dice_coef: 0.1721 - val_precision: 0.0996 - val_recall: 0.9358 - val_accuracy: 0.5237
# Epoch 6/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0
100
# 7/7 [==============================] - 2s 276ms/step - loss: 0.5685 - iou: 0.7540 - dice_coef: 0.2567 - precision: 0.1732 - recall: 0.9683 - accuracy: 0.7280 - val_loss: 0.6865 - val_iou: 0.7294 - val_dice_coef: 0.1809 - val_precision: 0.1404 - val_recall: 0.9107 - val_accuracy: 0.6585
# Epoch 82/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.5695 - iou: 0.7536 - dice_coef: 0.2557 - precision: 0.1737 - recall: 0.9699 - accuracy: 0.7277 - val_loss: 0.6881 - val_iou: 0.7287 - val_dice_coef: 0.1830 - val_precision: 0.1393 - val_recall: 0.9160 - val_accuracy: 0.6549
# Epoch 83/100
# 7/7 [==============================] - 2s 282ms/step - loss: 0.5660 - iou: 0.7545 - dice_coef: 0.2565 - precision: 0.1769 - recall: 0.9718 - accuracy: 0.7335 - val_loss: 0.6833 - val_iou: 0.7306 - val_dice_coef: 0.1817 - val_precision: 0.1461 - val_recall: 0.9151 - val_accuracy: 0.6689
# Epoch 84/100
# 7/7 [==============================] - 2s 277ms/step - loss: 0.5657 - iou: 0.7548 - dice_coef: 0.2566 - precision: 0.1742 - recall: 0.9706 - accuracy: 0.7299 - val_loss: 0.6798 - val_iou: 0.7314 - val_dice_coef: 0.1809 - val_precision: 0.1491 - val_recall: 0.9154 - val_accuracy: 0.6744
# Epoch 85/100
# 7/7 [==============================] - 2s 277ms/step - loss: 0.5604 - iou: 0.7560 - dice_coef: 0.2616 - precision: 0.1783 - recall: 0.9744 - accuracy: 0.7351 - val_loss: 0.6832 - val_iou: 0.7317 - val_dice_coef: 0.1840 - val_precision: 0.1504 - val_recall: 0.9189 - val_accuracy: 0.6773
# Epoch 86/100
# 7/7 [==============================] - 2s 281ms/step - loss: 0.5589 - iou: 0.7564 - dice_coef: 0.2617 - precision: 0.1827 - recall: 0.9742 - accuracy: 0.7419 - val_loss: 0.6955 - val_iou: 0.7299 - val_dice_coef: 0.1863 - val_precision: 0.1450 - val_recall: 0.9198 - val_accuracy: 0.6670
# Epoch 87/100
# 7/7 [==============================] - 2s 277ms/step - loss: 0.5572 - iou: 0.7563 - dice_coef: 0.2623 - precision: 0.1825 - recall: 0.9742 - accuracy: 0.7409 - val_loss: 0.6784 - val_iou: 0.7331 - val_dice_coef: 0.1878 - val_precision: 0.1543 - val_recall: 0.9275 - val_accuracy: 0.6837
# Epoch 88/100
# 7/7 [==============================] - 2s 277ms/step - loss: 0.5576 - iou: 0.7569 - dice_coef: 0.2634 - precision: 0.1831 - recall: 0.9755 - accuracy: 0.7420 - val_loss: 0.6712 - val_iou: 0.7343 - val_dice_coef: 0.1817 - val_precision: 0.1632 - val_recall: 0.9206 - val_accuracy: 0.6981
# Epoch 89/100
# 7/7 [==============================] - 2s 277ms/step - loss: 0.5549 - iou: 0.7572 - dice_coef: 0.2642 - precision: 0.1819 - recall: 0.9755 - accuracy: 0.7406 - val_loss: 0.6661 - val_iou: 0.7342 - val_dice_coef: 0.1833 - val_precision: 0.1592 - val_recall: 0.9176 - val_accuracy: 0.6926
# Epoch 90/100
# 7/7 [==============================] - 2s 279ms/step - loss: 0.5556 - iou: 0.7574 - dice_coef: 0.2640 - precision: 0.1837 - recall: 0.9751 - accuracy: 0.7437 - val_loss: 0.6745 - val_iou: 0.7339 - val_dice_coef: 0.1826 - val_precision: 0.1605 - val_recall: 0.9158 - val_accuracy: 0.6955
# Epoch 91/100
# 7/7 [==============================] - 2s 277ms/step - loss: 0.5543 - iou: 0.7578 - dice_coef: 0.2648 - precision: 0.1885 - recall: 0.9754 - accuracy: 0.7493 - val_loss: 0.6833 - val_iou: 0.7334 - val_dice_coef: 0.1814 - val_precision: 0.1620 - val_recall: 0.9150 - val_accuracy: 0.6972
# Epoch 92/100
# 7/7 [==============================] - 2s 277ms/step - loss: 0.5527 - iou: 0.7580 - dice_coef: 0.2656 - precision: 0.1850 - recall: 0.9770 - accuracy: 0.7456 - val_loss: 0.6841 - val_iou: 0.7340 - val_dice_coef: 0.1818 - val_precision: 0.1653 - val_recall: 0.9110 - val_accuracy: 0.7033
# Epoch 93/100
# 7/7 [==============================] - 2s 277ms/step - loss: 0.5508 - iou: 0.7576 - dice_coef: 0.2650 - precision: 0.1852 - recall: 0.9763 - accuracy: 0.7447 - val_loss: 0.6845 - val_iou: 0.7327 - val_dice_coef: 0.1869 - val_precision: 0.1554 - val_recall: 0.9194 - val_accuracy: 0.6866
# Epoch 94/100
# 7/7 [==============================] - 2s 271ms/step - loss: 0.5458 - iou: 0.7587 - dice_coef: 0.2678 - precision: 0.1917 - recall: 0.9775 - accuracy: 0.7538 - val_loss: 0.6809 - val_iou: 0.7335 - val_dice_coef: 0.1855 - val_precision: 0.1597 - val_recall: 0.9272 - val_accuracy: 0.6925
# Epoch 95/100
# 7/7 [==============================] - 2s 276ms/step - loss: 0.5450 - iou: 0.7587 - dice_coef: 0.2669 - precision: 0.1911 - recall: 0.9786 - accuracy: 0.7534 - val_loss: 0.6672 - val_iou: 0.7359 - val_dice_coef: 0.1799 - val_precision: 0.1723 - val_recall: 0.9152 - val_accuracy: 0.7131
# Epoch 96/100
# 7/7 [==============================] - 2s 276ms/step - loss: 0.5462 - iou: 0.7584 - dice_coef: 0.2676 - precision: 0.1877 - recall: 0.9767 - accuracy: 0.7475 - val_loss: 0.6739 - val_iou: 0.7354 - val_dice_coef: 0.1811 - val_precision: 0.1701 - val_recall: 0.9139 - val_accuracy: 0.7107
# Epoch 97/100
# 7/7 [==============================] - 2s 277ms/step - loss: 0.5430 - iou: 0.7595 - dice_coef: 0.2692 - precision: 0.1923 - recall: 0.9792 - accuracy: 0.7543 - val_loss: 0.6841 - val_iou: 0.7340 - val_dice_coef: 0.1804 - val_precision: 0.1676 - val_recall: 0.9091 - val_accuracy: 0.7069
# Epoch 98/100
# 7/7 [==============================] - 2s 278ms/step - loss: 0.5389 - iou: 0.7598 - dice_coef: 0.2697 - precision: 0.1949 - recall: 0.9812 - accuracy: 0.7584 - val_loss: 0.6891 - val_iou: 0.7326 - val_dice_coef: 0.1866 - val_precision: 0.1588 - val_recall: 0.9249 - val_accuracy: 0.6920
# Epoch 99/100
# 7/7 [==============================] - 2s 278ms/step - loss: 0.5375 - iou: 0.7599 - dice_coef: 0.2701 - precision: 0.1957 - recall: 0.9805 - accuracy: 0.7601 - val_loss: 0.6721 - val_iou: 0.7345 - val_dice_coef: 0.1855 - val_precision: 0.1617 - val_recall: 0.9150 - val_accuracy: 0.6993
# Epoch 100/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.5380 - iou: 0.7603 - dice_coef: 0.2713 - precision: 0.1952 - recall: 0.9814 - accuracy: 0.7587 - val_loss: 0.6564 - val_iou: 0.7379 - val_dice_coef: 0.1819 - val_precision: 0.1784 - val_recall: 0.9097 - val_accuracy: 0.7230

# %%
import matplotlib.pyplot as plt

history  = hist
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
print('\n~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 7/7 [==============================] - 1s 119ms/step - loss: 0.5512 - iou: 0.7558 - dice_coef: 0.2619 - precision: 0.1772 - recall: 0.9782 - accuracy: 0.7355
# ________________________
# IOU:       |   75.58  |
# Dice Coef: |   26.19  |
# Precision: |   17.72  |
# Recall:    |   97.82  |
# Accuracy:  |   73.55  |
# Loss:      |   55.12  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 3/3 [==============================] - 1s 247ms/step - loss: 0.6443 - iou: 0.7468 - dice_coef: 0.1677 - precision: 0.1694 - recall: 0.8779 - accuracy: 0.7334
# ________________________
# IOU:       |   74.68  |
# Dice Coef: |   16.77  |
# Precision: |   16.94  |
# Recall:    |   87.79  |
# Accuracy:  |   73.34  |
# Loss:      |   64.43  |
# ________________________
#
# -------------On validation Set---------------------
#
# 2/2 [==============================] - 0s 96ms/step - loss: 0.6564 - iou: 0.7379 - dice_coef: 0.1819 - precision: 0.1784 - recall: 0.9097 - accuracy: 0.7230
# ________________________
# IOU:       |   73.79  |
# Dice Coef: |   18.19  |
# Precision: |   17.84  |
# Recall:    |   90.97  |
# Accuracy:  |   72.30  |
# Loss:      |   65.64  |
# ________________________

# %%
plt.figure(figsize=(20, 14))
plt.suptitle('Training Statistics on Train Set')
plt.subplot(2,2,1)
plt.plot(hist.history['loss'], 'red')
plt.title('Loss')
plt.subplot(2,2,2)
plt.plot(hist.history['accuracy'], 'green')
plt.title('Accuracy')
plt.subplot(2,2,3)
plt.plot(hist.history['val_loss'], 'red')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Valdiation Loss')
plt.subplot(2,2,4)
plt.plot(hist.history['val_accuracy'], 'green')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Validation Accuracy')
plt.show()

# %%
model_0=model;

# %%
img_pred = model_0.predict(x_test)

# %%
rand_1=np.random.randint(1,38)
rand_2=np.random.randint(1,127)

# %%
rand_1=np.random.randint(1,38)
rand_2=np.random.randint(1,127)
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[rand_1,:,:,rand_2])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[rand_1,:,:,rand_2])
plt.title('Ground Truth')

plt.subplot(1,3,3)
plt.imshow(img_pred[rand_1,:,:,rand_2])
plt.title('Predicted Output')
plt.show()
