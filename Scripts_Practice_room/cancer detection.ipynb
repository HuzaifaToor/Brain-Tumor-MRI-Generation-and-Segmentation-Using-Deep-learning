# %%
path_to_zip_file='/content/archive.zip'

# %%
directory_to_extract_to='/content/sample_data/'

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/data.csv')

# %%
data.shape
# Out:
# (569, 33)

# %%
data.describe()
# Out:
#                  id  radius_mean  ...  fractal_dimension_worst  Unnamed: 32
# count  5.690000e+02   569.000000  ...               569.000000          0.0
# mean   3.037183e+07    14.127292  ...                 0.083946          NaN
# std    1.250206e+08     3.524049  ...                 0.018061          NaN
# min    8.670000e+03     6.981000  ...                 0.055040          NaN
# 25%    8.692180e+05    11.700000  ...                 0.071460          NaN
# 50%    9.060240e+05    13.370000  ...                 0.080040          NaN
# 75%    8.813129e+06    15.780000  ...                 0.092080          NaN
# max    9.113205e+08    28.110000  ...                 0.207500          NaN
#
# [8 rows x 32 columns]

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.neighbors import KNeighborsClassifier, NeighborhoodComponentsAnalysis, LocalOutlierFactor
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings("ignore")

# %%
data.drop(['Unnamed: 32','id'],inplace=True,axis=1)

# %%
data
# Out:
#     diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0           M        17.99  ...          0.4601                  0.11890
# 1           M        20.57  ...          0.2750                  0.08902
# 2           M        19.69  ...          0.3613                  0.08758
# 3           M        11.42  ...          0.6638                  0.17300
# 4           M        20.29  ...          0.2364                  0.07678
# ..        ...          ...  ...             ...                      ...
# 564         M        21.56  ...          0.2060                  0.07115
# 565         M        20.13  ...          0.2572                  0.06637
# 566         M        16.60  ...          0.2218                  0.07820
# 567         M        20.60  ...          0.4087                  0.12400
# 568         B         7.76  ...          0.2871                  0.07039
#
# [569 rows x 31 columns]

# %%
data.rename(columns={"diagnosis":"target"},inplace=True)

# %%
data
# Out:
#     target  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0        M        17.99  ...          0.4601                  0.11890
# 1        M        20.57  ...          0.2750                  0.08902
# 2        M        19.69  ...          0.3613                  0.08758
# 3        M        11.42  ...          0.6638                  0.17300
# 4        M        20.29  ...          0.2364                  0.07678
# ..     ...          ...  ...             ...                      ...
# 564      M        21.56  ...          0.2060                  0.07115
# 565      M        20.13  ...          0.2572                  0.06637
# 566      M        16.60  ...          0.2218                  0.07820
# 567      M        20.60  ...          0.4087                  0.12400
# 568      B         7.76  ...          0.2871                  0.07039
#
# [569 rows x 31 columns]

# %%
import seaborn as sns

sns.countplot(data["target"])

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
data['target']= label_encoder.fit_transform(data['target'])

# %%
x=data.drop(['target'],axis=1)
y=data.target

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.neighbors import KNeighborsClassifier, NeighborhoodComponentsAnalysis, LocalOutlierFactor
from sklearn.decomposition import PCA

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
X_train.shape,Y_train.shape
# Out:
# ((455, 30), (455,))

# %%
x=np.expand_dims(x, axis=2)
x.shape
# Out:
# (569, 30, 1)

# %%
X_train
# Out:
#      radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 68         9.029         17.33  ...          0.4228                  0.11750
# 181       21.090         26.57  ...          0.4098                  0.12840
# 63         9.173         13.86  ...          0.3282                  0.08490
# 248       10.650         25.22  ...          0.3409                  0.08147
# 60        10.170         14.88  ...          0.3557                  0.08020
# ..           ...           ...  ...             ...                      ...
# 71         8.888         14.64  ...          0.2254                  0.10840
# 106       11.640         18.33  ...          0.2806                  0.09097
# 270       14.290         16.82  ...          0.2458                  0.06120
# 435       13.980         19.62  ...          0.3179                  0.10550
# 102       12.180         20.52  ...          0.2694                  0.06878
#
# [455 rows x 30 columns]

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

# %%
data
# Out:
#      target  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0         1        17.99  ...          0.4601                  0.11890
# 1         1        20.57  ...          0.2750                  0.08902
# 2         1        19.69  ...          0.3613                  0.08758
# 3         1        11.42  ...          0.6638                  0.17300
# 4         1        20.29  ...          0.2364                  0.07678
# ..      ...          ...  ...             ...                      ...
# 564       1        21.56  ...          0.2060                  0.07115
# 565       1        20.13  ...          0.2572                  0.06637
# 566       1        16.60  ...          0.2218                  0.07820
# 567       1        20.60  ...          0.4087                  0.12400
# 568       0         7.76  ...          0.2871                  0.07039
#
# [569 rows x 31 columns]

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)

# %%
X_train=np.expand_dims(X_train, axis=2)
X_test=np.expand_dims(X_test, axis=2)
X_train.shape,X_test.shape
# Out:
# ((455, 30, 1), (114, 30, 1))

# %%
epcosh=50
from keras.models import Model, Sequential
from keras.layers import Activation, Dense, BatchNormalization, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape,Conv1D,Flatten
from keras.callbacks import EarlyStopping
from keras import backend as K
from tensorflow.keras.optimizers import Adam, SGD
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from warnings import filterwarnings

# %%
model=Sequential()
model.add(Conv1D(filters=32,kernel_size=2, activation='relu',input_shape=(30,1))) 
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv1D(64,kernel_size=2,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Conv1D(128,kernel_size=2,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_17 (Conv1D)          (None, 29, 32)            96
#
#  batch_normalization_15 (Bat  (None, 29, 32)           128
#  chNormalization)
#
#  dropout_15 (Dropout)        (None, 29, 32)            0
#
#  conv1d_18 (Conv1D)          (None, 28, 64)            4160
#
#  batch_normalization_16 (Bat  (None, 28, 64)           256
#  chNormalization)
#
#  dropout_16 (Dropout)        (None, 28, 64)            0
#
#  flatten_2 (Flatten)         (None, 1792)              0
#
#  dense_4 (Dense)             (None, 64)                114752
#
#  dropout_17 (Dropout)        (None, 64)                0
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 119,457
# Trainable params: 119,265
# Non-trainable params: 192
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(lr=0.0005),loss='binary_crossentropy',metrics=['accuracy'])

# %%
hist=model.fit(X_train,Y_train,epochs=50,validation_data=(X_test,Y_test), verbose=1)
# Out:
# Epoch 1/50
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0533 - accuracy: 0.9846 - val_loss: 0.0986 - val_accuracy: 0.9649
# Epoch 2/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0705 - accuracy: 0.9824 - val_loss: 0.1405 - val_accuracy: 0.9561
# Epoch 3/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0369 - accuracy: 0.9802 - val_loss: 0.1473 - val_accuracy: 0.9561
# Epoch 4/50
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0415 - accuracy: 0.9802 - val_loss: 0.1197 - val_accuracy: 0.9649
# Epoch 5/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0332 - accuracy: 0.9868 - val_loss: 0.1020 - val_accuracy: 0.9561
# Epoch 6/50
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0622 - accuracy: 0.9802 - val_loss: 0.0949 - val_accuracy: 0.9561
# Epoch 7/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0367 - accuracy: 0.9868 - val_loss: 0.0947 - val_accuracy: 0.9561
# Epoch 8/50
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0238 - accuracy: 0.9912 - val_loss: 0.0970 - val_accuracy: 0.9737
# Epoch 9/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0716 - accuracy: 0.9868 - val_loss: 0.0982 - val_accuracy: 0.9737
# Epoch 10/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0440 - accuracy: 0.9846 - val_loss: 0.1114 - val_accuracy: 0.9737
# Epoch 11/50
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0386 - accuracy: 0.9780 - val_loss: 0.1081 - val_accuracy: 0.9737
# Epoch 12/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1003 - accuracy: 0.9714 - val_loss: 0.1012 - val_accuracy: 0.9737
# Epoch 13/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0457 - accuracy: 0.9780 - val_loss: 0.1177 - val_accuracy: 0.9825
# Epoch 14/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0345 - accuracy: 0.9824 - val_loss: 0.1187 - val_accuracy: 0.9737
# Epoch 15/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0239 - accuracy: 0.9890 - val_loss: 0.1088 - val_accuracy: 0.9737
# Epoch 16/50
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0526 - accuracy: 0.9824 - val_loss: 0.1243 - val_accuracy: 0.9649
# Epoch 17/50
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0309 - accuracy: 0.9890 - val_loss: 0.1412 - val_accuracy: 0.9649
# Epoch 18/50
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0681 - accuracy: 0.9780 - val_loss: 0.1286 - val_accuracy: 0.9649
# Epoch 19/50
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0178 - accuracy: 0.9912 - val_loss: 0.1249 - val_accuracy: 0.9649
# Epoch 20/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0192 - accuracy: 0.9912 - val_loss: 0.1372 - val_accuracy: 0.9649
# Epoch 21/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0296 - accuracy: 0.9868 - val_loss: 0.1314 - val_accuracy: 0.9649
# Epoch 22/50
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0199 - accuracy: 0.9890 - val_loss: 0.1235 - val_accuracy: 0.9649
# Epoch 23/50
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0396 - accuracy: 0.9868 - val_loss: 0.1338 - val_accuracy: 0.9649
# Epoch 24/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0326 - accuracy: 0.9868 - val_loss: 0.1252 - val_accuracy: 0.9649
# Epoch 25/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0379 - accuracy: 0.9846 - val_loss: 0.1257 - val_accuracy: 0.9649
# Epoch 26/50
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0230 - accuracy: 0.9890 - val_loss: 0.1203 - val_accuracy: 0.9649
# Epoch 27/50
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0291 - accuracy: 0.9890 - val_loss: 0.1327 - val_accuracy: 0.9649
# Epoch 28/50
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0276 - accuracy: 0.9912 - val_loss: 0.1215 - val_accuracy: 0.9649
# Epoch 29/50
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0234 - accuracy: 0.9890 - val_loss: 0.1114 - val_accuracy: 0.9649
# Epoch 30/50
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0403 - accuracy: 0.9846 - val_loss: 0.1127 - val_accuracy: 0.9649
# Epoch 31/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0222 - accuracy: 0.9934 - val_loss: 0.1188 - val_accuracy: 0.9649
# Epoch 32/50
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0283 - accuracy: 0.9912 - val_loss: 0.1640 - val_accuracy: 0.9737
# Epoch 33/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0280 - accuracy: 0.9890 - val_loss: 0.1803 - val_accuracy: 0.9737
# Epoch 34/50
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0251 - accuracy: 0.9912 - val_loss: 0.1606 - val_accuracy: 0.9737
# Epoch 35/50
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0318 - accuracy: 0.9846 - val_loss: 0.1427 - val_accuracy: 0.9649
# Epoch 36/50
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0364 - accuracy: 0.9890 - val_loss: 0.1297 - val_accuracy: 0.9649
# Epoch 37/50
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0353 - accuracy: 0.9846 - val_loss: 0.1278 - val_accuracy: 0.9649
# Epoch 38/50
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0641 - accuracy: 0.9714 - val_loss: 0.1166 - val_accuracy: 0.9649
# Epoch 39/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0155 - accuracy: 0.9890 - val_loss: 0.1227 - val_accuracy: 0.9649
# Epoch 40/50
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0482 - accuracy: 0.9846 - val_loss: 0.1366 - val_accuracy: 0.9649
# Epoch 41/50
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0197 - accuracy: 0.9912 - val_loss: 0.1381 - val_accuracy: 0.9649
# Epoch 42/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0161 - accuracy: 0.9956 - val_loss: 0.1306 - val_accuracy: 0.9649
# Epoch 43/50
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0312 - accuracy: 0.9912 - val_loss: 0.1273 - val_accuracy: 0.9649
# Epoch 44/50
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0233 - accuracy: 0.9868 - val_loss: 0.1309 - val_accuracy: 0.9649
# Epoch 45/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0232 - accuracy: 0.9890 - val_loss: 0.1363 - val_accuracy: 0.9649
# Epoch 46/50
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0333 - accuracy: 0.9846 - val_loss: 0.1623 - val_accuracy: 0.9649
# Epoch 47/50
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0376 - accuracy: 0.9868 - val_loss: 0.1911 - val_accuracy: 0.9561
# Epoch 48/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0358 - accuracy: 0.9912 - val_loss: 0.1622 - val_accuracy: 0.9649
# Epoch 49/50
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0545 - accuracy: 0.9846 - val_loss: 0.1621 - val_accuracy: 0.9649
# Epoch 50/50
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0389 - accuracy: 0.9912 - val_loss: 0.1878 - val_accuracy: 0.9561

# %%
plt.figure(figsize=(20, 14))
plt.suptitle('Training Statistics on Train Set')
plt.subplot(2,2,1)
plt.plot(hist.history['loss'], 'red')
plt.title('Loss')
plt.subplot(2,2,2)
plt.plot(hist.history['accuracy'], 'green')
plt.title('Accuracy')
plt.subplot(2,2,3)
plt.plot(hist.history['val_loss'], 'red')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Valdiation Loss')
plt.subplot(2,2,4)
plt.plot(hist.history['val_accuracy'], 'green')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Validation Accuracy')
plt.show()

# %%
predicted=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score

# %%
score = accuracy_score(Y_test, np.round(abs(predicted)))

# %%
score
# Out:
# 0.956140350877193
