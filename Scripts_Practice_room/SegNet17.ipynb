# %% [markdown]
# **In previously used models, no. of classes are not added inside the model, hence that was not multiclass or multilabel model. So I improved the model by adding no of classed that is 4 in our case. But Still the reults are not encouraging, although accuracy is upto 95 for training data set**

# %%
from keras.models import Model
from keras.layers import Input
from keras.layers.core import Activation, Reshape, Dense
from keras.layers.convolutional import Convolution2D
from keras.layers import BatchNormalization
#from keras import layers
from keras.layers.convolutional import Convolution2D, MaxPooling2D, UpSampling2D
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
#import pandas as pd
#from glob import glob
#import pickle
import tensorflow as tf

# %%
x_train = np.load('/content/drive/MyDrive/brain tumor segmentation/huzaifa data/Prepared_MRI_data/Origna_data_handling/Stack_Arrays/train_images.npy')
x_test = np.load('/content/drive/MyDrive/brain tumor segmentation/huzaifa data/Prepared_MRI_data/Origna_data_handling/Stack_Arrays/val_images.npy')
y_train = np.load('/content/drive/MyDrive/brain tumor segmentation/huzaifa data/Prepared_MRI_data/Origna_data_handling/Stack_Arrays/train_masks.npy')
y_test = np.load('/content/drive/MyDrive/brain tumor segmentation/huzaifa data/Prepared_MRI_data/Origna_data_handling/Stack_Arrays/val_masks.npy')

# %%
from torch.nn import MaxPool2d, MaxUnpool2d

# %%
from keras.models import Model
from keras.layers import Input
from keras.layers.core import Activation, Reshape, Dense
from keras.layers.convolutional import Convolution2D
from keras.layers import BatchNormalization

#from layers import MaxPoolingWithArgmax2D, MaxUnpooling2D

def segnet(
        input_shape,
        n_labels,
        kernel=3,
        pool_size=(2, 2),
        output_mode="softmax"):
    # encoder
    inputs = Input(shape=input_shape)
    #inputs = tf.convert_to_tensor(inputs)
    conv_1 = Convolution2D(64, (kernel, kernel), padding="same", kernel_initializer='he_normal', name="block1_conv1")(inputs)
    conv_1 = BatchNormalization()(conv_1)
    conv_1 = Activation("relu")(conv_1)
    conv_2 = Convolution2D(64, (kernel, kernel), padding="same", kernel_initializer='he_normal', name="block1_conv2")(conv_1)
    conv_2 = BatchNormalization()(conv_2)
    conv_2 = Activation("relu")(conv_2)
    pool_1 = MaxPooling2D(pool_size, name="block1_pool")(conv_2)

    conv_3 = Convolution2D(128, (kernel, kernel), padding="same" , kernel_initializer='he_normal', name="block2_conv1")(pool_1)
    conv_3 = BatchNormalization()(conv_3)
    conv_3 = Activation("relu")(conv_3)
    conv_4 = Convolution2D(128, (kernel, kernel), padding="same", kernel_initializer='he_normal',  name="block2_conv2")(conv_3)
    conv_4 = BatchNormalization()(conv_4)
    conv_4 = Activation("relu")(conv_4)

    pool_2 = MaxPooling2D(pool_size, name="block2_pool")(conv_4)

    conv_5 = Convolution2D(256, (kernel, kernel), padding="same" , kernel_initializer='he_normal', name="block3_conv1")(pool_2)
    conv_5 = BatchNormalization()(conv_5)
    conv_5 = Activation("relu")(conv_5)
    conv_6 = Convolution2D(256, (kernel, kernel), padding="same" , kernel_initializer='he_normal', name="block3_conv2")(conv_5)
    conv_6 = BatchNormalization()(conv_6)
    conv_6 = Activation("relu")(conv_6)
    conv_7 = Convolution2D(256, (kernel, kernel), padding="same" , kernel_initializer='he_normal', name="block3_conv3")(conv_6)
    conv_7 = BatchNormalization()(conv_7)
    conv_7 = Activation("relu")(conv_7)

    pool_3 = MaxPooling2D(pool_size, name="block3_pool")(conv_7)

    conv_8 = Convolution2D(512, (kernel, kernel), padding="same", kernel_initializer='he_normal', name="block4_conv1")(pool_3)
    conv_8 = BatchNormalization()(conv_8)
    conv_8 = Activation("relu")(conv_8)
    conv_9 = Convolution2D(512, (kernel, kernel), padding="same" , kernel_initializer='he_normal', name="block4_conv2")(conv_8)
    conv_9 = BatchNormalization()(conv_9)
    conv_9 = Activation("relu")(conv_9)
    conv_10 = Convolution2D(512, (kernel, kernel), padding="same" , kernel_initializer='he_normal', name="block4_conv3")(conv_9)
    conv_10 = BatchNormalization()(conv_10)
    conv_10 = Activation("relu")(conv_10)

    pool_4 = MaxPooling2D(pool_size, name="block4_pool")(conv_10)

    conv_11 = Convolution2D(512, (kernel, kernel), padding="same", kernel_initializer='he_normal', name="block5_conv1")(pool_4)
    conv_11 = BatchNormalization()(conv_11)
    conv_11 = Activation("relu")(conv_11)
    conv_12 = Convolution2D(512, (kernel, kernel), padding="same" , kernel_initializer='he_normal',  name="block5_conv2")(conv_11)
    conv_12 = BatchNormalization()(conv_12)
    conv_12 = Activation("relu")(conv_12)
    conv_13 = Convolution2D(512, (kernel, kernel), padding="same" , kernel_initializer='he_normal',  name="block5_conv3")(conv_12)
    conv_13 = BatchNormalization()(conv_13)
    conv_13 = Activation("relu")(conv_13)

    pool_5 = MaxPooling2D(pool_size, name="block5_pool")(conv_13)
   
    # decoder
    unpool_1 = UpSampling2D(pool_size)(pool_5)

    conv_14 = Convolution2D(512, (kernel, kernel), padding="same", kernel_initializer='he_normal')(unpool_1)
    conv_14 = BatchNormalization()(conv_14)
    conv_14 = Activation("relu")(conv_14)
    conv_15 = Convolution2D(512, (kernel, kernel), padding="same", kernel_initializer='he_normal')(conv_14)
    conv_15 = BatchNormalization()(conv_15)
    conv_15 = Activation("relu")(conv_15)
    conv_16 = Convolution2D(512, (kernel, kernel), padding="same", kernel_initializer='he_normal')(conv_15)
    conv_16 = BatchNormalization()(conv_16)
    conv_16 = Activation("relu")(conv_16)

    unpool_2 = UpSampling2D(pool_size)(conv_16)

    conv_17 = Convolution2D(512, (kernel, kernel), padding="same", kernel_initializer='he_normal')(unpool_2)
    conv_17 = BatchNormalization()(conv_17)
    conv_17 = Activation("relu")(conv_17)
    conv_18 = Convolution2D(512, (kernel, kernel), padding="same", kernel_initializer='he_normal')(conv_17)
    conv_18 = BatchNormalization()(conv_18)
    conv_18 = Activation("relu")(conv_18)
    conv_19 = Convolution2D(256, (kernel, kernel), padding="same", kernel_initializer='he_normal')(conv_18)
    conv_19 = BatchNormalization()(conv_19)
    conv_19 = Activation("relu")(conv_19)

    unpool_3 = UpSampling2D(pool_size)(conv_19)

    conv_20 = Convolution2D(256, (kernel, kernel), padding="same", kernel_initializer='he_normal')(unpool_3)
    conv_20 = BatchNormalization()(conv_20)
    conv_20 = Activation("relu")(conv_20)
    conv_21 = Convolution2D(256, (kernel, kernel), padding="same", kernel_initializer='he_normal')(conv_20)
    conv_21 = BatchNormalization()(conv_21)
    conv_21 = Activation("relu")(conv_21)
    conv_22 = Convolution2D(128, (kernel, kernel), padding="same", kernel_initializer='he_normal')(conv_21)
    conv_22 = BatchNormalization()(conv_22)
    conv_22 = Activation("relu")(conv_22)

    unpool_4 = UpSampling2D(pool_size)(conv_22)

    conv_23 = Convolution2D(128, (kernel, kernel), padding="same", kernel_initializer='he_normal')(unpool_4)
    conv_23 = BatchNormalization()(conv_23)
    conv_23 = Activation("relu")(conv_23)
    conv_24 = Convolution2D(64, (kernel, kernel), padding="same", kernel_initializer='he_normal')(conv_23)
    conv_24 = BatchNormalization()(conv_24)
    conv_24 = Activation("relu")(conv_24)

    unpool_5 = UpSampling2D(pool_size)(conv_24)
    #pool, ind, output_shape, batch_size, name=None

    conv_25 = Convolution2D(64, (kernel, kernel), padding="same", kernel_initializer='he_normal')(unpool_5)
    conv_25 = BatchNormalization()(conv_25)
    conv_25 = Activation("relu")(conv_25)

    conv_26 = Convolution2D(n_labels, (1, 1), padding="same", kernel_initializer='he_normal')(conv_25)
    conv_26 = BatchNormalization()(conv_26)

    conv_26 = Dense(128)(conv_26)
    outputs = Activation(output_mode)(conv_26)
    print("Build decoder done..")
    #pred = Reshape((128,128,128))(outputs)
    model = Model(inputs=inputs, outputs=outputs, name="SegNet")

    return model


model = segnet(input_shape=(128,128,128), n_labels=4)

model.summary()
print(model.input_shape)
print(model.output_shape)
# Out:
# Build decoder done..
# Model: "SegNet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 128, 128, 128)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 128, 128, 64)      73792
# _________________________________________________________________
# batch_normalization_52 (Batc (None, 128, 128, 64)      256
# _________________________________________________________________
# activation_52 (Activation)   (None, 128, 128, 64)      0
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 128, 128, 64)      36928
# _________________________________________________________________
# batch_normalization_53 (Batc (None, 128, 128, 64)      256
# _________________________________________________________________
# activation_53 (Activation)   (None, 128, 128, 64)      0
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 64, 64, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 64, 64, 128)       73856
# _________________________________________________________________
# batch_normalization_54 (Batc (None, 64, 64, 128)       512
# _________________________________________________________________
# activation_54 (Activation)   (None, 64, 64, 128)       0
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 64, 64, 128)       147584
# _________________________________________________________________
# batch_normalization_55 (Batc (None, 64, 64, 128)       512
# _________________________________________________________________
# activation_55 (Activation)   (None, 64, 64, 128)       0
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 32, 32, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 32, 32, 256)       295168
# _________________________________________________________________
# batch_normalization_56 (Batc (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_56 (Activation)   (None, 32, 32, 256)       0
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_57 (Batc (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_57 (Activation)   (None, 32, 32, 256)       0
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_58 (Batc (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_58 (Activation)   (None, 32, 32, 256)       0
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 16, 16, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 16, 16, 512)       1180160
# _________________________________________________________________
# batch_normalization_59 (Batc (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_59 (Activation)   (None, 16, 16, 512)       0
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# batch_normalization_60 (Batc (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_60 (Activation)   (None, 16, 16, 512)       0
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# batch_normalization_61 (Batc (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_61 (Activation)   (None, 16, 16, 512)       0
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_62 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_62 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_63 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_63 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_64 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_64 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# up_sampling2d_10 (UpSampling (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_65 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_65 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_66 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_66 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_67 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_67 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# up_sampling2d_11 (UpSampling (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 16, 16, 512)       2359808
# _________________________________________________________________
# batch_normalization_68 (Batc (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_68 (Activation)   (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 16, 16, 512)       2359808
# _________________________________________________________________
# batch_normalization_69 (Batc (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_69 (Activation)   (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 16, 16, 256)       1179904
# _________________________________________________________________
# batch_normalization_70 (Batc (None, 16, 16, 256)       1024
# _________________________________________________________________
# activation_70 (Activation)   (None, 16, 16, 256)       0
# _________________________________________________________________
# up_sampling2d_12 (UpSampling (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_71 (Batc (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_71 (Activation)   (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_72 (Batc (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_72 (Activation)   (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 32, 32, 128)       295040
# _________________________________________________________________
# batch_normalization_73 (Batc (None, 32, 32, 128)       512
# _________________________________________________________________
# activation_73 (Activation)   (None, 32, 32, 128)       0
# _________________________________________________________________
# up_sampling2d_13 (UpSampling (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 64, 64, 128)       147584
# _________________________________________________________________
# batch_normalization_74 (Batc (None, 64, 64, 128)       512
# _________________________________________________________________
# activation_74 (Activation)   (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 64, 64, 64)        73792
# _________________________________________________________________
# batch_normalization_75 (Batc (None, 64, 64, 64)        256
# _________________________________________________________________
# activation_75 (Activation)   (None, 64, 64, 64)        0
# _________________________________________________________________
# up_sampling2d_14 (UpSampling (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 128, 128, 64)      36928
# _________________________________________________________________
# batch_normalization_76 (Batc (None, 128, 128, 64)      256
# _________________________________________________________________
# activation_76 (Activation)   (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 128, 128, 4)       260
# _________________________________________________________________
# batch_normalization_77 (Batc (None, 128, 128, 4)       16
# _________________________________________________________________
# dense_2 (Dense)              (None, 128, 128, 128)     640
# _________________________________________________________________
# activation_77 (Activation)   (None, 128, 128, 128)     0
# =================================================================
# Total params: 29,531,796
# Trainable params: 29,515,916
# Non-trainable params: 15,880
# _________________________________________________________________
# (None, 128, 128, 128)
# (None, 128, 128, 128)

# %%
from tensorflow.keras import backend as K

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

def dice_coef(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision
def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall
def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %%
from tensorflow.keras.optimizers import Adam
LR = 0.0001
optim = Adam(LR)

# %%
model.compile(optimizer= Adam(learning_rate=0.001, decay=0.05), loss= ["categorical_crossentropy"]
                  , metrics=[iou, dice_coef, precision, recall, accuracy])

# %%
#model = segnet()
hist = model.fit(x_train, y_train, epochs= 100, batch_size= 10, validation_data= (x_test, y_test), verbose=1)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 23s 246ms/step - loss: 57.8496 - iou: 0.9038 - dice_coef: 0.0146 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9560 - val_loss: 7512710.0000 - val_iou: 0.8971 - val_dice_coef: 0.0055 - val_precision: 0.0159 - val_recall: 0.0030 - val_accuracy: 0.9456
# Epoch 2/100
# 17/17 [==============================] - 2s 142ms/step - loss: 57.8595 - iou: 0.9038 - dice_coef: 0.0151 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9558 - val_loss: 2102987.7500 - val_iou: 0.8978 - val_dice_coef: 0.0279 - val_precision: 0.0926 - val_recall: 0.0149 - val_accuracy: 0.9464
# Epoch 3/100
# 17/17 [==============================] - 2s 141ms/step - loss: 57.9985 - iou: 0.9038 - dice_coef: 0.0154 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9558 - val_loss: 65366.5664 - val_iou: 0.8972 - val_dice_coef: 0.0084 - val_precision: 0.0263 - val_recall: 0.0045 - val_accuracy: 0.9457
# Epoch 4/100
# 17/17 [==============================] - 2s 139ms/step - loss: 58.2143 - iou: 0.9038 - dice_coef: 0.0157 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 16745.8965 - val_iou: 0.8981 - val_dice_coef: 0.0309 - val_precision: 0.1035 - val_recall: 0.0165 - val_accuracy: 0.9465
# Epoch 5/100
# 17/17 [==============================] - 2s 140ms/step - loss: 58.2043 - iou: 0.9038 - dice_coef: 0.0159 - precision: 34705884.0000 - recall: 3.9475e-06 - accuracy: 0.9560 - val_loss: 6447.2256 - val_iou: 0.8989 - val_dice_coef: 0.0309 - val_precision: 0.1095 - val_recall: 0.0166 - val_accuracy: 0.9469
# Epoch 6/100
# 17/17 [==============================] - 2s 138ms/step - loss: 58.1455 - iou: 0.9038 - dice_coef: 0.0162 - precision: 7058823.5000 - recall: 8.4303e-07 - accuracy: 0.9557 - val_loss: 802.2271 - val_iou: 0.9044 - val_dice_coef: 0.0301 - val_precision: 0.3791 - val_recall: 0.0202 - val_accuracy: 0.9514
# Epoch 7/100
# 17/17 [==============================] - 2s 139ms/step - loss: 58.1923 - iou: 0.9038 - dice_coef: 0.0163 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9558 - val_loss: 521.1521 - val_iou: 0.9048 - val_dice_coef: 0.0272 - val_precision: 0.3678 - val_recall: 0.0187 - val_accuracy: 0.9516
# Epoch 8/100
# 17/17 [==============================] - 2s 139ms/step - loss: 58.0506 - iou: 0.9038 - dice_coef: 0.0164 - precision: 1176470.6250 - recall: 1.6176e-07 - accuracy: 0.9557 - val_loss: 255.0888 - val_iou: 0.9055 - val_dice_coef: 0.0264 - val_precision: 0.7076 - val_recall: 0.0191 - val_accuracy: 0.9526
# Epoch 9/100
# 17/17 [==============================] - 2s 139ms/step - loss: 58.1146 - iou: 0.9038 - dice_coef: 0.0166 - precision: 31176470.0000 - recall: 2.7295e-06 - accuracy: 0.9559 - val_loss: 181.9971 - val_iou: 0.9057 - val_dice_coef: 0.0262 - val_precision: 1.1070 - val_recall: 0.0184 - val_accuracy: 0.9529
# Epoch 10/100
# 17/17 [==============================] - 2s 140ms/step - loss: 57.9741 - iou: 0.9038 - dice_coef: 0.0166 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 66.7040 - val_iou: 0.9061 - val_dice_coef: 0.0211 - val_precision: 33004001280.0000 - val_recall: 0.0048 - val_accuracy: 0.9533
# Epoch 11/100
# 17/17 [==============================] - 2s 140ms/step - loss: 58.0246 - iou: 0.9038 - dice_coef: 0.0168 - precision: 31764706.0000 - recall: 4.6800e-06 - accuracy: 0.9559 - val_loss: 82.2785 - val_iou: 0.9061 - val_dice_coef: 0.0233 - val_precision: 16611999744.0000 - val_recall: 0.0106 - val_accuracy: 0.9533
# Epoch 12/100
# 17/17 [==============================] - 2s 140ms/step - loss: 58.0028 - iou: 0.9038 - dice_coef: 0.0170 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9560 - val_loss: 70.6173 - val_iou: 0.9061 - val_dice_coef: 0.0209 - val_precision: 12720000000.0000 - val_recall: 0.0053 - val_accuracy: 0.9533
# Epoch 13/100
# 17/17 [==============================] - 2s 139ms/step - loss: 58.1193 - iou: 0.9038 - dice_coef: 0.0170 - precision: 67647056.0000 - recall: 7.3326e-06 - accuracy: 0.9560 - val_loss: 63.3454 - val_iou: 0.9061 - val_dice_coef: 0.0204 - val_precision: 18709999616.0000 - val_recall: 0.0022 - val_accuracy: 0.9533
# Epoch 14/100
# 17/17 [==============================] - 2s 140ms/step - loss: 58.
- val_iou: 0.9060 - val_dice_coef: 0.0161 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 75/100
# 17/17 [==============================] - 2s 142ms/step - loss: 58.0109 - iou: 0.9039 - dice_coef: 0.0188 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9558 - val_loss: 53.7482 - val_iou: 0.9060 - val_dice_coef: 0.0162 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 76/100
# 17/17 [==============================] - 2s 139ms/step - loss: 57.9761 - iou: 0.9039 - dice_coef: 0.0189 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9558 - val_loss: 53.7286 - val_iou: 0.9060 - val_dice_coef: 0.0161 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 77/100
# 17/17 [==============================] - 2s 138ms/step - loss: 57.9715 - iou: 0.9039 - dice_coef: 0.0188 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9556 - val_loss: 53.7670 - val_iou: 0.9060 - val_dice_coef: 0.0162 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 78/100
# 17/17 [==============================] - 2s 138ms/step - loss: 57.9818 - iou: 0.9039 - dice_coef: 0.0189 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9561 - val_loss: 53.7337 - val_iou: 0.9060 - val_dice_coef: 0.0161 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 79/100
# 17/17 [==============================] - 2s 140ms/step - loss: 57.9996 - iou: 0.9039 - dice_coef: 0.0189 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 53.7928 - val_iou: 0.9060 - val_dice_coef: 0.0164 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 80/100
# 17/17 [==============================] - 2s 141ms/step - loss: 58.0026 - iou: 0.9039 - dice_coef: 0.0189 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 53.7411 - val_iou: 0.9060 - val_dice_coef: 0.0163 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 81/100
# 17/17 [==============================] - 2s 138ms/step - loss: 57.9865 - iou: 0.9039 - dice_coef: 0.0189 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 53.7744 - val_iou: 0.9060 - val_dice_coef: 0.0164 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 82/100
# 17/17 [==============================] - 2s 140ms/step - loss: 57.9923 - iou: 0.9039 - dice_coef: 0.0187 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9557 - val_loss: 53.7106 - val_iou: 0.9060 - val_dice_coef: 0.0161 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 83/100
# 17/17 [==============================] - 2s 140ms/step - loss: 57.9940 - iou: 0.9039 - dice_coef: 0.0190 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9558 - val_loss: 53.7798 - val_iou: 0.9060 - val_dice_coef: 0.0164 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 84/100
# 17/17 [==============================] - 2s 140ms/step - loss: 58.0251 - iou: 0.9039 - dice_coef: 0.0190 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 53.7370 - val_iou: 0.9060 - val_dice_coef: 0.0163 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 85/100
# 17/17 [==============================] - 2s 140ms/step - loss: 58.0082 - iou: 0.9039 - dice_coef: 0.0190 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 53.7604 - val_iou: 0.9060 - val_dice_coef: 0.0165 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 86/100
# 17/17 [==============================] - 2s 142ms/step - loss: 57.9965 - iou: 0.9039 - dice_coef: 0.0190 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9557 - val_loss: 53.7563 - val_iou: 0.9060 - val_dice_coef: 0.0163 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 87/100
# 17/17 [==============================] - 2s 142ms/step - loss: 58.0198 - iou: 0.9039 - dice_coef: 0.0189 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9557 - val_loss: 53.7371 - val_iou: 0.9060 - val_dice_coef: 0.0164 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 88/100
# 17/17 [==============================] - 2s 139ms/step - loss: 57.9991 - iou: 0.9039 - dice_coef: 0.0189 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9557 - val_loss: 53.7013 - val_iou: 0.9060 - val_dice_coef: 0.0162 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 89/100
# 17/17 [==============================] - 2s 137ms/step - loss: 57.9706 - iou: 0.9039 - dice_coef: 0.0190 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9560 - val_loss: 53.7220 - val_iou: 0.9060 - val_dice_coef: 0.0163 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 90/100
# 17/17 [==============================] - 2s 140ms/step - loss: 58.0363 - iou: 0.9039 - dice_coef: 0.0189 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9558 - val_loss: 53.7539 - val_iou: 0.9060 - val_dice_coef: 0.0164 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 91/100
# 17/17 [==============================] - 2s 139ms/step - loss: 57.9781 - iou: 0.9039 - dice_coef: 0.0190 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9558 - val_loss: 53.7204 - val_iou: 0.9060 - val_dice_coef: 0.0164 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 92/100
# 17/17 [==============================] - 2s 140ms/step - loss: 58.0071 - iou: 0.9039 - dice_coef: 0.0191 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 53.7283 - val_iou: 0.9060 - val_dice_coef: 0.0163 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 93/100
# 17/17 [==============================] - 2s 140ms/step - loss: 58.0087 - iou: 0.9039 - dice_coef: 0.0190 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9558 - val_loss: 53.7061 - val_iou: 0.9060 - val_dice_coef: 0.0163 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 94/100
# 17/17 [==============================] - 2s 140ms/step - loss: 58.0209 - iou: 0.9039 - dice_coef: 0.0190 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 53.7039 - val_iou: 0.9060 - val_dice_coef: 0.0163 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 95/100
# 17/17 [==============================] - 2s 139ms/step - loss: 57.9916 - iou: 0.9039 - dice_coef: 0.0190 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9557 - val_loss: 53.7646 - val_iou: 0.9060 - val_dice_coef: 0.0164 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 96/100
# 17/17 [==============================] - 2s 142ms/step - loss: 57.9948 - iou: 0.9039 - dice_coef: 0.0190 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 53.7353 - val_iou: 0.9060 - val_dice_coef: 0.0163 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 97/100
# 17/17 [==============================] - 2s 140ms/step - loss: 58.0036 - iou: 0.9039 - dice_coef: 0.0190 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9558 - val_loss: 53.7141 - val_iou: 0.9060 - val_dice_coef: 0.0163 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 98/100
# 17/17 [==============================] - 2s 141ms/step - loss: 57.9709 - iou: 0.9039 - dice_coef: 0.0191 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9559 - val_loss: 53.7235 - val_iou: 0.9060 - val_dice_coef: 0.0164 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 99/100
# 17/17 [==============================] - 2s 141ms/step - loss: 58.0171 - iou: 0.9039 - dice_coef: 0.0191 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.9560 - val_loss: 53.7070 - val_iou: 0.9060 - val_dice_coef: 0.0164 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533
# Epoch 100/100
# 17/17 [==============================] - 2s 139ms/step - loss: 58.0548 - iou: 0.9039 - dice_coef: 0.0189 - precision: 237647056.0000 - recall: 3.7856e-05 - accuracy: 0.9559 - val_loss: 53.6701 - val_iou: 0.9060 - val_dice_coef: 0.0162 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.9533

# %%
loss = hist.history['loss']
val_loss = hist.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
prediction = model.predict(x_test)

# %%
n_slice = 50

image = 41

plt.figure(figsize=(12, 8))
plt.subplot(131)
plt.title('Testing Image')
plt.imshow(x_test[image,:,:,n_slice])
plt.subplot(132)
plt.title('Testing Label')
plt.imshow(y_test[image,:,:,n_slice])
plt.subplot(133)
plt.title('Prediction on test image')
plt.imshow(prediction[image,:,:,n_slice])
plt.show()
